# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]= '3'

# %%
# %matplotlib inline

import sys
sys.path.append("../../")

from train_model import train

from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot, PredictionError

import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 100
rcParams['font.size'] = 8
rcParams['font.family'] = 'sans-serif'
rcParams['axes.facecolor'] = '#ffffff'
rcParams['lines.linewidth'] = 2.0
# Out:
# 2023-08-22 00:11:44.204383: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
hyperparameter={
"num_nearest":60,
"sigma":10,
"learning_rate":0.001,
"batch_size":250,
"num_neuron":60,
"num_layers":2,
"size_embedded":50,
"num_nearest_geo":60,
"num_nearest_eucli":60,
"id_dataset":'sp',
"epochs":300,
"optimier":'adam',
"validation_split":0.1,
"label":'asi_sp',
"early_stopping": False,
"graph_label":'matrix',
}

# %% [markdown]
# # Model

# %%
spatial = train(**hyperparameter)

# %%
dataset,\
result,\
fit,\
embedded_train,\
embedded_test,\
predict_regression_train,\
predict_regression_test = spatial()
# Out:
# WARNING:tensorflow:From /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-08-22 00:11:46.586173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.590091: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.590350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.591034: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 00:11:46.593591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.593846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.594096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.951388: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.951661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.951890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 00:11:46.952085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# Epoch 1/300
# 2023-08-22 00:11:48.928597: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-22 00:11:48.930928: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f06ab514c70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-22 00:11:48.930942: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-22 00:11:48.934133: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-22 00:11:49.024143: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 195/199 [============================>.] - ETA: 0s - loss: 2.2407 - root_mean_squared_error: 4.3323
# Epoch 1: val_loss improved from inf to 0.23938, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 3s 5ms/step - loss: 2.2078 - root_mean_squared_error: 4.2965 - val_loss: 0.2394 - val_root_mean_squared_error: 0.3302 - lr: 0.0010
# Epoch 2/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.2010 - root_mean_squared_error: 0.2699
# Epoch 2: val_loss improved from 0.23938 to 0.18285, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.2009 - root_mean_squared_error: 0.2697 - val_loss: 0.1828 - val_root_mean_squared_error: 0.2406 - lr: 0.0010
# Epoch 3/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1847 - root_mean_squared_error: 0.2414
# Epoch 3: val_loss improved from 0.18285 to 0.17389, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1844 - root_mean_squared_error: 0.2410 - val_loss: 0.1739 - val_root_mean_squared_error: 0.2260 - lr: 0.0010
# Epoch 4/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1780 - root_mean_squared_error: 0.2324
# Epoch 4: val_loss improved from 0.17389 to 0.17163, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1779 - root_mean_squared_error: 0.2323 - val_loss: 0.1716 - val_root_mean_squared_error: 0.2218 - lr: 0.0010
# Epoch 5/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1748 - root_mean_squared_error: 0.2287
# Epoch 5: val_loss improved from 0.17163 to 0.16497, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1751 - root_mean_squared_error: 0.2287 - val_loss: 0.1650 - val_root_mean_squared_error: 0.2150 - lr: 0.0010
# Epoch 6/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1709 - root_mean_squared_error: 0.2235
# Epoch 6: val_loss did not improve from 0.16497
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1709 - root_mean_squared_error: 0.2236 - val_loss: 0.1682 - val_root_mean_squared_error: 0.2207 - lr: 0.0010
# Epoch 7/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1701 - root_mean_squared_error: 0.2232
# Epoch 7: val_loss did not improve from 0.16497
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1699 - root_mean_squared_error: 0.2230 - val_loss: 0.1679 - val_root_mean_squared_error: 0.2166 - lr: 0.0010
# Epoch 8/300
# 191/199 [===========================>..] - ETA: 0s - loss: 0.1681 - root_mean_squared_error: 0.2206
# Epoch 8: val_loss did not improve from 0.16497
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1679 - root_mean_squared_error: 0.2203 - val_loss: 0.1654 - val_root_mean_squared_error: 0.2156 - lr: 0.0010
# Epoch 9/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1652 - root_mean_squared_error: 0.2167
# Epoch 9: val_loss improved from 0.16497 to 0.15651, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1650 - root_mean_squared_error: 0.2166 - val_loss: 0.1565 - val_root_mean_squared_error: 0.2035 - lr: 0.0010
# Epoch 10/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1627 - root_mean_squared_error: 0.2143
# Epoch 10: val_loss did not improve from 0.15651
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1627 - root_mean_squared_error: 0.2143 - val_loss: 0.1723 - val_root_mean_squared_error: 0.2241 - lr: 0.0010
# Epoch 11/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1624 - root_mean_squared_error: 0.2140
# Epoch 11: val_loss did not improve from 0.15651
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1627 - root_mean_squared_error: 0.2143 - val_loss: 0.1594 - val_root_mean_squared_error: 0.2071 - lr: 0.0010
# Epoch 12/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1632 - root_mean_squared_error: 0.2146
# Epoch 12: val_loss did not improve from 0.15651
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1633 - root_mean_squared_error: 0.2147 - val_loss: 0.1603 - val_root_mean_squared_error: 0.2071 - lr: 0.0010
# Epoch 13/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1596 - root_mean_squared_error: 0.2106
# Epoch 13: val_loss did not improve from 0.15651
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1603 - root_mean_squared_error: 0.2114 - val_loss: 0.1761 - val_root_mean_squared_error: 0.2235 - lr: 0.0010
# Epoch 14/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1572 - root_mean_squared_error: 0.2080
# Epoch 14: val_loss improved from 0.15651 to 0.15351, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1571 - root_mean_squared_error: 0.2078 - val_loss: 0.1535 - val_root_mean_squared_error: 0.2007 - lr: 0.0010
# Epoch 15/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1568 - root_mean_squared_error: 0.2078
# Epoch 15: val_loss improved from 0.15351 to 0.15292, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1569 - root_mean_squared_error: 0.2078 - val_loss: 0.1529 - val_root_mean_squared_error: 0.2012 - lr: 0.0010
# Epoch 16/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1585 - root_mean_squared_error: 0.2091
# Epoch 16: val_loss improved from 0.15292 to 0.15007, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1581 - root_mean_squared_error: 0.2087 - val_loss: 0.1501 - val_root_mean_squared_error: 0.1993 - lr: 0.0010
# Epoch 17/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1547 - root_mean_squared_error: 0.2053
# Epoch 17: val_loss did not improve from 0.15007
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1546 - root_mean_squared_error: 0.2052 - val_loss: 0.1564 - val_root_mean_squared_error: 0.2033 - lr: 0.0010
# Epoch 18/300
# 192/199 [===========================>..] - ETA: 0s - loss: 0.1561 - root_mean_squared_error: 0.2069
# Epoch 18: val_loss did not improve from 0.15007
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1561 - root_mean_squared_error: 0.2069 - val_loss: 0.1728 - val_root_mean_squared_error: 0.2184 - lr: 0.0010
# Epoch 19/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1553 - root_mean_squared_error: 0.2057
# Epoch 19: val_loss did not improve from 0.15007
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1553 - root_mean_squared_error: 0.2058 - val_loss: 0.1545 - val_root_mean_squared_error: 0.2030 - lr: 0.0010
# Epoch 20/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1552 - root_mean_squared_error: 0.2057
# Epoch 20: val_loss did not improve from 0.15007
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1553 - root_mean_squared_error: 0.2059 - val_loss: 0.1560 - val_root_mean_squared_error: 0.2039 - lr: 0.0010
# Epoch 21/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1543 - root_mean_squared_error: 0.2047
# Epoch 21: val_loss improved from 0.15007 to 0.14814, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1544 - root_mean_squared_error: 0.2049 - val_loss: 0.1481 - val_root_mean_squared_error: 0.1964 - lr: 0.0010
# Epoch 22/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1542 - root_mean_squared_error: 0.2046
# Epoch 22: val_loss did not improve from 0.14814
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1542 - root_mean_squared_error: 0.2047 - val_loss: 0.1556 - val_root_mean_squared_error: 0.2017 - lr: 0.0010
# Epoch 23/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1540 - root_mean_squared_error: 0.2045
# Epoch 23: val_loss improved from 0.14814 to 0.14799, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1540 - root_mean_squared_error: 0.2045 - val_loss: 0.1480 - val_root_mean_squared_error: 0.1964 - lr: 0.0010
# Epoch 24/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1524 - root_mean_squared_error: 0.2030
# Epoch 24: val_loss did not improve from 0.14799
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1523 - root_mean_squared_error: 0.2028 - val_loss: 0.1506 - val_root_mean_squared_error: 0.1982 - lr: 0.0010
# Epoch 25/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1516 - root_mean_squared_error: 0.2018
# Epoch 25: val_loss improved from 0.14799 to 0.14717, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1517 - root_mean_squared_error: 0.2019 - val_loss: 0.1472 - val_root_mean_squared_error: 0.1946 - lr: 0.0010
# Epoch 26/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1521 - root_mean_squared_error: 0.2026
# Epoch 26: val_loss did not improve from 0.14717
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1521 - root_mean_squared_error: 0.2026 - val_loss: 0.1580 - val_root_mean_squared_error: 0.2034 - lr: 0.0010
# Epoch 27/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1514 - root_mean_squared_error: 0.2019
# Epoch 27: val_loss did not improve from 0.14717
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1514 - root_mean_squared_error: 0.2019 - val_loss: 0.1537 - val_root_mean_squared_error: 0.2032 - lr: 0.0010
# Epoch 28/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1499 - root_mean_squared_error: 0.2003
# Epoch 28: val_loss did not improve from 0.14717
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1504 - root_mean_squared_error: 0.2009 - val_loss: 0.1685 - val_root_mean_squared_error: 0.2181 - lr: 0.0010
# Epoch 29/300
# 187/199 [===========================>..] - ETA: 0s - loss: 0.1507 - root_mean_squared_error: 0.2011
# Epoch 29: val_loss improved from 0.14717 to 0.14371, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1504 - root_mean_squared_error: 0.2008 - val_loss: 0.1437 - val_root_mean_squared_error: 0.1920 - lr: 0.0010
# Epoch 30/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1500 - root_mean_squared_error: 0.2005
# Epoch 30: val_loss did not improve from 0.14371
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1500 - root_mean_squared_error: 0.2005 - val_loss: 0.1515 - val_root_mean_squared_error: 0.1994 - lr: 0.0010
# Epoch 31/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1493 - root_mean_squared_error: 0.1998
# Epoch 31: val_loss did not improve from 0.14371
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1490 - root_mean_squared_error: 0.1996 - val_loss: 0.1439 - val_root_mean_squared_error: 0.1924 - lr: 0.0010
# Epoch 32/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1494 - root_mean_squared_error: 0.2000
# Epoch 32: val_loss did not improve from 0.14371
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1493 - root_mean_squared_error: 0.1998 - val_loss: 0.1459 - val_root_mean_squared_error: 0.1933 - lr: 0.0010
# Epoch 33/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1481 - root_mean_squared_error: 0.1985
# Epoch 33: val_loss did not improve from 0.14371
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1481 - root_mean_squared_error: 0.1985 - val_loss: 0.1448 - val_root_mean_squared_error: 0.1925 - lr: 0.0010
# Epoch 34/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1481 - root_mean_squared_error: 0.1988
# Epoch 34: val_loss did not improve from 0.14371
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1480 - root_mean_squared_error: 0.1987 - val_loss: 0.1457 - val_root_mean_squared_error: 0.1936 - lr: 0.0010
# Epoch 35/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1433 - root_mean_squared_error: 0.1941
# Epoch 35: val_loss improved from 0.14371 to 0.14184, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1432 - root_mean_squared_error: 0.1941 - val_loss: 0.1418 - val_root_mean_squared_error: 0.1900 - lr: 1.0000e-04
# Epoch 36/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1430 - root_mean_squared_error: 0.1938
# Epoch 36: val_loss improved from 0.14184 to 0.14155, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1430 - root_mean_squared_error: 0.1938 - val_loss: 0.1416 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-04
# Epoch 37/300
# 192/199 [===========================>..] - ETA: 0s - loss: 0.1429 - root_mean_squared_error: 0.1935
# Epoch 37: val_loss improved from 0.14155 to 0.14136, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1429 - root_mean_squared_error: 0.1937 - val_loss: 0.1414 - val_root_mean_squared_error: 0.1896 - lr: 1.0000e-04
# Epoch 38/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1430 - root_mean_squared_error: 0.1939
# Epoch 38: val_loss did not improve from 0.14136
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1429 - root_mean_squared_error: 0.1936 - val_loss: 0.1429 - val_root_mean_squared_error: 0.1906 - lr: 1.0000e-04
# Epoch 39/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1427 - root_mean_squared_error: 0.1935
# Epoch 39: val_loss did not improve from 0.14136
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1429 - root_mean_squared_error: 0.1938 - val_loss: 0.1418 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-04
# Epoch 40/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1428 - root_mean_squared_error: 0.1935
# Epoch 40: val_loss did not improve from 0.14136
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1428 - root_mean_squared_error: 0.1935 - val_loss: 0.1416 - val_root_mean_squared_error: 0.1896 - lr: 1.0000e-04
# Epoch 41/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1429 - root_mean_squared_error: 0.1936
# Epoch 41: val_loss did not improve from 0.14136
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1429 - root_mean_squared_error: 0.1936 - val_loss: 0.1416 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-04
# Epoch 42/300
# 191/199 [===========================>..] - ETA: 0s - loss: 0.1428 - root_mean_squared_error: 0.1933
# Epoch 42: val_loss did not improve from 0.14136
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1430 - root_mean_squared_error: 0.1937 - val_loss: 0.1417 - val_root_mean_squared_error: 0.1899 - lr: 1.0000e-04
# Epoch 43/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1422 - root_mean_squared_error: 0.1930
# Epoch 43: val_loss improved from 0.14136 to 0.14118, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1421 - root_mean_squared_error: 0.1929 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1895 - lr: 1.0000e-05
# Epoch 44/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1928
# Epoch 44: val_loss did not improve from 0.14118
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1420 - root_mean_squared_error: 0.1929 - val_loss: 0.1414 - val_root_mean_squared_error: 0.1895 - lr: 1.0000e-05
# Epoch 45/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1929
# Epoch 45: val_loss improved from 0.14118 to 0.14114, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1420 - root_mean_squared_error: 0.1929 - val_loss: 0.1411 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-05
# Epoch 46/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1928
# Epoch 46: val_loss improved from 0.14114 to 0.14111, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1420 - root_mean_squared_error: 0.1929 - val_loss: 0.1411 - val_root_mean_squared_error: 0.1895 - lr: 1.0000e-05
# Epoch 47/300
# 192/199 [===========================>..] - ETA: 0s - loss: 0.1418 - root_mean_squared_error: 0.1925
# Epoch 47: val_loss improved from 0.14111 to 0.14110, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1420 - root_mean_squared_error: 0.1928 - val_loss: 0.1411 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-05
# Epoch 48/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1929
# Epoch 48: val_loss improved from 0.14110 to 0.14110, saving model to /disk1/jupyter/smhan/ASI-revised/output/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1420 - root_mean_squared_error: 0.1928 - val_loss: 0.1411 - val_root_mean_squared_error: 0.1894 - lr: 1.0000e-05
# Epoch 49/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1421 - root_mean_squared_error: 0.1929
# Epoch 49: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-06
# Epoch 50/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1417 - root_mean_squared_error: 0.1925
# Epoch 50: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-06
# Epoch 51/300
# 189/199 [===========================>..] - ETA: 0s - loss: 0.1418 - root_mean_squared_error: 0.1928
# Epoch 51: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1927 - val_loss: 0.1411 - val_root_mean_squared_error: 0.1894 - lr: 1.0000e-06
# Epoch 52/300
# 191/199 [===========================>..] - ETA: 0s - loss: 0.1419 - root_mean_squared_error: 0.1928
# Epoch 52: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-06
# Epoch 53/300
# 187/199 [===========================>..] - ETA: 0s - loss: 0.1419 - root_mean_squared_error: 0.1928
# Epoch 53: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-06
# Epoch 54/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1418 - root_mean_squared_error: 0.1927
# Epoch 54: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-07
# Epoch 55/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1419 - root_mean_squared_error: 0.1929
# Epoch 55: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-07
# Epoch 56/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1418 - root_mean_squared_error: 0.1927
# Epoch 56: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-07
# Epoch 57/300
# 190/199 [===========================>..] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1930
# Epoch 57: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-07
# Epoch 58/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1420 - root_mean_squared_error: 0.1929
# Epoch 58: val_loss did not improve from 0.14110
# 199/199 [==============================] - 1s 4ms/step - loss: 0.1419 - root_mean_squared_error: 0.1928 - val_loss: 0.1412 - val_root_mean_squared_error: 0.1893 - lr: 1.0000e-07
# 431/431 [==============================] - 1s 1ms/step
# 1722/1722 [==============================] - 2s 977us/step
# 221/221 [==============================] - 0s 883us/step
# 56/56 [==============================] - 0s 1ms/step
# 221/221 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step

# %%
print('################# Test ##########################')
print('MALE test:.... {}'.format(result[0]))
print('RMSE test:.... {}'.format(result[1]))
print('MAPE test:.... {}'.format(result[2]))
print('################# Train ##########################')
print('MALE train:.... {}'.format(result[3]))
print('RMSE train:.... {}'.format(result[4]))
print('MAPE train:.... {}'.format(result[5]))
# Out:
# ################# Test ##########################
# MALE test:.... 0.14172649283902813
# RMSE test:.... 159742.4675331382
# MAPE test:.... 10.797947979798025
# ################# Train ##########################
# MALE train:.... 0.14193460339561598
# RMSE train:.... 160074.68201508682
# MAPE train:.... 10.637366845180164

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(pred, label):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape

# %%
y_label = np.exp(dataset.y_test)
y_pred = np.exp(result[6].flatten())
metric(y_pred, y_label) # should be same value
# Out:
# (0.1417265, 159742.47, 0.10797947979797984)

# %%
plt.scatter(y_label, y_pred)

# %% [markdown]
# # Display Model Training History

# %%
rcParams['figure.figsize'] = (16, 6)
# summarize history for loss
plt.plot(fit.history['loss'])
plt.plot(fit.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Residue

# %% [markdown]
# ## Raw

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the model
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the visualizer
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
g = visualizer.poof();            # Draw/show/poof the data

# %% [markdown]
# ## Embedded

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the model
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the visualizer
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
g = visualizer.poof()             # Draw/show/poof the data

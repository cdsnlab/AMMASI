# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]= '3'

# %%
# %matplotlib inline

import sys
sys.path.append("../../")

from train_model_sm import train

from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import ResidualsPlot, PredictionError

import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rcParams
rcParams['figure.figsize'] = (8, 4)
rcParams['figure.dpi'] = 100
rcParams['font.size'] = 8
rcParams['font.family'] = 'sans-serif'
rcParams['axes.facecolor'] = '#ffffff'
rcParams['lines.linewidth'] = 2.0
# Out:
# 2023-08-22 10:45:56.010998: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
hyperparameter={
"num_nearest":60,
"sigma":10,
"learning_rate":0.001,
"batch_size":250,
"num_neuron":60,
"num_layers":2,
"size_embedded":50,
"num_nearest_geo":60,
"num_nearest_eucli":60,
"id_dataset":'sp',
"epochs":300,
"optimier":'adam',
"validation_split":0.1,
"label":'asi_sp',
"early_stopping": False,
"graph_label":'matrix',
"sequence":'_normalized'
}

# %% [markdown]
# # Model

# %%
spatial = train(**hyperparameter)

# %%
dataset,\
result,\
fit,\
embedded_train,\
embedded_test,\
predict_regression_train,\
predict_regression_test = spatial()
# Out:
# node2vec (68848, 7)
# 2023-08-22 10:45:58.158409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.162377: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.162620: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.163282: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 10:45:58.165174: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.165405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.165610: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.516551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.516805: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.517029: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-22 10:45:58.517213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# self.dist_eucli.shape, self.context_struc_eucli_target.shape, self.n2v_eucli.shape (None, 60) (None, 60, 8) (None, 61, 7)
# self.dist_geo.shape, self.context_geo_target_dist.shape, self.n2v_geo.shape (None, 60) (None, 60, 9) (None, 61, 7)
# WARNING:tensorflow:From /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# self.input_phenomenon.shape Tensor("Placeholder:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# feedforward (None, 60)
# Epoch 1/300
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 2023-08-22 10:46:02.524771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-22 10:46:02.532567: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f0d3802fbd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-22 10:46:02.532617: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-22 10:46:02.538060: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-22 10:46:02.641099: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 198/199 [============================>.] - ETA: 0s - loss: 0.8602 - root_mean_squared_error: 2.4773self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
#
# Epoch 1: val_loss improved from inf to 0.17845, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 7s 10ms/step - loss: 0.8593 - root_mean_squared_error: 2.4756 - val_loss: 0.1784 - val_root_mean_squared_error: 0.2314 - lr: 0.0010
# Epoch 2/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1779 - root_mean_squared_error: 0.2312
# Epoch 2: val_loss improved from 0.17845 to 0.16308, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1779 - root_mean_squared_error: 0.2312 - val_loss: 0.1631 - val_root_mean_squared_error: 0.2133 - lr: 0.0010
# Epoch 3/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1725 - root_mean_squared_error: 0.2251
# Epoch 3: val_loss did not improve from 0.16308
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1725 - root_mean_squared_error: 0.2251 - val_loss: 0.1715 - val_root_mean_squared_error: 0.2215 - lr: 0.0010
# Epoch 4/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1668 - root_mean_squared_error: 0.2190
# Epoch 4: val_loss improved from 0.16308 to 0.15484, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1669 - root_mean_squared_error: 0.2190 - val_loss: 0.1548 - val_root_mean_squared_error: 0.2037 - lr: 0.0010
# Epoch 5/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1658 - root_mean_squared_error: 0.2180
# Epoch 5: val_loss did not improve from 0.15484
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1658 - root_mean_squared_error: 0.2179 - val_loss: 0.1555 - val_root_mean_squared_error: 0.2042 - lr: 0.0010
# Epoch 6/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1595 - root_mean_squared_error: 0.2110
# Epoch 6: val_loss improved from 0.15484 to 0.15264, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1595 - root_mean_squared_error: 0.2110 - val_loss: 0.1526 - val_root_mean_squared_error: 0.2020 - lr: 0.0010
# Epoch 7/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1602 - root_mean_squared_error: 0.2114
# Epoch 7: val_loss did not improve from 0.15264
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1602 - root_mean_squared_error: 0.2114 - val_loss: 0.1578 - val_root_mean_squared_error: 0.2050 - lr: 0.0010
# Epoch 8/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1605 - root_mean_squared_error: 0.2123
# Epoch 8: val_loss improved from 0.15264 to 0.15004, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1603 - root_mean_squared_error: 0.2120 - val_loss: 0.1500 - val_root_mean_squared_error: 0.1977 - lr: 0.0010
# Epoch 9/300
# 192/199 [===========================>..] - ETA: 0s - loss: 0.1589 - root_mean_squared_error: 0.2099
# Epoch 9: val_loss did not improve from 0.15004
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1591 - root_mean_squared_error: 0.2101 - val_loss: 0.1548 - val_root_mean_squared_error: 0.2040 - lr: 0.0010
# Epoch 10/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1572 - root_mean_squared_error: 0.2084
# Epoch 10: val_loss did not improve from 0.15004
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1571 - root_mean_squared_error: 0.2082 - val_loss: 0.1549 - val_root_mean_squared_error: 0.2043 - lr: 0.0010
# Epoch 11/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1561 - root_mean_squared_error: 0.2070
# Epoch 11: val_loss did not improve from 0.15004
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1561 - root_mean_squared_error: 0.2069 - val_loss: 0.1533 - val_root_mean_squared_error: 0.2016 - lr: 0.0010
# Epoch 12/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1563 - root_mean_squared_error: 0.2070
# Epoch 12: val_loss did not improve from 0.15004
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1563 - root_mean_squared_error: 0.2070 - val_loss: 0.1508 - val_root_mean_squared_error: 0.1977 - lr: 0.0010
# Epoch 13/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1544 - root_mean_squared_error: 0.2051
# Epoch 13: val_loss did not improve from 0.15004
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1545 - root_mean_squared_error: 0.2051 - val_loss: 0.1512 - val_root_mean_squared_error: 0.1980 - lr: 0.0010
# Epoch 14/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1481 - root_mean_squared_error: 0.1987
# Epoch 14: val_loss improved from 0.15004 to 0.14538, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1482 - root_mean_squared_error: 0.1988 - val_loss: 0.1454 - val_root_mean_squared_error: 0.1927 - lr: 1.0000e-04
# Epoch 15/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1478 - root_mean_squared_error: 0.1985
# Epoch 15: val_loss improved from 0.14538 to 0.14449, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1478 - root_mean_squared_error: 0.1985 - val_loss: 0.1445 - val_root_mean_squared_error: 0.1921 - lr: 1.0000e-04
# Epoch 16/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1481 - root_mean_squared_error: 0.1988
# Epoch 16: val_loss improved from 0.14449 to 0.14443, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1479 - root_mean_squared_error: 0.1984 - val_loss: 0.1444 - val_root_mean_squared_error: 0.1921 - lr: 1.0000e-04
# Epoch 17/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1474 - root_mean_squared_error: 0.1982
# Epoch 17: val_loss improved from 0.14443 to 0.14423, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1474 - root_mean_squared_error: 0.1981 - val_loss: 0.1442 - val_root_mean_squared_error: 0.1917 - lr: 1.0000e-04
# Epoch 18/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1477 - root_mean_squared_error: 0.1984
# Epoch 18: val_loss did not improve from 0.14423
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1476 - root_mean_squared_error: 0.1981 - val_loss: 0.1457 - val_root_mean_squared_error: 0.1924 - lr: 1.0000e-04
# Epoch 19/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1471 - root_mean_squared_error: 0.1978
# Epoch 19: val_loss improved from 0.14423 to 0.14395, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1471 - root_mean_squared_error: 0.1978 - val_loss: 0.1440 - val_root_mean_squared_error: 0.1915 - lr: 1.0000e-04
# Epoch 20/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1472 - root_mean_squared_error: 0.1976
# Epoch 20: val_loss did not improve from 0.14395
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1473 - root_mean_squared_error: 0.1979 - val_loss: 0.1441 - val_root_mean_squared_error: 0.1918 - lr: 1.0000e-04
# Epoch 21/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1470 - root_mean_squared_error: 0.1976
# Epoch 21: val_loss did not improve from 0.14395
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1470 - root_mean_squared_error: 0.1976 - val_loss: 0.1442 - val_root_mean_squared_error: 0.1921 - lr: 1.0000e-04
# Epoch 22/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1469 - root_mean_squared_error: 0.1975
# Epoch 22: val_loss improved from 0.14395 to 0.14364, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1469 - root_mean_squared_error: 0.1975 - val_loss: 0.1436 - val_root_mean_squared_error: 0.1911 - lr: 1.0000e-04
# Epoch 23/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1471 - root_mean_squared_error: 0.1977
# Epoch 23: val_loss improved from 0.14364 to 0.14326, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1471 - root_mean_squared_error: 0.1977 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1907 - lr: 1.0000e-04
# Epoch 24/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1469 - root_mean_squared_error: 0.1976
# Epoch 24: val_loss did not improve from 0.14326
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1468 - root_mean_squared_error: 0.1975 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1904 - lr: 1.0000e-04
# Epoch 25/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1465 - root_mean_squared_error: 0.1971
# Epoch 25: val_loss did not improve from 0.14326
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1464 - root_mean_squared_error: 0.1971 - val_loss: 0.1440 - val_root_mean_squared_error: 0.1921 - lr: 1.0000e-04
# Epoch 26/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1463 - root_mean_squared_error: 0.1969
# Epoch 26: val_loss did not improve from 0.14326
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1464 - root_mean_squared_error: 0.1970 - val_loss: 0.1447 - val_root_mean_squared_error: 0.1913 - lr: 1.0000e-04
# Epoch 27/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1463 - root_mean_squared_error: 0.1968
# Epoch 27: val_loss improved from 0.14326 to 0.14301, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1463 - root_mean_squared_error: 0.1968 - val_loss: 0.1430 - val_root_mean_squared_error: 0.1906 - lr: 1.0000e-04
# Epoch 28/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1463 - root_mean_squared_error: 0.1968
# Epoch 28: val_loss did not improve from 0.14301
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1463 - root_mean_squared_error: 0.1969 - val_loss: 0.1446 - val_root_mean_squared_error: 0.1932 - lr: 1.0000e-04
# Epoch 29/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1462 - root_mean_squared_error: 0.1970
# Epoch 29: val_loss did not improve from 0.14301
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1462 - root_mean_squared_error: 0.1970 - val_loss: 0.1430 - val_root_mean_squared_error: 0.1908 - lr: 1.0000e-04
# Epoch 30/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1456 - root_mean_squared_error: 0.1962
# Epoch 30: val_loss did not improve from 0.14301
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1457 - root_mean_squared_error: 0.1964 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1912 - lr: 1.0000e-04
# Epoch 31/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1464 - root_mean_squared_error: 0.1973
# Epoch 31: val_loss did not improve from 0.14301
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1464 - root_mean_squared_error: 0.1972 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1903 - lr: 1.0000e-04
# Epoch 32/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1453 - root_mean_squared_error: 0.1960
# Epoch 32: val_loss did not improve from 0.14301
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1453 - root_mean_squared_error: 0.1960 - val_loss: 0.1445 - val_root_mean_squared_error: 0.1913 - lr: 1.0000e-04
# Epoch 33/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1443 - root_mean_squared_error: 0.1951
# Epoch 33: val_loss improved from 0.14301 to 0.14244, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1444 - root_mean_squared_error: 0.1952 - val_loss: 0.1424 - val_root_mean_squared_error: 0.1900 - lr: 1.0000e-05
# Epoch 34/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1443 - root_mean_squared_error: 0.1951
# Epoch 34: val_loss improved from 0.14244 to 0.14224, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1443 - root_mean_squared_error: 0.1951 - val_loss: 0.1422 - val_root_mean_squared_error: 0.1900 - lr: 1.0000e-05
# Epoch 35/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1444 - root_mean_squared_error: 0.1952
# Epoch 35: val_loss improved from 0.14224 to 0.14214, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1442 - root_mean_squared_error: 0.1951 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1899 - lr: 1.0000e-05
# Epoch 36/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1441 - root_mean_squared_error: 0.1950
# Epoch 36: val_loss did not improve from 0.14214
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1442 - root_mean_squared_error: 0.1951 - val_loss: 0.1423 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-05
# Epoch 37/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1441 - root_mean_squared_error: 0.1950
# Epoch 37: val_loss improved from 0.14214 to 0.14211, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1442 - root_mean_squared_error: 0.1950 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-05
# Epoch 38/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1442 - root_mean_squared_error: 0.1951
# Epoch 38: val_loss did not improve from 0.14211
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1442 - root_mean_squared_error: 0.1951 - val_loss: 0.1422 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-05
# Epoch 39/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1442 - root_mean_squared_error: 0.1950
# Epoch 39: val_loss did not improve from 0.14211
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1442 - root_mean_squared_error: 0.1950 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-05
# Epoch 40/300
# 196/199 [============================>.] - ETA: 0s - loss: 0.1441 - root_mean_squared_error: 0.1950
# Epoch 40: val_loss did not improve from 0.14211
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1441 - root_mean_squared_error: 0.1950 - val_loss: 0.1422 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-05
# Epoch 41/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1441 - root_mean_squared_error: 0.1950
# Epoch 41: val_loss improved from 0.14211 to 0.14207, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1441 - root_mean_squared_error: 0.1950 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-05
# Epoch 42/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1440 - root_mean_squared_error: 0.1948
# Epoch 42: val_loss improved from 0.14207 to 0.14206, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1441 - root_mean_squared_error: 0.1950 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-05
# Epoch 43/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 43: val_loss did not improve from 0.14206
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1440 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-06
# Epoch 44/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 44: val_loss did not improve from 0.14206
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-06
# Epoch 45/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1949
# Epoch 45: val_loss improved from 0.14206 to 0.14205, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1949 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-06
# Epoch 46/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 46: val_loss did not improve from 0.14205
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-06
# Epoch 47/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1437 - root_mean_squared_error: 0.1946
# Epoch 47: val_loss improved from 0.14205 to 0.14204, saving model to /disk1/jupyter/smhan/ASI-revised/output_sm/models/sp/asi_sp_weights.hdf5
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1420 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-06
# Epoch 48/300
# 198/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1949
# Epoch 48: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1949 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-07
# Epoch 49/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1440 - root_mean_squared_error: 0.1950
# Epoch 49: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-07
# Epoch 50/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 50: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-07
# Epoch 51/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1438 - root_mean_squared_error: 0.1946
# Epoch 51: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-07
# Epoch 52/300
# 193/199 [============================>.] - ETA: 0s - loss: 0.1438 - root_mean_squared_error: 0.1945
# Epoch 52: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-07
# Epoch 53/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 53: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-08
# Epoch 54/300
# 194/199 [============================>.] - ETA: 0s - loss: 0.1437 - root_mean_squared_error: 0.1946
# Epoch 54: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-08
# Epoch 55/300
# 197/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 55: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-08
# Epoch 56/300
# 199/199 [==============================] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1948
# Epoch 56: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 8ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-08
# Epoch 57/300
# 195/199 [============================>.] - ETA: 0s - loss: 0.1439 - root_mean_squared_error: 0.1949
# Epoch 57: val_loss did not improve from 0.14204
# 199/199 [==============================] - 2s 9ms/step - loss: 0.1439 - root_mean_squared_error: 0.1948 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1897 - lr: 1.0000e-08
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 431/431 [==============================] - 1s 3ms/step
# 1722/1722 [==============================] - 5s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 221/221 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 56/56 [==============================] - 0s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 221/221 [==============================] - 1s 3ms/step
# self.input_phenomenon.shape Tensor("IteratorGetNext:0", shape=(None, 7), dtype=float32)
# self.source_distance.shape (None, 60)
# self.context.shape (None, 60, 9)
# self.n2v.shape (None, 61, 7)
# att_query.shape, att_value.shape (None, 1, 64) (None, 60, 64)
# att_output (None, 64)
# 56/56 [==============================] - 0s 3ms/step

# %%
print('################# Test ##########################')
print('MALE test:.... {}'.format(result[0]))
print('RMSE test:.... {}'.format(result[1]))
print('MAPE test:.... {}'.format(result[2]))
print('################# Train ##########################')
print('MALE train:.... {}'.format(result[3]))
print('RMSE train:.... {}'.format(result[4]))
print('MAPE train:.... {}'.format(result[5]))
# Out:
# ################# Test ##########################
# MALE test:.... 0.14337089851195584
# RMSE test:.... 160785.4122180319
# MAPE test:.... 10.87869050480766
# ################# Train ##########################
# MALE train:.... 0.14375034639746015
# RMSE train:.... 161055.4368609315
# MAPE train:.... 10.875079576646964

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(pred, label):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape

# %%
y_label = np.exp(dataset.y_test)
y_pred = np.exp(result[6].flatten())
metric(y_pred, y_label) # should be same value
# Out:
# (0.1433709, 160785.4, 0.10878690504807692)

# %%
plt.scatter(y_label, y_pred)

# %% [markdown]
# # Display Model Training History

# %%
rcParams['figure.figsize'] = (16, 6)
# summarize history for loss
plt.plot(fit.history['loss'])
plt.plot(fit.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %% [markdown]
# # Residue

# %% [markdown]
# ## Raw

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the model
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression);

visualizer.fit(dataset.X_train, dataset.y_train);  # Fit the training data to the visualizer
visualizer.score(dataset.X_test, dataset.y_test);  # Evaluate the model on the test data
g = visualizer.poof();            # Draw/show/poof the data

# %% [markdown]
# ## Embedded

# %%
# Instantiate the linear model and visualizer
regressor = LinearRegression()
visualizer = ResidualsPlot(regressor)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the model
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
visualizer.poof();                 # Draw/show/poof the data

# %%
# Instantiate the linear model and visualizer
regression = LinearRegression()
visualizer = PredictionError(regression)

visualizer.fit(embedded_train, dataset.y_train)  # Fit the training data to the visualizer
visualizer.score(embedded_test, dataset.y_test)  # Evaluate the model on the test data
g = visualizer.poof()             # Draw/show/poof the data

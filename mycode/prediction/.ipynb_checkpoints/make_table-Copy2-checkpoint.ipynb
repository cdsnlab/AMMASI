# %%
import numpy as np

# %%
import os

# %%
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape*100

# %%
datasets = ['fc', 'kc', 'sp', 'poa']

# %%
os.listdir('fc')
# Out:
# ['fc_MyBasicNei_128_0.05_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_2.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.1_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_5.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_20.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_20.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_3.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_2.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.05_loc_False_poi_False.npy',
#  'ground_truth.npy',
#  'fc_MyBasicNei_128_0.02_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.1_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_10.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_1.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_10.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_3.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.07_loc_False_poi_True.npy']

# %%
dname = datasets[0]

# %%
os.listdir('fc')
# Out:
# ['fc_MyBasicNei_128_0.05_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_2.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.1_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_5.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.2_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_20.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_20.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_3.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_2.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_5.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.5_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.05_loc_False_poi_False.npy',
#  'ground_truth.npy',
#  'fc_MyBasicNei_128_0.02_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.1_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_10.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.07_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.01_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_10.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.03_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.3_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.05_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_1.0_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_1.0_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.2_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.03_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.3_0.09_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_2.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.03_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.09_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.05_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_10.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_20.0_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.5_0.01_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_3.0_0.03_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.1_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_3.0_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.05_0.07_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.02_0.05_loc_False_poi_False.npy',
#  'fc_MyBasicNei_128_0.01_0.01_loc_False_poi_True.npy',
#  'fc_MyBasicNei_128_0.02_0.07_loc_False_poi_True.npy']

# %%
result_dict = dict()
asi_dict = {
    'fc': (0.098, 23177, 6.49),
    'kc': (0.113, 115763, 8.00),
    'sp': (0.135, 155585, 9.80),
    'poa': (0.143, 94492, 9.58)
}




for dname in datasets:
    print(dname, 'sigma', 'sigma2', 'latlon', 'poi', 'male', 'rmse', 'mape', sep='\t')
    gt = np.load(f'{dname}/ground_truth.npy')
    
    min_result = (np.inf, np.inf, np.inf)
    min_cond = 'none'
    for use_latlon in ['False', 'True', 'Sinsinoidal', 'Locfeat']:
        for use_poiprox in ['False', 'True']:
#     for use_latlon in ['True']:
#         for use_poiprox in ['False', 'True']:
            for sigma in [0.01, 0.02, 0.03, 0.05,
                           0.1,  0.2,  0.3,  0.5,  
                           1, 2, 3, 5, 10, 20]:
                for sigma2 in [0.01, 0.03, 0.05, 0.07, 0.09]:
                    fname = f'{dname}/{dname}_MyBasicNei_128_{sigma}_{sigma2}_loc_{use_latlon}_poi_{use_poiprox}.npy'
                    if os.path.isfile(fname):
                        pred = np.load(fname)
                        res = metric(np.exp(gt), np.exp(pred))
                        result_dict[(dname, sigma, sigma2, use_latlon[:5], use_poiprox)] = res

                        if min_result[1] > res[1]:
#                         if use_poiprox == 'True' and min_result[1] > res[1]:
#                             print((dname, sigma, sigma2, use_latlon[:5], use_poiprox), res)
                            min_result = res
                            min_cond = (dname, sigma, sigma2, use_latlon[:5], use_poiprox)
                        
                    else:
                        res = (np.inf, np.inf, np.inf)
                        result_dict[(dname, sigma, sigma2, use_latlon[:5], use_poiprox)] = (np.inf, np.inf, np.inf)
                        
                        
                
                    #print(dname, sigma, sigma2, use_latlon, use_poiprox, '%.3f\t%.0f\t%.2f'%(res), sep='\t')
    print('---best---')
#     print(dname, min_cond[1], min_cond[2], True, False, '%.3f\t%.0f\t%.2f'%(result_dict[min_cond]), sep='\t')
    print(*min_cond, '%.3f\t%.0f\t%.2f'%(result_dict[min_cond]), sep='\t')
#     print(dname, min_cond[1], min_cond[2], True, False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'False')]), sep='\t')
#     print(dname, min_cond[1], min_cond[2], True, False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'False')]), sep='\t')
#     print(dname, min_cond[1], min_cond[2], True, True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'True')]), sep='\t')
    print('---best---')
    
    print(dname, min_cond[1], min_cond[2], 'False', False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'False', 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], 'False', True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'False', 'True')]), sep='\t')
    
    
    print(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], 'True')]), sep='\t')
    
    print(dname, min_cond[1], min_cond[2], 'Locfeat'[:5], False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Locfeat'[:5], 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], 'Locfeat'[:5], True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Locfeat'[:5], 'True')]), sep='\t')
    
    
    print(dname, min_cond[1], min_cond[2], True, False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], True, True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'True')]), sep='\t')
    print(dname, 'asidict', '', '', '', '%.3f\t%.0f\t%.2f'%(asi_dict[(dname)]), sep='\t')
    print()
# Out:
# fc	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# fc	0.1	0.09	Sinsi	False	0.096	22951	6.11
# ---best---
# fc	0.1	0.09	False	False	0.097	23289	6.16
# fc	0.1	0.09	False	True	0.096	23323	6.10
# fc	0.1	0.09	Sinsi	False	0.096	22951	6.11
# fc	0.1	0.09	Sinsi	True	0.096	23189	6.09
# fc	0.1	0.09	Locfe	False	0.111	25891	7.35
# fc	0.1	0.09	Locfe	True	0.096	23073	6.14
# fc	0.1	0.09	True	False	0.096	23153	6.11
# fc	0.1	0.09	True	True	0.097	23389	6.17
# fc	asidict				0.098	23177	6.49
#
# kc	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# kc	0.5	0.05	Locfe	True	0.113	103780	7.95
# ---best---
# kc	0.5	0.05	False	False	0.114	120714	7.78
# kc	0.5	0.05	False	True	0.113	110227	7.86
# kc	0.5	0.05	Sinsi	False	0.113	113716	7.94
# kc	0.5	0.05	Sinsi	True	0.112	107498	7.78
# kc	0.5	0.05	Locfe	False	0.113	116652	7.86
# kc	0.5	0.05	Locfe	True	0.113	103780	7.95
# kc	0.5	0.05	True	False	0.112	112848	7.75
# kc	0.5	0.05	True	True	0.113	111359	7.95
# kc	asidict				0.113	115763	8.00
#
# sp	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# sp	0.01	0.03	Locfe	True	0.134	154910	9.45
# ---best---
# sp	0.01	0.03	False	False	0.137	156908	9.93
# sp	0.01	0.03	False	True	0.138	158449	9.89
# sp	0.01	0.03	Sinsi	False	0.136	156474	9.70
# sp	0.01	0.03	Sinsi	True	0.135	155280	9.55
# sp	0.01	0.03	Locfe	False	0.137	158298	9.92
# sp	0.01	0.03	Locfe	True	0.134	154910	9.45
# sp	0.01	0.03	True	False	0.137	158191	9.80
# sp	0.01	0.03	True	True	0.138	157026	10.06
# sp	asidict				0.135	155585	9.80
#
# poa	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# poa	0.02	0.09	Sinsi	False	0.143	93855	9.95
# ---best---
# poa	0.02	0.09	False	False	0.146	95306	9.95
# poa	0.02	0.09	False	True	0.145	94770	10.21
# poa	0.02	0.09	Sinsi	False	0.143	93855	9.95
# poa	0.02	0.09	Sinsi	True	0.143	94265	9.69
# poa	0.02	0.09	Locfe	False	0.150	96477	10.47
# poa	0.02	0.09	Locfe	True	0.148	95445	10.61
# poa	0.02	0.09	True	False	0.144	94864	10.09
# poa	0.02	0.09	True	True	0.146	95050	10.22
# poa	asidict				0.143	94492	9.58

# %%
import pandas as pd

# %%
# for dname in datasets:
#     print(dname, '--', 'L-', '-P', 'LP', sep='\t')
#     for sigma in [0.02, 0.05, 0.1, 0.5, 1.0, 5.0, 10.0, 20.0]:
#         sigma2 = 0.0
#         if dname == 'fc':
#             sigma2 = 0.1
#         if dname == 'kc':
#             sigma2 = 0.5
#         if dname == 'sp':
#             sigma2 = 0.02
#         if dname == 'poa':
#             sigma2 = 0.02
            
#         line = []
#         for use_poiprox in ['False', 'True']:
#             for use_latlon in ['False', 'True']:
#                 line.append(str('%.2f'%result_dict[(dname, sigma, sigma2, use_latlon, use_poiprox)][2]))
#         print(f'{sigma}\t' + '\t'.join(line))
    
#     print()

# %%
df_dict = {}
for dname in datasets:
#    print(dname, '--', 'L-', '-P', 'LP', sep='\t')
    gt = np.load(f'{dname}/ground_truth.npy')
    rows = []
    for sigma in [0.01, 0.02, 0.03, 0.05,
                   0.1,  0.2,  0.3,  0.5,  
                   1., 2., 3., 5., 10., 20.]:
        sigma2 = -1
        if dname == 'fc':
            sigma2 = 0.09
        if dname == 'kc':
            sigma2 = 0.05
        if dname == 'sp':
            sigma2 = 0.03
        if dname == 'poa':
            sigma2 = 0.09
        
        line = []
        for use_poiprox in ['False', 'True']:
            for use_latlon in ['False', 'Locfeat', 'Sinsinoidal', 'True']:
                fname = f'{dname}/{dname}_MyBasicNei_128_{sigma}_{sigma2}_loc_{use_latlon}_poi_{use_poiprox}.npy'
                if os.path.isfile(fname):
                    pred = np.load(fname)
                    res = metric(np.exp(gt), np.exp(pred))
                    #result_dict[(dname, sigma, use_latlon, use_poiprox)] = res

                    #line.append(float('%.2f'%result_dict[(dname, sigma, use_latlon, use_poiprox)][2]))
                    #line.append(float('%.2f'%res[0]))
                    line.append(res[1])
                else:
                    line.append(float('nan'))

        rows.append([sigma] + line)
    df = pd.DataFrame(rows, columns = ['σ_G', '--', '-P', 'L-', 'LP', 'S-', 'SP', 'A-', 'AP'])
    df = df.set_index('σ_G')
    df_dict[dname] = df
    
    print()

# %%
import seaborn as sns

# %%
df_dict['poa']
# Out:
#                   --             -P             L-             LP  \
# σ_G
# 0.01    95408.164062   95804.882812   94515.468750   95409.851562
# 0.02    95305.960938   96476.609375   93855.070312   94864.109375
# 0.03    95893.585938   95060.960938   93924.867188   95453.382812
# 0.05    98031.742188   96733.156250   95816.750000   98658.312500
# 0.10    99000.789062   98263.656250   98849.796875   98701.812500
# 0.20   101748.679688  100806.273438  101217.929688  102016.500000
# 0.30   103515.796875  103830.648438  103204.195312  103127.812500
# 0.50   103936.164062  104536.234375  103570.726562  104255.085938
# 1.00   104657.507812  104578.546875  104261.734375  104417.343750
# 2.00   104833.382812  104405.109375  104083.156250  104271.117188
# 3.00   104653.828125  104262.562500  104225.101562  104212.281250
# 5.00   104246.460938  103959.234375  104627.773438  104558.898438
# 10.00  104811.000000  105102.406250  104683.046875  104805.085938
# 20.00  104579.406250  104569.445312  104320.437500  104720.062500
#
#                   S-             SP             A-             AP
# σ_G
# 0.01    95340.601562   95004.148438   93859.578125   95698.757812
# 0.02    94770.039062   95445.226562   94264.984375   95050.242188
# 0.03    97398.007812   96995.171875   94895.640625   95074.710938
# 0.05    96299.250000   96348.031250   96472.492188   95869.757812
# 0.10    98477.234375   99748.351562   98270.023438   98709.367188
# 0.20   100409.281250  100400.367188  101464.320312  101063.710938
# 0.30   103922.976562  103928.179688  103812.570312  103926.953125
# 0.50   104551.750000  105045.078125  103962.609375  104833.046875
# 1.00   104749.039062  104310.039062  104367.484375  104591.554688
# 2.00   104309.609375  104643.226562  103507.046875  104758.742188
# 3.00   105089.156250  104280.515625  105064.437500  104080.921875
# 5.00   104854.851562  104769.429688  104536.648438  105511.828125
# 10.00  104443.351562  105086.820312  104155.726562  104438.976562
# 20.00  104976.835938  105541.570312  103980.500000  104474.953125

# %%
import matplotlib.pyplot as plt

# %%
color_lines = [
    ('blue', '--'),
    ('darkblue', '-'),
    ('orange', '--'),
    ('darkorange', '-'),
    ('green', '--'),
    ('darkgreen', '-'),
    ('red', '--'),
    ('darkred', '-'),
]





for dname, vv in zip(datasets, [0.1, 0.1, 0.01, 0.02]):
    fig, ax = plt.subplots(figsize=(4, 3))
    
    minval = np.inf
    maxval = -np.inf
    for col, cl in zip(['--', '-P', 'L-', 'LP', 'S-', 'SP', 'A-', 'AP'], color_lines):
        if col[1] == 'P':
            m = 'P'
        else:
            m = '.'
        df_dict[dname][col].plot(ax=ax, marker=m, color=cl[0], linestyle=cl[1])
        for kv in df_dict[dname][col].values:
            if kv < minval:
                minval = kv
            if kv > maxval:
                maxval = kv
                
    #df_dict[dname][['--', '-P', 'L-', 'LP', 'S-', 'SP', 'A-', 'AP']].plot(ax=ax, marker='.')
    plt.xscale('log')
    
    plt.ylabel('RMSE')
    plt.legend()
    plt.vlines(vv, minval, maxval, linewidth=.5, linestyle='--', color='gray')
    plt.xlabel(f'σ_G (best: {vv})')
    #plt.title(dname)

    # Show the figure
    #plt.show()

    # Set a higher DPI value (e.g., 300)
    fig.set_dpi(300)

    # Save the figure with high resolution
    fig.savefig(f'ablation_{dname}.png', dpi=300,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Create the figure and axes
# fig, axs = plt.subplots(len(datasets), len(models), figsize=(12, 9), sharex=True, sharey=True)

# # Iterate over datasets and models
# for i, dataset in enumerate(datasets):
#     ground_truth = np.load(f'./{dataset}/ground_truth.npy')
#     for j, model in enumerate(models):
#         # Generate random data for each ablation setting
#         ablations_style = []
#         if model == 'MyUAGCRN' or model == 'MyUAGCTransformer':
#             ablations = []
#             ablations_name = []
#             ablations_style = []
#             for g, a, s in reversed([('legacy', 'none', 'none'),
#                             ('cooccur_dist', 'none', 'none'),
#                             ('legacy', 'AE', 'SE'),
#                             ('cooccur_dist', 'AE', 'SE')]):
#                 ablations.append((g, a, s))

#                 aname = []
#                 if g == 'legacy':
#                     aname.append('legacy')
#                     astyle = '--'
#                 else:
#                     aname.append('ourgraph')
#                     astyle = '-'

#                 acolor = 'gray'
#                 if a == 'AE':
#                     aname.append('AE')
#                     acolor = 'red'
#                 if s == 'SE':
#                     aname.append('SE')
#                     acolor = 'green'
#                 if a == 'AE' and s == 'SE':
#                     acolor = 'blue'

#                 aname = '+'.join(aname)
#                 if len(aname) == 0:
#                     aname = 'none'
#                 ablations_name.append(aname)
#                 ablations_style.append((acolor, astyle))

#         elif model == 'MyARLSTM' or model == 'MyTransformer':
#             ablations = []
#             ablations_name = []
#             ablations_style = []
#             for a in ['AE', 'none']:
#                 for s in ['SE', 'none']:
#                     ablations.append(('none', a, s))

#                     aname = []
#                     astyle = '-'
#                     acolor = 'gray'
#                     if a == 'AE':
#                         aname.append('AE')
#                         acolor = 'red'
#                     if s == 'SE':
#                         aname.append('SE')
#                         acolor = 'green'
#                     if a == 'AE' and s == 'SE':
#                         acolor = 'blue'

#                     aname = '+'.join(aname)
#                     if len(aname) == 0:
#                         aname = 'none'
#                     ablations_name.append(aname)
#                     ablations_style.append((acolor, astyle))
#         else:
#             ablations = []
#             ablations_name = []

#         if dataset != 'pemsd7':
#             maxQ = 12
#         else:
#             maxQ = 9

# #         x = np.arange(1, maxQ + 1)
#         x = np.arange(1, 3 + 1)
#         y = []
#         for g, a, s in ablations:
#             fname = f'./{dataset}/{dataset}_{model}_G-{g}_AE-{a}_SE-{s}.npy'

#             try:
#                 if fname in fname2eval:
#                     evals = fname2eval[fname]
#                 else:
#                     prediction = np.load(fname)
#                     evals = []
#                     for Q in range(maxQ):
#                         vvv = metric(ground_truth[:, Q, ...], prediction[:, Q, ...])
#                         evals.append(vvv[1])
                    
#                     fname2eval[fname] = evals
#             except:
#                 print('not exist:', fname)
#                 pass
            
#             if maxQ == 12:
#                 y.append([evals[2], evals[5], evals[11]])
#             elif maxQ == 9:
#                 y.append([evals[2], evals[5], evals[ 8]])
                
# #         print(y)

#         # Plot the data
#         ax = axs[i, j]
#         bar_width = 0.15
#         opacity = 0.8
#         colors = ['blue', 'red', 'green', 'orange', 'purple']

#         ax.bar(x, dcrnn_metric[dataset], bar_width, alpha=opacity, color='black', label='DCRNN')
#         for k in range(len(ablations)):
#             ax.bar(x + ((k+1) * bar_width), y[k], bar_width, alpha=opacity, color=colors[k], label=ablations_name[k])

#         ax.set(xticks=list(range(1, 3+1)), ylim=(2, 10))
#         ax.set_title(model2title[model])
#         ax.legend( loc='upper left')
# #         ax.legend()

#         fig.tight_layout()

# # Add a common x-axis label and a legend
# # fig.text(0.5, 0.04, 'Q', ha='center', fontsize=14)
# # fig.legend(bbox_to_anchor=(0.5, -0.1), loc='lower center', ncol=len(ablations))

# # Set the overall title
# # fig.suptitle('Evaluation Results', fontsize=16)

# # Show the figure
# plt.show()

# # Set a higher DPI value (e.g., 300)
# fig.set_dpi(300)

# # Save the figure with high resolution
# fig.savefig('figure_high_resolution.png', dpi=300)

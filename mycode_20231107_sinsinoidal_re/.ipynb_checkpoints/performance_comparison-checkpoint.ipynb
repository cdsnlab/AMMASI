# %%
import os
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape

# %%
for dataset in ['prediction/fc', 'prediction/kc', 'prediction/poa', 'prediction/sp']:
    if not os.path.isfile(dataset + '/ground_truth.npy'):
        continue
    best1, best2, best3 = 999999999, 9999999999, 9999999999
    gt = np.load(dataset + '/ground_truth.npy')
    
    npy_list = dict()
    for fname in sorted(os.listdir(dataset)):
        if fname != 'ground_truth.npy' and fname[-4:] == '.npy':
            npy_list[fname] = np.load(dataset + '/' + fname)
            
            new1, new2, new3 = metric(np.exp(gt), np.exp(npy_list[fname]))
            if best1 > new1:
                best1 = new1
            if best2 > new2:
                best2 = new2
            if best3 > new3:
                best3 = new3
            
    print((f'{dataset} best' + ' '*40)[:40], '\t'.join([f"{v:14.3f}" for v in (best1, best2, best3)]), sep='\t')            
    for fname in npy_list:
        a1, a2, a3 = metric(np.exp(gt), np.exp(npy_list[fname]))
        a1 -= best1
        a2 -= best2
        a3 -= best3
        print((fname + ' '*20)[:40], '\t'.join([f"{v:+14.3f}" for v in (a1, a2, a3)]), sep='\t')
    print()
# Out:
# prediction/fc best                      	         0.115	     27081.652	         0.075
# fc_MyBasicNeighbor_0.1_128.npy          	        +0.007	     +1378.277	        +0.004
# fc_MyBasicNeighbor_0.1_256.npy          	        +0.000	      +284.906	        +0.000
# fc_MyBasicNeighbor_0.1_32.npy           	        +0.020	     +3155.906	        +0.015
# fc_MyBasicNeighbor_0.1_64.npy           	        +0.016	     +2610.994	        +0.012
# fc_MyBasicNeighbor_0.2_128.npy          	        +0.004	      +955.271	        +0.003
# fc_MyBasicNeighbor_0.2_256.npy          	        +0.002	      +572.607	        +0.001
# fc_MyBasicNeighbor_0.2_32.npy           	        +0.022	     +3687.559	        +0.015
# fc_MyBasicNeighbor_0.2_64.npy           	        +0.010	     +1915.176	        +0.009
# fc_MyBasicNeighbor_0.3_128.npy          	        +0.003	      +866.260	        +0.002
# fc_MyBasicNeighbor_0.3_256.npy          	        +0.000	        +0.000	        +0.000
# fc_MyBasicNeighbor_0.3_32.npy           	        +0.021	     +3398.047	        +0.015
# fc_MyBasicNeighbor_0.3_64.npy           	        +0.010	     +1932.289	        +0.007
# fc_MyBasicNeighbor_0.5_128.npy          	        +0.009	     +1892.430	        +0.006
# fc_MyBasicNeighbor_0.5_32.npy           	        +0.031	     +4998.824	        +0.023
# fc_MyBasicNeighbor_0.5_64.npy           	        +0.014	     +2442.574	        +0.010
# fc_MyBasic_0.1_128.npy                  	        +0.008	     +1395.994	        +0.005
# fc_MyBasic_0.1_256.npy                  	        +0.003	      +605.189	        +0.001
# fc_MyBasic_0.1_32.npy                   	        +0.019	     +3276.439	        +0.014
# fc_MyBasic_0.1_64.npy                   	        +0.016	     +3048.873	        +0.010
# fc_MyBasic_0.2_128.npy                  	        +0.005	      +920.752	        +0.003
# fc_MyBasic_0.2_256.npy                  	        +0.001	      +190.867	        +0.000
# fc_MyBasic_0.2_32.npy                   	        +0.019	     +3210.051	        +0.014
# fc_MyBasic_0.2_64.npy                   	        +0.013	     +2331.209	        +0.008
# fc_MyBasic_0.3_128.npy                  	        +0.002	      +352.236	        +0.001
# fc_MyBasic_0.3_256.npy                  	        +0.005	     +1059.098	        +0.003
# fc_MyBasic_0.3_32.npy                   	        +0.031	     +4974.424	        +0.022
# fc_MyBasic_0.3_64.npy                   	        +0.014	     +2473.402	        +0.009
# fc_MyBasic_0.5_128.npy                  	        +0.008	     +1537.906	        +0.006
# fc_MyBasic_0.5_256.npy                  	        +0.002	      +645.529	        +0.001
# fc_MyBasic_0.5_32.npy                   	        +0.021	     +3196.799	        +0.014
# fc_MyBasic_0.5_64.npy                   	        +0.010	     +1687.801	        +0.007
# fc_MyBasic_1.0_128.npy                  	        +0.006	     +1160.670	        +0.003
# fc_MyBasic_1.0_256.npy                  	        +0.002	      +438.121	        +0.001
# fc_MyBasic_1.0_32.npy                   	        +0.028	     +4484.764	        +0.019
# fc_MyBasic_1.0_64.npy                   	        +0.009	     +1653.543	        +0.006
# fc_MyBasic_1.5_128.npy                  	        +0.003	      +830.049	        +0.001
# fc_MyBasic_1.5_256.npy                  	        +0.003	      +700.131	        +0.002
# fc_MyBasic_1.5_32.npy                   	        +0.022	     +3516.959	        +0.016
# fc_MyBasic_1.5_64.npy                   	        +0.007	     +1371.408	        +0.005
# fc_MyBasic_3.0_128.npy                  	        +0.007	     +1444.705	        +0.004
# fc_MyBasic_3.0_256.npy                  	        +0.004	      +798.051	        +0.001
# fc_MyBasic_3.0_32.npy                   	        +0.028	     +4453.086	        +0.019
# fc_MyBasic_3.0_64.npy                   	        +0.022	     +3523.580	        +0.015
# fc_MyBasic_5.0_128.npy                  	        +0.004	      +784.441	        +0.002
# fc_MyBasic_5.0_256.npy                  	        +0.002	      +613.910	        +0.001
# fc_MyBasic_5.0_32.npy                   	        +0.022	     +3500.967	        +0.015
# fc_MyBasic_5.0_64.npy                   	        +0.014	     +2277.016	        +0.010
# fc_MyBasic_999.0_128.npy                	        +0.009	     +1818.621	        +0.005
# fc_MyBasic_999.0_256.npy                	        +0.008	     +1503.215	        +0.006
# fc_MyBasic_999.0_32.npy                 	        +0.025	     +4069.797	        +0.018
# fc_MyBasic_999.0_64.npy                 	        +0.011	     +2178.164	        +0.007
# fc_MyNeighborMean_0.1_128.npy           	        +0.010	     +1730.939	        +0.006
# fc_MyNeighborMean_0.1_256.npy           	        +0.007	     +1548.799	        +0.004
# fc_MyNeighborMean_0.1_32.npy            	        +0.030	     +4604.904	        +0.022
# fc_MyNeighborMean_0.1_64.npy            	        +0.015	     +2609.340	        +0.011
# fc_MyNeighborMean_0.2_128.npy           	        +0.007	     +1534.553	        +0.005
# fc_MyNeighborMean_0.2_256.npy           	        +0.003	      +762.977	        +0.002
# fc_MyNeighborMean_0.2_32.npy            	        +0.029	     +4889.389	        +0.020
# fc_MyNeighborMean_0.2_64.npy            	        +0.018	     +3129.957	        +0.013
# fc_MyNeighborMean_0.3_128.npy           	        +0.012	     +2286.266	        +0.008
# fc_MyNeighborMean_0.3_256.npy           	        +0.006	     +1580.873	        +0.003
# fc_MyNeighborMean_0.3_32.npy            	        +0.040	     +6338.297	        +0.029
# fc_MyNeighborMean_0.3_64.npy            	        +0.023	     +3877.471	        +0.016
# fc_MyNeighborMean_0.5_128.npy           	        +0.008	     +1683.936	        +0.005
# fc_MyNeighborMean_0.5_256.npy           	        +0.006	     +1162.820	        +0.004
# fc_MyNeighborMean_0.5_32.npy            	        +0.033	     +5182.816	        +0.025
# fc_MyNeighborMean_0.5_64.npy            	        +0.020	     +3303.578	        +0.014
# fc_MyNeighborMean_1.0_128.npy           	        +0.007	     +1365.586	        +0.005
# fc_MyNeighborMean_1.0_256.npy           	        +0.003	      +863.945	        +0.001
# fc_MyNeighborMean_1.0_32.npy            	        +0.032	     +5341.150	        +0.024
# fc_MyNeighborMean_1.0_64.npy            	        +0.020	     +3293.920	        +0.014
# fc_MyNeighborMean_1.5_128.npy           	        +0.011	     +2002.639	        +0.007
# fc_MyNeighborMean_1.5_256.npy           	        +0.006	     +1280.465	        +0.004
# fc_MyNeighborMean_1.5_32.npy            	        +0.038	     +6124.934	        +0.028
# fc_MyNeighborMean_1.5_64.npy            	        +0.017	     +2936.908	        +0.012
# fc_MyNeighborMean_3.0_128.npy           	        +0.011	     +1848.023	        +0.008
# fc_MyNeighborMean_3.0_256.npy           	        +0.005	     +1098.850	        +0.003
# fc_MyNeighborMean_3.0_32.npy            	        +0.033	     +5295.637	        +0.024
# fc_MyNeighborMean_3.0_64.npy            	        +0.017	     +3067.209	        +0.010
# fc_MyNeighborMean_5.0_128.npy           	        +0.012	     +2051.047	        +0.007
# fc_MyNeighborMean_5.0_256.npy           	        +0.003	      +785.264	        +0.001
# fc_MyNeighborMean_5.0_32.npy            	        +0.038	     +6096.309	        +0.027
# fc_MyNeighborMean_5.0_64.npy            	        +0.015	     +2513.256	        +0.010
# fc_MyNeighborMean_999.0_128.npy         	        +0.005	     +1206.830	        +0.003
# fc_MyNeighborMean_999.0_256.npy         	        +0.005	     +1147.271	        +0.002
# fc_MyNeighborMean_999.0_32.npy          	        +0.032	     +5280.889	        +0.023
# fc_MyNeighborMean_999.0_64.npy          	        +0.014	     +2457.139	        +0.010
#
# prediction/kc best                      	         0.115	    107094.711	         0.081
# kc_MyBasicNeighbor_0.1_128.npy          	        +0.007	     +5972.250	        +0.007
# kc_MyBasicNeighbor_0.1_256.npy          	        +0.006	     +5784.766	        +0.006
# kc_MyBasicNeighbor_0.1_32.npy           	        +0.010	     +9873.500	        +0.010
# kc_MyBasicNeighbor_0.1_64.npy           	        +0.011	    +12066.227	        +0.010
# kc_MyBasicNeighbor_0.2_128.npy          	        +0.007	    +10576.312	        +0.007
# kc_MyBasicNeighbor_0.2_256.npy          	        +0.005	     +4544.797	        +0.005
# kc_MyBasicNeighbor_0.2_32.npy           	        +0.013	    +11268.250	        +0.011
# kc_MyBasicNeighbor_0.2_64.npy           	        +0.007	     +4891.219	        +0.007
# kc_MyBasicNeighbor_0.3_128.npy          	        +0.005	     +6531.906	        +0.005
# kc_MyBasicNeighbor_0.3_256.npy          	        +0.003	     +3617.891	        +0.002
# kc_MyBasicNeighbor_0.3_32.npy           	        +0.008	     +6077.469	        +0.009
# kc_MyBasicNeighbor_0.3_64.npy           	        +0.009	     +6298.039	        +0.008
# kc_MyBasicNeighbor_0.5_128.npy          	        +0.003	     +3017.141	        +0.003
# kc_MyBasicNeighbor_0.5_256.npy          	        +0.003	     +4820.312	        +0.004
# kc_MyBasicNeighbor_0.5_32.npy           	        +0.011	    +10548.906	        +0.011
# kc_MyBasicNeighbor_0.5_64.npy           	        +0.006	     +3355.172	        +0.004
# kc_MyBasicNeighbor_1.0_128.npy          	        +0.003	     +2356.516	        +0.002
# kc_MyBasicNeighbor_1.0_256.npy          	        +0.002	     +1191.125	        +0.003
# kc_MyBasicNeighbor_1.0_32.npy           	        +0.007	     +7738.648	        +0.006
# kc_MyBasicNeighbor_1.0_64.npy           	        +0.006	     +5793.477	        +0.005
# kc_MyBasicNeighbor_1.5_128.npy          	        +0.001	     +1699.445	        +0.001
# kc_MyBasicNeighbor_1.5_256.npy          	        +0.002	     +2773.148	        +0.001
# kc_MyBasicNeighbor_1.5_32.npy           	        +0.008	     +7015.906	        +0.008
# kc_MyBasicNeighbor_1.5_64.npy           	        +0.006	     +5632.391	        +0.006
# kc_MyBasicNeighbor_3.0_128.npy          	        +0.002	      +627.641	        +0.003
# kc_MyBasicNeighbor_3.0_256.npy          	        +0.000	        +0.000	        +0.001
# kc_MyBasicNeighbor_3.0_32.npy           	        +0.006	     +7052.203	        +0.005
# kc_MyBasicNeighbor_3.0_64.npy           	        +0.003	     +3547.383	        +0.004
# kc_MyBasicNeighbor_5.0_128.npy          	        +0.002	     +1401.422	        +0.003
# kc_MyBasicNeighbor_5.0_256.npy          	        +0.002	     +2706.867	        +0.002
# kc_MyBasicNeighbor_5.0_32.npy           	        +0.006	     +6272.727	        +0.007
# kc_MyBasicNeighbor_5.0_64.npy           	        +0.008	     +8769.258	        +0.007
# kc_MyBasicNeighbor_999.0_128.npy        	        +0.005	     +5748.156	        +0.005
# kc_MyBasicNeighbor_999.0_256.npy        	        +0.002	     +2648.516	        +0.003
# kc_MyBasicNeighbor_999.0_32.npy         	        +0.008	     +6379.398	        +0.007
# kc_MyBasicNeighbor_999.0_64.npy         	        +0.006	     +6228.367	        +0.006
# kc_MyBasic_0.1_128.npy                  	        +0.001	     +1675.375	        +0.000
# kc_MyBasic_0.1_256.npy                  	        +0.003	     +3673.430	        +0.003
# kc_MyBasic_0.1_32.npy                   	        +0.004	     +8363.195	        +0.004
# kc_MyBasic_0.1_64.npy                   	        +0.004	     +5185.070	        +0.004
# kc_MyBasic_0.2_128.npy                  	        +0.001	     +2700.570	        +0.001
# kc_MyBasic_0.2_256.npy                  	        +0.000	     +5860.609	        +0.000
# kc_MyBasic_0.2_32.npy                   	        +0.002	     +2819.523	        +0.002
# kc_MyBasic_0.2_64.npy                   	        +0.002	     +3639.250	        +0.002
# kc_MyBasic_0.3_128.npy                  	        +0.002	     +3469.672	        +0.001
# kc_MyBasic_0.3_256.npy                  	        +0.000	     +1504.523	        +0.002
# kc_MyBasic_0.3_32.npy                   	        +0.007	     +5476.734	        +0.006
# kc_MyBasic_0.3_64.npy                   	        +0.006	     +5298.961	        +0.006
# kc_MyBasic_0.5_128.npy                  	        +0.002	     +4230.586	        +0.001
# kc_MyBasic_0.5_256.npy                  	        +0.001	     +3095.695	        +0.001
# kc_MyBasic_0.5_32.npy                   	        +0.005	     +4621.773	        +0.005
# kc_MyBasic_0.5_64.npy                   	        +0.002	     +1484.133	        +0.001
# kc_MyBasic_1.0_128.npy                  	        +0.001	     +2638.023	        +0.000
# kc_MyBasic_1.0_256.npy                  	        +0.001	     +3269.914	        +0.001
# kc_MyBasic_1.0_32.npy                   	        +0.003	     +2267.812	        +0.002
# kc_MyBasic_1.0_64.npy                   	        +0.005	     +4828.562	        +0.004
# kc_MyBasic_1.5_128.npy                  	        +0.001	     +2240.234	        +0.000
# kc_MyBasic_1.5_256.npy                  	        +0.002	     +4875.062	        +0.002
# kc_MyBasic_1.5_32.npy                   	        +0.005	     +5293.914	        +0.004
# kc_MyBasic_1.5_64.npy                   	        +0.003	     +3138.047	        +0.001
# kc_MyBasic_3.0_128.npy                  	        +0.002	     +3466.945	        +0.002
# kc_MyBasic_3.0_256.npy                  	        +0.003	     +3502.570	        +0.002
# kc_MyBasic_3.0_32.npy                   	        +0.005	     +3848.078	        +0.003
# kc_MyBasic_3.0_64.npy                   	        +0.004	     +4185.055	        +0.003
# kc_MyBasic_5.0_128.npy                  	        +0.004	     +3392.102	        +0.003
# kc_MyBasic_5.0_256.npy                  	        +0.002	     +3845.922	        +0.001
# kc_MyBasic_5.0_32.npy                   	        +0.007	     +6266.023	        +0.007
# kc_MyBasic_5.0_64.npy                   	        +0.003	     +4322.758	        +0.002
# kc_MyBasic_999.0_128.npy                	        +0.003	     +5477.641	        +0.002
# kc_MyBasic_999.0_256.npy                	        +0.003	     +3636.094	        +0.001
# kc_MyBasic_999.0_32.npy                 	        +0.006	     +6714.359	        +0.005
# kc_MyBasic_999.0_64.npy                 	        +0.002	     +1524.539	        +0.002
# kc_MyNeighborMean_0.1_128.npy           	        +0.003	     +4900.391	        +0.003
# kc_MyNeighborMean_0.1_256.npy           	        +0.005	     +6808.438	        +0.005
# kc_MyNeighborMean_0.1_32.npy            	        +0.008	     +6588.273	        +0.008
# kc_MyNeighborMean_0.1_64.npy            	        +0.013	    +23314.227	        +0.013
# kc_MyNeighborMean_0.2_128.npy           	        +0.004	     +5108.867	        +0.004
# kc_MyNeighborMean_0.2_256.npy           	        +0.005	     +5590.812	        +0.004
# kc_MyNeighborMean_0.2_32.npy            	        +0.011	     +9251.141	        +0.012
# kc_MyNeighborMean_0.2_64.npy            	        +0.006	     +5686.555	        +0.005
# kc_MyNeighborMean_0.3_128.npy           	        +0.006	     +5793.734	        +0.004
# kc_MyNeighborMean_0.3_256.npy           	        +0.006	     +7075.703	        +0.004
# kc_MyNeighborMean_0.3_32.npy            	        +0.016	    +17510.344	        +0.015
# kc_MyNeighborMean_0.3_64.npy            	        +0.011	    +11363.672	        +0.012
# kc_MyNeighborMean_0.5_128.npy           	        +0.005	     +4282.891	        +0.005
# kc_MyNeighborMean_0.5_256.npy           	        +0.004	     +5183.570	        +0.005
# kc_MyNeighborMean_0.5_32.npy            	        +0.013	    +12063.930	        +0.013
# kc_MyNeighborMean_0.5_64.npy            	        +0.007	     +6551.234	        +0.008
# kc_MyNeighborMean_1.0_128.npy           	        +0.004	     +3522.250	        +0.003
# kc_MyNeighborMean_1.0_256.npy           	        +0.004	     +5593.586	        +0.003
# kc_MyNeighborMean_1.0_32.npy            	        +0.012	    +10496.445	        +0.011
# kc_MyNeighborMean_1.0_64.npy            	        +0.009	     +6912.961	        +0.008
# kc_MyNeighborMean_1.5_128.npy           	        +0.005	     +5211.625	        +0.004
# kc_MyNeighborMean_1.5_256.npy           	        +0.004	     +5543.797	        +0.002
# kc_MyNeighborMean_1.5_32.npy            	        +0.012	    +10011.586	        +0.010
# kc_MyNeighborMean_1.5_64.npy            	        +0.007	     +7125.633	        +0.006
# kc_MyNeighborMean_3.0_128.npy           	        +0.004	     +4342.445	        +0.003
# kc_MyNeighborMean_3.0_256.npy           	        +0.004	     +5257.430	        +0.003
# kc_MyNeighborMean_3.0_32.npy            	        +0.011	     +8237.008	        +0.011
# kc_MyNeighborMean_3.0_64.npy            	        +0.005	     +4597.180	        +0.004
# kc_MyNeighborMean_5.0_128.npy           	        +0.006	     +4719.070	        +0.006
# kc_MyNeighborMean_5.0_256.npy           	        +0.004	     +4517.883	        +0.003
# kc_MyNeighborMean_5.0_32.npy            	        +0.011	     +9732.727	        +0.010
# kc_MyNeighborMean_5.0_64.npy            	        +0.010	     +9334.852	        +0.009
# kc_MyNeighborMean_999.0_128.npy         	        +0.009	     +7812.227	        +0.007
# kc_MyNeighborMean_999.0_256.npy         	        +0.005	     +5317.648	        +0.005
# kc_MyNeighborMean_999.0_32.npy          	        +0.014	    +13039.750	        +0.013
# kc_MyNeighborMean_999.0_64.npy          	        +0.008	     +6629.609	        +0.007
# prediction/poa best                     	         0.211	    121744.031	         0.174
# poa_MyBasicNeighbor_0.1_128.npy         	        +0.010	     +5443.594	        +0.012
# poa_MyBasicNeighbor_0.1_256.npy         	        +0.012	     +6357.812	        +0.014
# poa_MyBasicNeighbor_0.1_32.npy          	        +0.012	     +6796.344	        +0.016
# poa_MyBasicNeighbor_0.1_64.npy          	        +0.009	     +5818.828	        +0.013
# poa_MyBasicNeighbor_0.2_128.npy         	        +0.006	     +4231.906	        +0.008
# poa_MyBasicNeighbor_0.2_256.npy         	        +0.003	     +2195.102	        +0.004
# poa_MyBasicNeighbor_0.2_32.npy          	        +0.010	     +5587.828	        +0.016
# poa_MyBasicNeighbor_0.2_64.npy          	        +0.009	     +5339.406	        +0.012
# poa_MyBasicNeighbor_0.3_128.npy         	        +0.004	     +3326.438	        +0.006
# poa_MyBasicNeighbor_0.3_256.npy         	        +0.001	     +2069.023	        +0.002
# poa_MyBasicNeighbor_0.3_32.npy          	        +0.012	     +8149.547	        +0.014
# poa_MyBasicNeighbor_0.3_64.npy          	        +0.007	     +4929.344	        +0.012
# poa_MyBasicNeighbor_0.5_128.npy         	        +0.005	     +2990.656	        +0.006
# poa_MyBasicNeighbor_0.5_256.npy         	        +0.002	     +1515.594	        +0.001
# poa_MyBasicNeighbor_0.5_32.npy          	        +0.011	     +5660.320	        +0.014
# poa_MyBasicNeighbor_0.5_64.npy          	        +0.010	     +4985.719	        +0.012
# poa_MyBasicNeighbor_1.0_128.npy         	        +0.010	     +5527.250	        +0.011
# poa_MyBasicNeighbor_1.0_256.npy         	        +0.002	     +1446.844	        +0.000
# poa_MyBasicNeighbor_1.0_32.npy          	        +0.007	     +4155.781	        +0.011
# poa_MyBasicNeighbor_1.0_64.npy          	        +0.004	     +2692.430	        +0.006
# poa_MyBasicNeighbor_1.5_128.npy         	        +0.007	     +3450.352	        +0.008
# poa_MyBasicNeighbor_1.5_256.npy         	        +0.000	      +649.836	        +0.001
# poa_MyBasicNeighbor_1.5_32.npy          	        +0.019	    +10212.781	        +0.021
# poa_MyBasicNeighbor_1.5_64.npy          	        +0.005	     +3053.820	        +0.003
# poa_MyBasicNeighbor_3.0_128.npy         	        +0.008	    +24859.016	        +0.011
# poa_MyBasicNeighbor_3.0_256.npy         	        +0.004	    +83661.891	        +0.006
# poa_MyBasicNeighbor_3.0_32.npy          	        +0.010	    +10126.344	        +0.013
# poa_MyBasicNeighbor_3.0_64.npy          	        +0.007	     +3654.594	        +0.008
# poa_MyBasicNeighbor_5.0_128.npy         	        +0.003	     +1809.641	        +0.004
# poa_MyBasicNeighbor_5.0_256.npy         	        +0.001	        +0.000	        +0.001
# poa_MyBasicNeighbor_5.0_32.npy          	        +0.010	     +4367.109	        +0.010
# poa_MyBasicNeighbor_5.0_64.npy          	        +0.011	     +6026.203	        +0.010
# poa_MyBasicNeighbor_999.0_128.npy       	        +0.006	     +3714.977	        +0.009
# poa_MyBasicNeighbor_999.0_256.npy       	        +0.004	     +2018.148	        +0.005
# poa_MyBasicNeighbor_999.0_32.npy        	        +0.014	     +7456.055	        +0.014
# poa_MyBasicNeighbor_999.0_64.npy        	        +0.011	     +6271.781	        +0.011
# poa_MyBasic_0.1_128.npy                 	        +0.001	      +285.953	        +0.003
# poa_MyBasic_0.1_256.npy                 	        +0.003	     +1573.578	        +0.005
# poa_MyBasic_0.1_32.npy                  	        +0.006	     +3972.625	        +0.009
# poa_MyBasic_0.1_64.npy                  	        +0.007	     +3730.203	        +0.007
# poa_MyBasic_0.2_128.npy                 	        +0.005	     +3101.289	        +0.006
# poa_MyBasic_0.2_256.npy                 	        +0.004	     +1764.469	        +0.005
# poa_MyBasic_0.2_32.npy                  	        +0.006	     +3974.328	        +0.010
# poa_MyBasic_0.2_64.npy                  	        +0.007	     +3112.664	        +0.009
# poa_MyBasic_0.3_128.npy                 	        +0.004	     +2121.125	        +0.007
# poa_MyBasic_0.3_256.npy                 	        +0.003	     +1709.984	        +0.005
# poa_MyBasic_0.3_32.npy                  	        +0.007	     +4642.188	        +0.011
# poa_MyBasic_0.3_64.npy                  	        +0.006	     +2489.414	        +0.009
# poa_MyBasic_0.5_128.npy                 	        +0.006	     +3193.219	        +0.007
# poa_MyBasic_0.5_256.npy                 	        +0.001	      +489.562	        +0.001
# poa_MyBasic_0.5_32.npy                  	        +0.007	     +4737.172	        +0.008
# poa_MyBasic_0.5_64.npy                  	        +0.006	     +2940.008	        +0.009
# poa_MyBasic_1.0_128.npy                 	        +0.002	      +980.312	        +0.005
# poa_MyBasic_1.0_256.npy                 	        +0.005	     +2726.219	        +0.006
# poa_MyBasic_1.0_32.npy                  	        +0.009	     +5243.586	        +0.010
# poa_MyBasic_1.0_64.npy                  	        +0.004	     +1997.758	        +0.006
# poa_MyBasic_1.5_128.npy                 	        +0.004	     +2393.008	        +0.007
# poa_MyBasic_1.5_256.npy                 	        +0.003	     +1907.742	        +0.003
# poa_MyBasic_1.5_32.npy                  	        +0.006	     +3643.602	        +0.009
# poa_MyBasic_1.5_64.npy                  	        +0.006	     +3405.727	        +0.009
# poa_MyBasic_3.0_128.npy                 	        +0.003	     +1474.180	        +0.006
# poa_MyBasic_3.0_256.npy                 	        +0.006	     +3867.828	        +0.007
# poa_MyBasic_3.0_32.npy                  	        +0.007	     +4047.383	        +0.010
# poa_MyBasic_3.0_64.npy                  	        +0.002	     +1287.602	        +0.004
# poa_MyBasic_5.0_128.npy                 	        +0.002	      +911.211	        +0.004
# poa_MyBasic_5.0_256.npy                 	        +0.004	     +1816.156	        +0.005
# poa_MyBasic_5.0_32.npy                  	        +0.003	     +2285.078	        +0.005
# poa_MyBasic_5.0_64.npy                  	        +0.006	     +3020.711	        +0.011
# poa_MyBasic_999.0_128.npy               	        +0.003	     +1636.742	        +0.004
# poa_MyBasic_999.0_256.npy               	        +0.004	     +2024.945	        +0.004
# poa_MyBasic_999.0_32.npy                	        +0.008	     +3685.695	        +0.007
# poa_MyBasic_999.0_64.npy                	        +0.006	     +2703.531	        +0.007
# poa_MyNeighborMean_0.1_128.npy          	        +0.011	     +5846.570	        +0.012
# poa_MyNeighborMean_0.1_256.npy          	        +0.007	     +4382.844	        +0.010
# poa_MyNeighborMean_0.1_32.npy           	        +0.016	     +9348.906	        +0.019
# poa_MyNeighborMean_0.1_64.npy           	        +0.013	     +6680.547	        +0.017
# poa_MyNeighborMean_0.2_128.npy          	        +0.011	     +6985.805	        +0.015
# poa_MyNeighborMean_0.2_256.npy          	        +0.005	     +4431.125	        +0.009
# poa_MyNeighborMean_0.2_32.npy           	        +0.017	    +10078.109	        +0.019
# poa_MyNeighborMean_0.2_64.npy           	        +0.011	     +7749.398	        +0.012
# poa_MyNeighborMean_0.3_128.npy          	        +0.009	     +4639.867	        +0.012
# poa_MyNeighborMean_0.3_256.npy          	        +0.008	     +4774.039	        +0.010
# poa_MyNeighborMean_0.3_32.npy           	        +0.013	     +7442.711	        +0.013
# poa_MyNeighborMean_0.3_64.npy           	        +0.011	     +6544.711	        +0.013
# poa_MyNeighborMean_0.5_128.npy          	        +0.009	     +4494.812	        +0.010
# poa_MyNeighborMean_0.5_256.npy          	        +0.009	     +4847.391	        +0.011
# poa_MyNeighborMean_0.5_32.npy           	        +0.016	     +8545.055	        +0.020
# poa_MyNeighborMean_0.5_64.npy           	        +0.018	    +10026.812	        +0.020
# poa_MyNeighborMean_1.0_128.npy          	        +0.008	     +4465.672	        +0.009
# poa_MyNeighborMean_1.0_256.npy          	        +0.006	     +3127.617	        +0.010
# poa_MyNeighborMean_1.0_32.npy           	        +0.018	     +9883.438	        +0.020
# poa_MyNeighborMean_1.0_64.npy           	        +0.009	     +4407.242	        +0.010
# poa_MyNeighborMean_1.5_128.npy          	        +0.008	     +4588.062	        +0.007
# poa_MyNeighborMean_1.5_256.npy          	        +0.008	     +3642.383	        +0.010
# poa_MyNeighborMean_1.5_32.npy           	        +0.017	     +9253.836	        +0.019
# poa_MyNeighborMean_1.5_64.npy           	        +0.010	     +5790.359	        +0.012
# poa_MyNeighborMean_3.0_128.npy          	        +0.010	     +5801.875	        +0.013
# poa_MyNeighborMean_3.0_256.npy          	        +0.005	     +2732.375	        +0.008
# poa_MyNeighborMean_3.0_32.npy           	        +0.017	     +9400.969	        +0.022
# poa_MyNeighborMean_3.0_64.npy           	        +0.014	     +6991.812	        +0.019
# poa_MyNeighborMean_5.0_128.npy          	        +0.008	     +4146.938	        +0.009
# poa_MyNeighborMean_5.0_256.npy          	        +0.009	     +4797.117	        +0.010
# poa_MyNeighborMean_5.0_32.npy           	        +0.020	    +10151.094	        +0.022
# poa_MyNeighborMean_5.0_64.npy           	        +0.017	     +9554.703	        +0.020
# poa_MyNeighborMean_999.0_128.npy        	        +0.016	     +8887.961	        +0.016
# poa_MyNeighborMean_999.0_256.npy        	        +0.005	     +2808.211	        +0.006
# poa_MyNeighborMean_999.0_32.npy         	        +0.018	     +9654.688	        +0.020
# poa_MyNeighborMean_999.0_64.npy         	        +0.012	     +5788.305	        +0.013
#
# prediction/sp best                      	         0.162	    176243.938	         0.126
# sp_MyBasicNeighbor_0.1_128.npy          	        +0.003	     +3277.047	        +0.004
# sp_MyBasicNeighbor_0.1_256.npy          	        +0.006	     +5516.625	        +0.006
# sp_MyBasicNeighbor_0.1_32.npy           	        +0.013	    +11554.000	        +0.013
# sp_MyBasicNeighbor_0.1_64.npy           	        +0.008	     +6557.531	        +0.009
# sp_MyBasicNeighbor_0.2_128.npy          	        +0.007	     +6245.812	        +0.007
# sp_MyBasicNeighbor_0.2_256.npy          	        +0.003	     +2052.562	        +0.003
# sp_MyBasicNeighbor_0.2_32.npy           	        +0.006	     +5222.297	        +0.006
# sp_MyBasicNeighbor_0.2_64.npy           	        +0.008	     +6789.172	        +0.008
# sp_MyBasicNeighbor_0.3_128.npy          	        +0.004	     +2888.359	        +0.003
# sp_MyBasicNeighbor_0.3_256.npy          	        +0.002	     +2353.766	        +0.003
# sp_MyBasicNeighbor_0.3_32.npy           	        +0.012	    +10571.969	        +0.012
# sp_MyBasicNeighbor_0.3_64.npy           	        +0.002	     +2203.750	        +0.003
# sp_MyBasicNeighbor_0.5_128.npy          	        +0.001	     +1403.828	        +0.002
# sp_MyBasicNeighbor_0.5_256.npy          	        +0.001	     +1631.906	        +0.003
# sp_MyBasicNeighbor_0.5_32.npy           	        +0.008	     +6208.828	        +0.008
# sp_MyBasicNeighbor_0.5_64.npy           	        +0.004	     +3499.172	        +0.005
# sp_MyBasicNeighbor_1.0_128.npy          	        +0.002	     +1923.141	        +0.003
# sp_MyBasicNeighbor_1.0_256.npy          	        +0.002	     +2308.453	        +0.003
# sp_MyBasicNeighbor_1.0_32.npy           	        +0.007	     +4846.984	        +0.009
# sp_MyBasicNeighbor_1.0_64.npy           	        +0.004	     +3466.984	        +0.006
# sp_MyBasicNeighbor_1.5_128.npy          	        +0.003	     +2927.359	        +0.004
# sp_MyBasicNeighbor_1.5_256.npy          	        +0.004	     +2501.875	        +0.004
# sp_MyBasicNeighbor_1.5_32.npy           	        +0.007	     +5111.406	        +0.007
# sp_MyBasicNeighbor_1.5_64.npy           	        +0.006	     +5044.062	        +0.006
# sp_MyBasicNeighbor_3.0_128.npy          	        +0.002	     +1795.422	        +0.003
# sp_MyBasicNeighbor_3.0_256.npy          	        +0.002	     +2007.984	        +0.002
# sp_MyBasicNeighbor_3.0_32.npy           	        +0.014	     +9638.359	        +0.013
# sp_MyBasicNeighbor_3.0_64.npy           	        +0.003	     +2284.297	        +0.004
# sp_MyBasicNeighbor_5.0_128.npy          	        +0.002	     +1915.781	        +0.002
# sp_MyBasicNeighbor_5.0_256.npy          	        +0.000	      +328.734	        +0.000
# sp_MyBasicNeighbor_5.0_32.npy           	        +0.009	     +6431.625	        +0.010
# sp_MyBasicNeighbor_5.0_64.npy           	        +0.003	     +2780.328	        +0.005
# sp_MyBasicNeighbor_999.0_128.npy        	        +0.001	     +1042.375	        +0.001
# sp_MyBasicNeighbor_999.0_256.npy        	        +0.002	     +1760.844	        +0.003
# sp_MyBasicNeighbor_999.0_32.npy         	        +0.010	     +6970.875	        +0.011
# sp_MyBasicNeighbor_999.0_64.npy         	        +0.006	     +4305.844	        +0.007
# sp_MyBasic_0.1_128.npy                  	        +0.002	     +2097.969	        +0.002
# sp_MyBasic_0.1_256.npy                  	        +0.001	      +847.484	        +0.001
# sp_MyBasic_0.1_32.npy                   	        +0.006	     +4407.984	        +0.007
# sp_MyBasic_0.1_64.npy                   	        +0.002	     +1471.328	        +0.001
# sp_MyBasic_0.2_128.npy                  	        +0.002	     +1480.656	        +0.004
# sp_MyBasic_0.2_256.npy                  	        +0.003	     +2301.328	        +0.004
# sp_MyBasic_0.2_32.npy                   	        +0.007	     +4719.781	        +0.008
# sp_MyBasic_0.2_64.npy                   	        +0.005	     +3249.844	        +0.005
# sp_MyBasic_0.3_128.npy                  	        +0.002	     +2046.328	        +0.003
# sp_MyBasic_0.3_256.npy                  	        +0.002	     +1422.797	        +0.002
# sp_MyBasic_0.3_32.npy                   	        +0.008	     +5790.453	        +0.009
# sp_MyBasic_0.3_64.npy                   	        +0.007	     +5653.734	        +0.008
# sp_MyBasic_0.5_128.npy                  	        +0.001	     +1016.750	        +0.001
# sp_MyBasic_0.5_256.npy                  	        +0.002	     +2050.594	        +0.004
# sp_MyBasic_0.5_32.npy                   	        +0.007	     +5332.844	        +0.009
# sp_MyBasic_0.5_64.npy                   	        +0.004	     +2746.891	        +0.004
# sp_MyBasic_1.0_128.npy                  	        +0.000	      +205.172	        +0.000
# sp_MyBasic_1.0_256.npy                  	        +0.002	     +1851.344	        +0.004
# sp_MyBasic_1.0_32.npy                   	        +0.005	     +4150.312	        +0.007
# sp_MyBasic_1.0_64.npy                   	        +0.003	     +3235.406	        +0.004
# sp_MyBasic_1.5_128.npy                  	        +0.002	     +1942.156	        +0.002
# sp_MyBasic_1.5_256.npy                  	        +0.001	     +1112.391	        +0.001
# sp_MyBasic_1.5_32.npy                   	        +0.007	     +4534.547	        +0.007
# sp_MyBasic_1.5_64.npy                   	        +0.005	     +4026.062	        +0.005
# sp_MyBasic_3.0_128.npy                  	        +0.001	      +837.734	        +0.003
# sp_MyBasic_3.0_256.npy                  	        +0.001	        +0.000	        +0.001
# sp_MyBasic_3.0_32.npy                   	        +0.006	     +4511.844	        +0.007
# sp_MyBasic_3.0_64.npy                   	        +0.005	     +3887.844	        +0.006
# sp_MyBasic_5.0_128.npy                  	        +0.002	     +1368.266	        +0.002
# sp_MyBasic_5.0_256.npy                  	        +0.003	     +2433.859	        +0.004
# sp_MyBasic_5.0_32.npy                   	        +0.007	     +4505.094	        +0.008
# sp_MyBasic_5.0_64.npy                   	        +0.003	     +2275.875	        +0.005
# sp_MyBasic_999.0_128.npy                	        +0.003	     +2160.609	        +0.004
# sp_MyBasic_999.0_256.npy                	        +0.001	     +1013.922	        +0.002
# sp_MyBasic_999.0_32.npy                 	        +0.005	     +3646.641	        +0.006
# sp_MyBasic_999.0_64.npy                 	        +0.004	     +2783.344	        +0.005
# sp_MyNeighborMean_0.1_128.npy           	        +0.005	     +4446.141	        +0.006
# sp_MyNeighborMean_0.1_256.npy           	        +0.004	     +2833.969	        +0.004
# sp_MyNeighborMean_0.1_32.npy            	        +0.016	    +12592.891	        +0.015
# sp_MyNeighborMean_0.1_64.npy            	        +0.013	    +10838.156	        +0.014
# sp_MyNeighborMean_0.2_128.npy           	        +0.004	     +2944.062	        +0.004
# sp_MyNeighborMean_0.2_256.npy           	        +0.004	     +3747.469	        +0.005
# sp_MyNeighborMean_0.2_32.npy            	        +0.022	    +20283.469	        +0.022
# sp_MyNeighborMean_0.2_64.npy            	        +0.004	     +3190.047	        +0.005
# sp_MyNeighborMean_0.3_128.npy           	        +0.004	     +3562.766	        +0.004
# sp_MyNeighborMean_0.3_256.npy           	        +0.005	     +4870.734	        +0.005
# sp_MyNeighborMean_0.3_32.npy            	        +0.011	     +9615.031	        +0.010
# sp_MyNeighborMean_0.3_64.npy            	        +0.011	     +9698.219	        +0.010
# sp_MyNeighborMean_0.5_128.npy           	        +0.003	     +1860.141	        +0.002
# sp_MyNeighborMean_0.5_256.npy           	        +0.003	     +2034.188	        +0.003
# sp_MyNeighborMean_0.5_32.npy            	        +0.014	    +11141.109	        +0.013
# sp_MyNeighborMean_0.5_64.npy            	        +0.012	     +8825.766	        +0.011
# sp_MyNeighborMean_1.0_128.npy           	        +0.002	     +1533.922	        +0.003
# sp_MyNeighborMean_1.0_256.npy           	        +0.002	     +1641.891	        +0.003
# sp_MyNeighborMean_1.0_32.npy            	        +0.010	     +7514.812	        +0.011
# sp_MyNeighborMean_1.0_64.npy            	        +0.011	     +8570.734	        +0.012
# sp_MyNeighborMean_1.5_128.npy           	        +0.001	     +1116.859	        +0.002
# sp_MyNeighborMean_1.5_256.npy           	        +0.005	     +3729.172	        +0.006
# sp_MyNeighborMean_1.5_32.npy            	        +0.010	     +6851.469	        +0.010
# sp_MyNeighborMean_1.5_64.npy            	        +0.009	     +5996.391	        +0.010
# sp_MyNeighborMean_3.0_128.npy           	        +0.002	     +2275.109	        +0.003
# sp_MyNeighborMean_3.0_256.npy           	        +0.002	     +1796.891	        +0.003
# sp_MyNeighborMean_3.0_32.npy            	        +0.018	    +14207.047	        +0.017
# sp_MyNeighborMean_3.0_64.npy            	        +0.006	     +4352.172	        +0.006
# sp_MyNeighborMean_5.0_128.npy           	        +0.007	     +5887.703	        +0.006
# sp_MyNeighborMean_5.0_256.npy           	        +0.002	     +1650.672	        +0.003
# sp_MyNeighborMean_5.0_32.npy            	        +0.014	    +11436.438	        +0.013
# sp_MyNeighborMean_5.0_64.npy            	        +0.016	    +12565.250	        +0.014
# sp_MyNeighborMean_999.0_128.npy         	        +0.004	     +3895.500	        +0.004
# sp_MyNeighborMean_999.0_256.npy         	        +0.001	      +536.250	        +0.001
# sp_MyNeighborMean_999.0_32.npy          	        +0.020	    +17553.344	        +0.019
# sp_MyNeighborMean_999.0_64.npy          	        +0.005	     +4395.078	        +0.006

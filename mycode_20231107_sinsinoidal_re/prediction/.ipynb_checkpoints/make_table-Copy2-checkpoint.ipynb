# %%
import numpy as np

# %%
import os

# %%
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = np.not_equal(label, 0)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        rmse = np.square(mae)
        mape = np.divide(mae, label)
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape) # np.mean(mape) -- author leverages median
    return male, rmse, mape*100

# %%
datasets = ['fc', 'kc', 'sp', 'poa']

# %%
os.listdir('fc')
# Out:
# ['fc_MyBasicNei_64_0.05_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.03_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.01_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_10.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.03_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_3.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_3.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_20.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.5_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_3.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_3.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.5_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_1.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_20.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_10.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.03_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_1.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.02_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.03_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.01_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_3.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_2.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_20.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_1.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_5.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_20.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_10.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.02_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_20.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_False_poi_False.npy',
#  'fc_MyBasicNei_64_0.02_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.01_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_10.0_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_3.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.01_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'ground_truth.npy',
#  'fc_MyBasicNei_64_0.05_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_3.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_10.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.5_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_2.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_1.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_10.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_10.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.5_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_1.0_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_20.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_1.0_0.05_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_10.0_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_5.0_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.02_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.2_2.0_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.3_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_20.0_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.2_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_20.0_0.05_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.02_loc_False_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.02_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_3.0_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.5_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.05_2.0_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.2_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.02_0.02_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.03_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.3_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.01_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.1_0.2_loc_Sinsinoidal_poi_False.npy',
#  'fc_MyBasicNei_64_0.1_0.05_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.02_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_0.02_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.02_0.2_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_2.0_loc_True_poi_True.npy',
#  'fc_MyBasicNei_64_0.03_2.0_loc_Sinsinoidal_poi_True.npy',
#  'fc_MyBasicNei_64_0.05_0.05_loc_True_poi_False.npy',
#  'fc_MyBasicNei_64_0.2_0.05_loc_Sinsinoidal_poi_False.npy']

# %%
dname = datasets[0]

# %%
result_dict = dict()
asi_dict = {
    'fc': (0.098, 23177, 6.49),
    'kc': (0.113, 115763, 8.00),
    'sp': (0.135, 155585, 9.80),
    'poa': (0.143, 94492, 9.58)
}






for dname in datasets:
    print(dname, 'sigma', 'sigma2', 'latlon', 'poi', 'male', 'rmse', 'mape', sep='\t')
    gt = np.load(f'{dname}/ground_truth.npy')
    
    min_result = (np.inf, np.inf, np.inf)
    min_cond = 'none'
    for use_latlon in ['False', 'True', 'Sinsinoidal']:
        for use_poiprox in ['False', 'True']:
            for sigma in [0.01, 0.02, 0.03, 0.05,
                           0.1,  0.2,  0.3,  0.5,  
                           1, 2, 3, 5, 10, 20]:
                for sigma2 in [0.02, 0.05, 0.2, 2]:
                    fname = f'{dname}/{dname}_MyBasicNei_64_{sigma}_{sigma2}_loc_{use_latlon}_poi_{use_poiprox}.npy'
                    if os.path.isfile(fname):
                        pred = np.load(fname)
                        res = metric(np.exp(gt), np.exp(pred))
                        result_dict[(dname, sigma, sigma2, use_latlon[:5], use_poiprox)] = res

                        if min_result[2] > res[2]:
                            min_result = res
                            min_cond = (dname, sigma, sigma2, use_latlon[:5], use_poiprox)
                        
                    else:
                        res = (np.inf, np.inf, np.inf)
                        result_dict[(dname, sigma, sigma2, use_latlon[:5], use_poiprox)] = (np.inf, np.inf, np.inf)
                        
                        
                
                    #print(dname, sigma, sigma2, use_latlon, use_poiprox, '%.3f\t%.0f\t%.2f'%(res), sep='\t')
    print('---best---')
    print(dname, min_cond[1], min_cond[2], min_cond[3], min_cond[4], '%.3f\t%.0f\t%.2f'%(min_result), sep='\t')
    print('---best---')
    
    print(dname, min_cond[1], min_cond[2], 'False', False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'False', 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], 'False', True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'False', 'True')]), sep='\t')
    
    
    print(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'Sinsinoidal'[:5], 'True')]), sep='\t')
    
    
    print(dname, min_cond[1], min_cond[2], True, False, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'False')]), sep='\t')
    print(dname, min_cond[1], min_cond[2], True, True, '%.3f\t%.0f\t%.2f'%(result_dict[(dname, min_cond[1], min_cond[2], 'True', 'True')]), sep='\t')
    print(dname, 'asidict', '', '', '', '%.3f\t%.0f\t%.2f'%(asi_dict[(dname)]), sep='\t')
    print()
# Out:
# fc	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# fc	0.1	0.02	Sinsi	True	0.096	22986	6.07
# ---best---
# fc	0.1	0.02	False	False	0.097	23194	6.14
# fc	0.1	0.02	False	True	0.096	23010	6.08
# fc	0.1	0.02	Sinsi	False	0.096	23036	6.11
# fc	0.1	0.02	Sinsi	True	0.096	22986	6.07
# fc	0.1	0.02	True	False	0.096	23110	6.09
# fc	0.1	0.02	True	True	0.096	23195	6.12
# fc	asidict				0.098	23177	6.49
#
# kc	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# kc	0.3	0.05	Sinsi	False	0.112	117505	7.70
# ---best---
# kc	0.3	0.05	False	False	inf	inf	inf
# kc	0.3	0.05	False	True	inf	inf	inf
# kc	0.3	0.05	Sinsi	False	0.112	117505	7.70
# kc	0.3	0.05	Sinsi	True	0.112	110752	7.84
# kc	0.3	0.05	True	False	0.112	116427	7.83
# kc	0.3	0.05	True	True	0.112	113302	7.85
# kc	asidict				0.113	115763	8.00
#
# sp	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# sp	0.01	0.05	True	True	0.136	157154	9.61
# ---best---
# sp	0.01	0.05	False	False	0.136	157129	9.82
# sp	0.01	0.05	False	True	0.137	157235	9.85
# sp	0.01	0.05	Sinsi	False	0.137	156903	9.85
# sp	0.01	0.05	Sinsi	True	0.135	155406	9.69
# sp	0.01	0.05	True	False	0.137	156918	9.84
# sp	0.01	0.05	True	True	0.136	157154	9.61
# sp	asidict				0.135	155585	9.80
#
# poa	sigma	sigma2	latlon	poi	male	rmse	mape
# ---best---
# poa	0.02	0.05	Sinsi	True	0.141	93783	9.41
# ---best---
# poa	0.02	0.05	False	False	inf	inf	inf
# poa	0.02	0.05	False	True	inf	inf	inf
# poa	0.02	0.05	Sinsi	False	0.142	93946	9.66
# poa	0.02	0.05	Sinsi	True	0.141	93783	9.41
# poa	0.02	0.05	True	False	0.143	94333	9.80
# poa	0.02	0.05	True	True	0.143	94281	9.72
# poa	asidict				0.143	94492	9.58

# %%
import pandas as pd

# %%
# for dname in datasets:
#     print(dname, '--', 'L-', '-P', 'LP', sep='\t')
#     for sigma in [0.02, 0.05, 0.1, 0.5, 1.0, 5.0, 10.0, 20.0]:
#         sigma2 = 0.0
#         if dname == 'fc':
#             sigma2 = 0.1
#         if dname == 'kc':
#             sigma2 = 0.5
#         if dname == 'sp':
#             sigma2 = 0.02
#         if dname == 'poa':
#             sigma2 = 0.02
            
#         line = []
#         for use_poiprox in ['False', 'True']:
#             for use_latlon in ['False', 'True']:
#                 line.append(str('%.2f'%result_dict[(dname, sigma, sigma2, use_latlon, use_poiprox)][2]))
#         print(f'{sigma}\t' + '\t'.join(line))
    
#     print()

# %%
df_dict = {}
for dname in datasets:
#    print(dname, '--', 'L-', '-P', 'LP', sep='\t')
    gt = np.load(f'{dname}/ground_truth.npy')
    rows = []
    for sigma in [0.01, 0.02, 0.03, 0.05,
                   0.1,  0.2,  0.3,  0.5,  
                   1, 2, 3, 5, 10, 20]:
        sigma2 = -1
        if dname == 'fc':
            sigma2 = 0.02
        if dname == 'kc':
            sigma2 = 0.2
        if dname == 'sp':
            sigma2 = 0.2
        if dname == 'poa':
            sigma2 = 0.05
        
        line = []
        for use_poiprox in ['False', 'True']:
            for use_latlon in ['False', 'True']:
                fname = f'{dname}/{dname}_MyBasicNei_64_{sigma}_{sigma2}_loc_{use_latlon}_poi_{use_poiprox}.npy'
                if os.path.isfile(fname):
                    pred = np.load(fname)
                    res = metric(np.exp(gt), np.exp(pred))
                    #result_dict[(dname, sigma, use_latlon, use_poiprox)] = res

                    #line.append(float('%.2f'%result_dict[(dname, sigma, use_latlon, use_poiprox)][2]))
                    line.append(float('%.2f'%res[1]))
                else:
                    line.append(float('nan'))

        rows.append([sigma] + line)
    df = pd.DataFrame(rows, columns = ['sigma', '--', 'L-', '-P', 'LP'])
    df = df.set_index('sigma')
    df_dict[dname] = df
    
    print()

# %%
import seaborn as sns

# %%
df_dict['poa']
# Out:
#               --         L-         -P         LP
# sigma
# 0.01    94113.32   94663.46   94719.72   94660.37
# 0.02    93812.31   94268.32   94319.73   93997.14
# 0.03    94305.98   95182.62   93069.03   95230.34
# 0.05    95290.56   96208.38   95433.59   95966.47
# 0.10    99785.62   98809.09   99059.26   98216.53
# 0.20   100004.47  100874.27  100519.50  100850.23
# 0.30   103304.79  103093.04  103314.09  103376.18
# 0.50   104124.24  104092.60  104371.30  103683.58
# 1.00         NaN        NaN        NaN        NaN
# 2.00         NaN        NaN        NaN        NaN
# 3.00         NaN        NaN        NaN        NaN
# 5.00         NaN        NaN        NaN        NaN
# 10.00        NaN        NaN        NaN        NaN
# 20.00        NaN        NaN        NaN        NaN

# %%
for dname in datasets:
    fig, ax = plt.subplots(figsize=(4, 3))
    df_dict[dname][['--', 'L-', '-P', 'LP']].plot(ax=ax, marker='.')
    plt.xscale('log')
    
    plt.ylabel('RMSE')
    plt.title(dname)

    # Show the figure
    #plt.show()

    # Set a higher DPI value (e.g., 300)
    fig.set_dpi(300)

    # Save the figure with high resolution
    fig.savefig(f'ablation_{dname}.png', dpi=300,bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Create the figure and axes
# fig, axs = plt.subplots(len(datasets), len(models), figsize=(12, 9), sharex=True, sharey=True)

# # Iterate over datasets and models
# for i, dataset in enumerate(datasets):
#     ground_truth = np.load(f'./{dataset}/ground_truth.npy')
#     for j, model in enumerate(models):
#         # Generate random data for each ablation setting
#         ablations_style = []
#         if model == 'MyUAGCRN' or model == 'MyUAGCTransformer':
#             ablations = []
#             ablations_name = []
#             ablations_style = []
#             for g, a, s in reversed([('legacy', 'none', 'none'),
#                             ('cooccur_dist', 'none', 'none'),
#                             ('legacy', 'AE', 'SE'),
#                             ('cooccur_dist', 'AE', 'SE')]):
#                 ablations.append((g, a, s))

#                 aname = []
#                 if g == 'legacy':
#                     aname.append('legacy')
#                     astyle = '--'
#                 else:
#                     aname.append('ourgraph')
#                     astyle = '-'

#                 acolor = 'gray'
#                 if a == 'AE':
#                     aname.append('AE')
#                     acolor = 'red'
#                 if s == 'SE':
#                     aname.append('SE')
#                     acolor = 'green'
#                 if a == 'AE' and s == 'SE':
#                     acolor = 'blue'

#                 aname = '+'.join(aname)
#                 if len(aname) == 0:
#                     aname = 'none'
#                 ablations_name.append(aname)
#                 ablations_style.append((acolor, astyle))

#         elif model == 'MyARLSTM' or model == 'MyTransformer':
#             ablations = []
#             ablations_name = []
#             ablations_style = []
#             for a in ['AE', 'none']:
#                 for s in ['SE', 'none']:
#                     ablations.append(('none', a, s))

#                     aname = []
#                     astyle = '-'
#                     acolor = 'gray'
#                     if a == 'AE':
#                         aname.append('AE')
#                         acolor = 'red'
#                     if s == 'SE':
#                         aname.append('SE')
#                         acolor = 'green'
#                     if a == 'AE' and s == 'SE':
#                         acolor = 'blue'

#                     aname = '+'.join(aname)
#                     if len(aname) == 0:
#                         aname = 'none'
#                     ablations_name.append(aname)
#                     ablations_style.append((acolor, astyle))
#         else:
#             ablations = []
#             ablations_name = []

#         if dataset != 'pemsd7':
#             maxQ = 12
#         else:
#             maxQ = 9

# #         x = np.arange(1, maxQ + 1)
#         x = np.arange(1, 3 + 1)
#         y = []
#         for g, a, s in ablations:
#             fname = f'./{dataset}/{dataset}_{model}_G-{g}_AE-{a}_SE-{s}.npy'

#             try:
#                 if fname in fname2eval:
#                     evals = fname2eval[fname]
#                 else:
#                     prediction = np.load(fname)
#                     evals = []
#                     for Q in range(maxQ):
#                         vvv = metric(ground_truth[:, Q, ...], prediction[:, Q, ...])
#                         evals.append(vvv[1])
                    
#                     fname2eval[fname] = evals
#             except:
#                 print('not exist:', fname)
#                 pass
            
#             if maxQ == 12:
#                 y.append([evals[2], evals[5], evals[11]])
#             elif maxQ == 9:
#                 y.append([evals[2], evals[5], evals[ 8]])
                
# #         print(y)

#         # Plot the data
#         ax = axs[i, j]
#         bar_width = 0.15
#         opacity = 0.8
#         colors = ['blue', 'red', 'green', 'orange', 'purple']

#         ax.bar(x, dcrnn_metric[dataset], bar_width, alpha=opacity, color='black', label='DCRNN')
#         for k in range(len(ablations)):
#             ax.bar(x + ((k+1) * bar_width), y[k], bar_width, alpha=opacity, color=colors[k], label=ablations_name[k])

#         ax.set(xticks=list(range(1, 3+1)), ylim=(2, 10))
#         ax.set_title(model2title[model])
#         ax.legend( loc='upper left')
# #         ax.legend()

#         fig.tight_layout()

# # Add a common x-axis label and a legend
# # fig.text(0.5, 0.04, 'Q', ha='center', fontsize=14)
# # fig.legend(bbox_to_anchor=(0.5, -0.1), loc='lower center', ncol=len(ablations))

# # Set the overall title
# # fig.suptitle('Evaluation Results', fontsize=16)

# # Show the figure
# plt.show()

# # Set a higher DPI value (e.g., 300)
# fig.set_dpi(300)

# # Save the figure with high resolution
# fig.savefig('figure_high_resolution.png', dpi=300)

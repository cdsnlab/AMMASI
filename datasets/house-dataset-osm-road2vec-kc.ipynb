# %%
import os, tqdm

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = (label == label) & (pred == pred)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        
        rmse = np.square(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        
        mape = np.divide(mae, label)
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape*mask)
        
        print('masked:', np.sum(mask == 0))
    return male, rmse, mape

# %%
os.listdir('.')
# Out:
# ['house-dataset-osm-road2vec-poa.ipynb',
#  'house-dataset-visualization.html',
#  'house-dataset-visualization.ipynb',
#  '.ipynb_checkpoints',
#  'house-lgbm.ipynb',
#  'generateSE.py',
#  'sp',
#  'house-dataset-visualization-Copy1.ipynb',
#  'house-dataset-osm-road2vec-dbscan.ipynb',
#  'node2vec.py',
#  '.gitkeep ',
#  'poa',
#  'house-dataset-osm-road2vec-Copy2.ipynb',
#  'fc',
#  'kc',
#  'house-dataset-osm-road2vec-kc.ipynb',
#  'house_reverse_geocoding.py',
#  '__pycache__',
#  'house-lgbm-sonia.ipynb',
#  'house-dataset-osm-road2vec-Copy1.ipynb',
#  'house-dataset-osm-road2vec-sp.ipynb',
#  'osmdata',
#  'house-dataset-osm-road2vec.ipynb',
#  'house-dataset-osm-buildings.ipynb',
#  'house-dataset-osm-buildings-Copy1.ipynb',
#  'cache']

# %%
datasets = ['kc']

# %%
import numpy as np

# %%
streetmap = {
    'style': 'mapbox://styles/mapbox/streets-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}
mybasemap = {
    #'style': 'mapbox://styles/mapbox/streets-v9',
    'style': 'mapbox://styles/mapbox/satellite-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}

# %%
from cartoframes.viz import *
# Out:
# Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
for dname in ['kc']:#['kc', 'fc', 'sp', 'poa']:
    print(dname)
    data = np.load(f'{dname}/data.npz')
    
    dict1 = {'lat':data['X_train'][:,0], 'lng': data['X_train'][:,1], 'price': data['y_train']}
    dict2 = {'lat':data['X_test'][:,0], 'lng': data['X_test'][:,1], 'price': data['y_test']}
    attr_names = []
    for a in range(2, data['X_train'].shape[1]):
        dict1.update({f'attr{a-2}': data['X_train'][:, a]})
        dict2.update({f'attr{a-2}': data['X_test'][:, a]})
        attr_names.append(f'attr{a-2}')
    df1 = pd.DataFrame(dict1)
    df2 = pd.DataFrame(dict2)
    df = pd.concat([df1, df2])
    
    train_gdf = gpd.GeoDataFrame(df1.copy(), geometry=gpd.points_from_xy(x=df1.lng, y=df1.lat))
    train_gdf.crs = 'EPSG:4326'
    test_gdf = gpd.GeoDataFrame(df2.copy(), geometry=gpd.points_from_xy(x=df2.lng, y=df2.lat))
    test_gdf.crs = 'EPSG:4326'
    house_gdf = gpd.GeoDataFrame(df.copy(), geometry=gpd.points_from_xy(x=df.lng, y=df.lat))
    house_gdf.crs = 'EPSG:4326'
    #print(np.exp(df['price'].values).mean())
    gdf = house_gdf
    for attr in attr_names:
        print(attr, gdf[attr].nunique())
        if gdf[attr].nunique() < 30:
            gdf[attr] = gdf[attr].astype(str)
    gdfcpy = gdf.copy()
    
    
#     display(Map(
#         [
#             Layer(gdfcpy, color_category_style(tattr, cat=cat, palette='cb_blues'), encode_data=False),
#             Layer(gdf, color_continuous_style('price', palette='sunset'), encode_data=False),
#         ],
#         basemap=mybasemap))
    
    break
# Out:
# kc
# attr0 13
# attr1 30
# attr2 1038
# attr3 9782
# attr4 6
# attr5 2
# attr6 5
# attr7 5
# attr8 12
# attr9 946
# attr10 306
# attr11 116
# attr12 70
# attr13 70
# attr14 777
# attr15 8689

# %%
import osmnx as ox
from shapely.geometry import *

if not os.path.isdir('osmdata'):
    os.mkdir('osmdata')
    
DATASET_NAME = dname
OSM_FILE_PATH = f'osmdata/{DATASET_NAME}.graphml'

from shapely.geometry import MultiPoint


x1, y1, x2, y2 = gdf.total_bounds

house_center_latitude = (y1 + y2)/2 #sensor_hull.centroid.y
house_center_longitude = (x1 + x2)/2 #sensor_hull.centroid.x

     
graphs = dict()
# retrieve the street network for the location
if not os.path.isfile(OSM_FILE_PATH):
    center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
    center_point.crs = 'epsg:4326'
    center_point = center_point.to_crs('epsg:3310')
    max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
    print('max_distance:', max_distance)
    graph = ox.graph_from_point((house_center_latitude, house_center_longitude), dist=max_distance)

    # save the street network to a shapefile
    ox.save_graphml(graph, filepath=OSM_FILE_PATH)
else:
    graph = ox.load_graphml(filepath=OSM_FILE_PATH)
    

# buildings = buildings.reset_index()
# buildings.geometry = buildings.geometry.centroid

# %%
graph2 = ox.graph_from_place('vashon')
osm_nodes2, osm_edges2 = ox.graph_to_gdfs(graph2)

# %%
osm_nodes1, osm_edges1 = ox.graph_to_gdfs(graph)


osm_nodes = pd.concat((osm_nodes1, osm_nodes2))
osm_edges = pd.concat((osm_edges1, osm_edges2))


osm_nodes['osmidn'] = osm_nodes.index
osm_nodes['osmidstr'] = osm_nodes['osmidn'].astype(str)
osm_edges = osm_edges.reset_index()
cond = np.array([str(type(s)) for s in osm_edges['highway']]) == "<class 'str'>"
osm_edges = osm_edges[cond]

# %%
alist = osm_nodes.geometry.tolist()

# %%
np.random.shuffle(alist)

# %%
Layer(gpd.GeoDataFrame(geometry=alist[:100]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %%
center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
center_point.crs = 'epsg:4326'
center_point = center_point.to_crs('epsg:3310')
max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
buildings = ox.geometries.geometries_from_point((house_center_latitude, house_center_longitude), 
                                    tags = {'building': True},
                                    dist=max_distance)

# %%
rbuildings = buildings.reset_index()
fbuildings = buildings.reset_index()
fbuildings.geometry = fbuildings.geometry.centroid
fbuildings['nx'] = fbuildings.geometry.x
fbuildings['ny'] = fbuildings.geometry.y

fbuildings['barea'] = buildings.reset_index().to_crs('epsg:3310').area

corr_osmid = []
for _, htem in tqdm.tqdm(house_gdf.iterrows(), total=len(house_gdf)):
    ffbs = rbuildings[(fbuildings['nx'] > htem.lng - 0.002) & (fbuildings['nx'] < htem.lng + 0.002) & \
                        (fbuildings['ny'] > htem.lat - 0.002) & (fbuildings['ny'] < htem.lat + 0.002) & \
                         (fbuildings['barea'] > 70)]
    if len(ffbs) == 0:
        corr_osmid.append(-1)
    else:
        target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
        corr_osmid.append(target_bd['osmid'])

nhouse_gdf = house_gdf.copy()
nhouse_gdf['osmid'] = corr_osmid
# Out:
# /tmp/ipykernel_1319568/565877014.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   fbuildings.geometry = fbuildings.geometry.centroid
#   0%|                                                                                         | 0/21608 [00:00<?, ?it/s]/tmp/ipykernel_1319568/565877014.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
# 100%|████████████████████████████████████████████████████████████████████████████| 21608/21608 [03:13<00:00, 111.74it/s]

# %%
osmid2geo = {osmid:geo for osmid, geo in zip(rbuildings['osmid'], rbuildings['geometry'])}

geos = []
for i, osmid in enumerate(nhouse_gdf['osmid']):
    if osmid > 0:
        geos.append(osmid2geo[osmid])
    else:
        geos.append(house_gdf.iloc[i].geometry)

nhouse_gdf.geometry = geos
nhouse_gdf.geometry = nhouse_gdf.geometry.centroid
# Out:
# /tmp/ipykernel_1319568/2617699450.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nhouse_gdf.geometry = nhouse_gdf.geometry.centroid

# %% [markdown]
# # Next

# %%
import node2vec
import numpy as np
import networkx as nx
from gensim.models import Word2Vec

with open(f'{dname}/Adj.txt', 'w') as fp:
    for _, item in osm_edges.iterrows():
        fp.write(f'{item.u} {item.v} 1.0\n')
        
        
def read_graph(edgelist):
    G = nx.read_edgelist(
        edgelist, nodetype=str, data=(('weight',float),),
        create_using=nx.DiGraph())
    return G

Adj_file = f'{dname}/Adj.txt'
nx_G = read_graph(Adj_file)

num_walks = 10
walk_length = 20
p = 2
q = 1
is_directed = True

G = node2vec.Graph(nx_G, is_directed, p, q)
G.preprocess_transition_probs()
node2vec_walks = G.simulate_walks(num_walks, walk_length)
# Out:
# /disk1/jupyter/smhan/ASI/datasets/node2vec.py:120: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   J = np.zeros(K, dtype=np.int)
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10

# %%
from gensim.models import Word2Vec

vector_size = 32
sentences = node2vec_walks
model_node = Word2Vec(sentences, window=5, min_count=0, workers=4, vector_size=vector_size)

edge_discover_path_list = []
for path in node2vec_walks:# + discover_path_list:
    edge = []
    for u, v in zip(path[:-1], path[1:]):
        edge.append(f'{u}-{v}')
    edge_discover_path_list.append(edge)
sentences = edge_discover_path_list
model_edge = Word2Vec(sentences, window=5, min_count=1, workers=4, vector_size=vector_size)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 199927 words, keeping 103920 word types
# PROGRESS: at sentence #20000, processed 399759 words, keeping 191375 word types
# PROGRESS: at sentence #30000, processed 599642 words, keeping 263482 word types
# PROGRESS: at sentence #40000, processed 799607 words, keeping 325022 word types
# PROGRESS: at sentence #50000, processed 999502 words, keeping 376982 word types
# PROGRESS: at sentence #60000, processed 1199425 words, keeping 420893 word types
# PROGRESS: at sentence #70000, processed 1399233 words, keeping 457862 word types
# PROGRESS: at sentence #80000, processed 1599127 words, keeping 489272 word types
# PROGRESS: at sentence #90000, processed 1798952 words, keeping 515819 word types
# PROGRESS: at sentence #100000, processed 1998868 words, keeping 538531 word types
# PROGRESS: at sentence #110000, processed 2198744 words, keeping 557855 word types
# PROGRESS: at sentence #120000, processed 2398619 words, keeping 574366 word types
# PROGRESS: at sentence #130000, processed 2598486 words, keeping 588535 word types
# PROGRESS: at sentence #140000, processed 2798402 words, keeping 600877 word types
# PROGRESS: at sentence #150000, processed 2998307 words, keeping 611548 word types
# PROGRESS: at sentence #160000, processed 3198185 words, keeping 620727 word types
# PROGRESS: at sentence #170000, processed 3398103 words, keeping 628590 word types
# PROGRESS: at sentence #180000, processed 3598003 words, keeping 635710 word types
# PROGRESS: at sentence #190000, processed 3797894 words, keeping 641984 word types
# PROGRESS: at sentence #200000, processed 3997762 words, keeping 647279 word types
# PROGRESS: at sentence #210000, processed 4197680 words, keeping 651797 word types
# PROGRESS: at sentence #220000, processed 4397591 words, keeping 655902 word types
# PROGRESS: at sentence #230000, processed 4597402 words, keeping 659399 word types
# PROGRESS: at sentence #240000, processed 4797304 words, keeping 662593 word types
# PROGRESS: at sentence #250000, processed 4997145 words, keeping 665409 word types
# PROGRESS: at sentence #260000, processed 5197051 words, keeping 667743 word types
# PROGRESS: at sentence #270000, processed 5396880 words, keeping 669895 word types
# PROGRESS: at sentence #280000, processed 5596784 words, keeping 671849 word types
# PROGRESS: at sentence #290000, processed 5796627 words, keeping 673543 word types
# PROGRESS: at sentence #300000, processed 5996545 words, keeping 675021 word types
# PROGRESS: at sentence #310000, processed 6196408 words, keeping 676390 word types
# PROGRESS: at sentence #320000, processed 6396282 words, keeping 677615 word types
# PROGRESS: at sentence #330000, processed 6596156 words, keeping 678661 word types
# PROGRESS: at sentence #340000, processed 6796047 words, keeping 679565 word types
# PROGRESS: at sentence #350000, processed 6995933 words, keeping 680437 word types
# PROGRESS: at sentence #360000, processed 7195825 words, keeping 681218 word types
# PROGRESS: at sentence #370000, processed 7395697 words, keeping 681898 word types
# PROGRESS: at sentence #380000, processed 7595580 words, keeping 682489 word types
# PROGRESS: at sentence #390000, processed 7795538 words, keeping 683045 word types
# PROGRESS: at sentence #400000, processed 7995430 words, keeping 683475 word types
# PROGRESS: at sentence #410000, processed 8195344 words, keeping 683927 word types
# PROGRESS: at sentence #420000, processed 8395268 words, keeping 684346 word types
# PROGRESS: at sentence #430000, processed 8595219 words, keeping 684718 word types
# PROGRESS: at sentence #440000, processed 8795095 words, keeping 685052 word types
# PROGRESS: at sentence #450000, processed 8994960 words, keeping 685331 word types
# PROGRESS: at sentence #460000, processed 9194760 words, keeping 685560 word types
# PROGRESS: at sentence #470000, processed 9394654 words, keeping 685800 word types
# PROGRESS: at sentence #480000, processed 9594513 words, keeping 685998 word types
# PROGRESS: at sentence #490000, processed 9794387 words, keeping 686172 word types
# PROGRESS: at sentence #500000, processed 9994257 words, keeping 686321 word types
# PROGRESS: at sentence #510000, processed 10194201 words, keeping 686454 word types
# PROGRESS: at sentence #520000, processed 10394148 words, keeping 686558 word types
# PROGRESS: at sentence #530000, processed 10594081 words, keeping 686663 word types
# PROGRESS: at sentence #540000, processed 10793993 words, keeping 686779 word types
# PROGRESS: at sentence #550000, processed 10993836 words, keeping 686867 word types
# PROGRESS: at sentence #560000, processed 11193637 words, keeping 686940 word types
# PROGRESS: at sentence #570000, processed 11393495 words, keeping 687032 word types
# PROGRESS: at sentence #580000, processed 11593369 words, keeping 687091 word types
# PROGRESS: at sentence #590000, processed 11793214 words, keeping 687138 word types
# PROGRESS: at sentence #600000, processed 11993111 words, keeping 687189 word types
# PROGRESS: at sentence #610000, processed 12192833 words, keeping 687221 word types
# PROGRESS: at sentence #620000, processed 12392763 words, keeping 687262 word types
# PROGRESS: at sentence #630000, processed 12592649 words, keeping 687292 word types
# PROGRESS: at sentence #640000, processed 12792539 words, keeping 687328 word types
# PROGRESS: at sentence #650000, processed 12992368 words, keeping 687349 word types
# PROGRESS: at sentence #660000, processed 13192311 words, keeping 687371 word types
# PROGRESS: at sentence #670000, processed 13392187 words, keeping 687384 word types
# PROGRESS: at sentence #680000, processed 13592080 words, keeping 687395 word types
# PROGRESS: at sentence #690000, processed 13791907 words, keeping 687405 word types
# PROGRESS: at sentence #700000, processed 13991776 words, keeping 687405 word types
# PROGRESS: at sentence #710000, processed 14191564 words, keeping 687405 word types
# PROGRESS: at sentence #720000, processed 14391487 words, keeping 687405 word types
# PROGRESS: at sentence #730000, processed 14591363 words, keeping 687405 word types
# PROGRESS: at sentence #740000, processed 14791248 words, keeping 687405 word types
# PROGRESS: at sentence #750000, processed 14991108 words, keeping 687405 word types
# PROGRESS: at sentence #760000, processed 15190999 words, keeping 687405 word types
# PROGRESS: at sentence #770000, processed 15390836 words, keeping 687405 word types
# PROGRESS: at sentence #780000, processed 15590668 words, keeping 687405 word types
# PROGRESS: at sentence #790000, processed 15790604 words, keeping 687405 word types
# PROGRESS: at sentence #800000, processed 15990500 words, keeping 687405 word types
# PROGRESS: at sentence #810000, processed 16190330 words, keeping 687405 word types
# PROGRESS: at sentence #820000, processed 16390196 words, keeping 687405 word types
# PROGRESS: at sentence #830000, processed 16590088 words, keeping 687405 word types
# PROGRESS: at sentence #840000, processed 16790033 words, keeping 687405 word types
# PROGRESS: at sentence #850000, processed 16989960 words, keeping 687405 word types
# PROGRESS: at sentence #860000, processed 17189807 words, keeping 687405 word types
# PROGRESS: at sentence #870000, processed 17389666 words, keeping 687405 word types
# PROGRESS: at sentence #880000, processed 17589500 words, keeping 687405 word types
# PROGRESS: at sentence #890000, processed 17789382 words, keeping 687405 word types
# PROGRESS: at sentence #900000, processed 17989270 words, keeping 687405 word types
# PROGRESS: at sentence #910000, processed 18189090 words, keeping 687405 word types
# PROGRESS: at sentence #920000, processed 18388977 words, keeping 687405 word types
# PROGRESS: at sentence #930000, processed 18588861 words, keeping 687405 word types
# PROGRESS: at sentence #940000, processed 18788740 words, keeping 687405 word types
# PROGRESS: at sentence #950000, processed 18988681 words, keeping 687405 word types
# PROGRESS: at sentence #960000, processed 19188564 words, keeping 687405 word types
# PROGRESS: at sentence #970000, processed 19388453 words, keeping 687405 word types
# PROGRESS: at sentence #980000, processed 19588295 words, keeping 687405 word types
# PROGRESS: at sentence #990000, processed 19788220 words, keeping 687405 word types
# PROGRESS: at sentence #1000000, processed 19988103 words, keeping 687405 word types
# PROGRESS: at sentence #1010000, processed 20188021 words, keeping 687405 word types
# PROGRESS: at sentence #1020000, processed 20387899 words, keeping 687405 word types
# PROGRESS: at sentence #1030000, processed 20587808 words, keeping 687405 word types
# PROGRESS: at sentence #1040000, processed 20787634 words, keeping 687405 word types
# PROGRESS: at sentence #1050000, processed 20987495 words, keeping 687405 word types
# PROGRESS: at sentence #1060000, processed 21187345 words, keeping 687405 word types
# PROGRESS: at sentence #1070000, processed 21387232 words, keeping 687405 word types
# PROGRESS: at sentence #1080000, processed 21587168 words, keeping 687405 word types
# PROGRESS: at sentence #1090000, processed 21787112 words, keeping 687405 word types
# PROGRESS: at sentence #1100000, processed 21986973 words, keeping 687405 word types
# PROGRESS: at sentence #1110000, processed 22186895 words, keeping 687405 word types
# PROGRESS: at sentence #1120000, processed 22386702 words, keeping 687405 word types
# PROGRESS: at sentence #1130000, processed 22586524 words, keeping 687405 word types
# PROGRESS: at sentence #1140000, processed 22786467 words, keeping 687405 word types
# PROGRESS: at sentence #1150000, processed 22986359 words, keeping 687405 word types
# PROGRESS: at sentence #1160000, processed 23186220 words, keeping 687405 word types
# PROGRESS: at sentence #1170000, processed 23386095 words, keeping 687405 word types
# PROGRESS: at sentence #1180000, processed 23585999 words, keeping 687405 word types
# PROGRESS: at sentence #1190000, processed 23785860 words, keeping 687405 word types
# PROGRESS: at sentence #1200000, processed 23985733 words, keeping 687405 word types
# PROGRESS: at sentence #1210000, processed 24185585 words, keeping 687405 word types
# PROGRESS: at sentence #1220000, processed 24385397 words, keeping 687405 word types
# PROGRESS: at sentence #1230000, processed 24585265 words, keeping 687405 word types
# PROGRESS: at sentence #1240000, processed 24785136 words, keeping 687405 word types
# PROGRESS: at sentence #1250000, processed 24985101 words, keeping 687405 word types
# PROGRESS: at sentence #1260000, processed 25185030 words, keeping 687405 word types
# PROGRESS: at sentence #1270000, processed 25384838 words, keeping 687405 word types
# PROGRESS: at sentence #1280000, processed 25584723 words, keeping 687405 word types
# PROGRESS: at sentence #1290000, processed 25784642 words, keeping 687405 word types
# PROGRESS: at sentence #1300000, processed 25984512 words, keeping 687405 word types
# PROGRESS: at sentence #1310000, processed 26184480 words, keeping 687405 word types
# PROGRESS: at sentence #1320000, processed 26384322 words, keeping 687405 word types
# PROGRESS: at sentence #1330000, processed 26584238 words, keeping 687405 word types
# PROGRESS: at sentence #1340000, processed 26784107 words, keeping 687405 word types
# PROGRESS: at sentence #1350000, processed 26984078 words, keeping 687405 word types
# PROGRESS: at sentence #1360000, processed 27183930 words, keeping 687405 word types
# PROGRESS: at sentence #1370000, processed 27383796 words, keeping 687405 word types
# PROGRESS: at sentence #1380000, processed 27583681 words, keeping 687405 word types
# PROGRESS: at sentence #1390000, processed 27783548 words, keeping 687405 word types
# PROGRESS: at sentence #1400000, processed 27983456 words, keeping 687405 word types
# PROGRESS: at sentence #1410000, processed 28183338 words, keeping 687405 word types
# PROGRESS: at sentence #1420000, processed 28383169 words, keeping 687405 word types
# PROGRESS: at sentence #1430000, processed 28583046 words, keeping 687405 word types
# PROGRESS: at sentence #1440000, processed 28782894 words, keeping 687405 word types
# PROGRESS: at sentence #1450000, processed 28982825 words, keeping 687405 word types
# PROGRESS: at sentence #1460000, processed 29182699 words, keeping 687405 word types
# PROGRESS: at sentence #1470000, processed 29382577 words, keeping 687405 word types
# PROGRESS: at sentence #1480000, processed 29582445 words, keeping 687405 word types
# PROGRESS: at sentence #1490000, processed 29782384 words, keeping 687405 word types
# PROGRESS: at sentence #1500000, processed 29982247 words, keeping 687405 word types
# PROGRESS: at sentence #1510000, processed 30182108 words, keeping 687405 word types
# PROGRESS: at sentence #1520000, processed 30381993 words, keeping 687405 word types
# PROGRESS: at sentence #1530000, processed 30581839 words, keeping 687405 word types
# PROGRESS: at sentence #1540000, processed 30781665 words, keeping 687405 word types
# PROGRESS: at sentence #1550000, processed 30981565 words, keeping 687405 word types
# PROGRESS: at sentence #1560000, processed 31181430 words, keeping 687405 word types
# PROGRESS: at sentence #1570000, processed 31381260 words, keeping 687405 word types
# PROGRESS: at sentence #1580000, processed 31581090 words, keeping 687405 word types
# PROGRESS: at sentence #1590000, processed 31781013 words, keeping 687405 word types
# PROGRESS: at sentence #1600000, processed 31980874 words, keeping 687405 word types
# PROGRESS: at sentence #1610000, processed 32180808 words, keeping 687405 word types
# PROGRESS: at sentence #1620000, processed 32380755 words, keeping 687405 word types
# PROGRESS: at sentence #1630000, processed 32580664 words, keeping 687405 word types
# PROGRESS: at sentence #1640000, processed 32780544 words, keeping 687405 word types
# PROGRESS: at sentence #1650000, processed 32980519 words, keeping 687405 word types
# PROGRESS: at sentence #1660000, processed 33180453 words, keeping 687405 word types
# PROGRESS: at sentence #1670000, processed 33380263 words, keeping 687405 word types
# PROGRESS: at sentence #1680000, processed 33580112 words, keeping 687405 word types
# PROGRESS: at sentence #1690000, processed 33779968 words, keeping 687405 word types
# PROGRESS: at sentence #1700000, processed 33979880 words, keeping 687405 word types
# PROGRESS: at sentence #1710000, processed 34179764 words, keeping 687405 word types
# PROGRESS: at sentence #1720000, processed 34379715 words, keeping 687405 word types
# PROGRESS: at sentence #1730000, processed 34579600 words, keeping 687405 word types
# PROGRESS: at sentence #1740000, processed 34779521 words, keeping 687405 word types
# PROGRESS: at sentence #1750000, processed 34979433 words, keeping 687405 word types
# PROGRESS: at sentence #1760000, processed 35179289 words, keeping 687405 word types
# PROGRESS: at sentence #1770000, processed 35379163 words, keeping 687405 word types
# PROGRESS: at sentence #1780000, processed 35579064 words, keeping 687405 word types
# PROGRESS: at sentence #1790000, processed 35778906 words, keeping 687405 word types
# PROGRESS: at sentence #1800000, processed 35978794 words, keeping 687405 word types
# PROGRESS: at sentence #1810000, processed 36178707 words, keeping 687405 word types
# PROGRESS: at sentence #1820000, processed 36378490 words, keeping 687405 word types
# PROGRESS: at sentence #1830000, processed 36578403 words, keeping 687405 word types
# PROGRESS: at sentence #1840000, processed 36778345 words, keeping 687405 word types
# PROGRESS: at sentence #1850000, processed 36978240 words, keeping 687405 word types
# PROGRESS: at sentence #1860000, processed 37178152 words, keeping 687405 word types
# PROGRESS: at sentence #1870000, processed 37378004 words, keeping 687405 word types
# PROGRESS: at sentence #1880000, processed 37577937 words, keeping 687405 word types
# PROGRESS: at sentence #1890000, processed 37777849 words, keeping 687405 word types
# PROGRESS: at sentence #1900000, processed 37977676 words, keeping 687405 word types
# PROGRESS: at sentence #1910000, processed 38177513 words, keeping 687405 word types
# PROGRESS: at sentence #1920000, processed 38377385 words, keeping 687405 word types
# PROGRESS: at sentence #1930000, processed 38577323 words, keeping 687405 word types
# PROGRESS: at sentence #1940000, processed 38777143 words, keeping 687405 word types
# PROGRESS: at sentence #1950000, processed 38977056 words, keeping 687405 word types
# PROGRESS: at sentence #1960000, processed 39176941 words, keeping 687405 word types
# PROGRESS: at sentence #1970000, processed 39376784 words, keeping 687405 word types
# PROGRESS: at sentence #1980000, processed 39576656 words, keeping 687405 word types
# PROGRESS: at sentence #1990000, processed 39776510 words, keeping 687405 word types
# PROGRESS: at sentence #2000000, processed 39976437 words, keeping 687405 word types
# PROGRESS: at sentence #2010000, processed 40176372 words, keeping 687405 word types
# PROGRESS: at sentence #2020000, processed 40376283 words, keeping 687405 word types
# PROGRESS: at sentence #2030000, processed 40576170 words, keeping 687405 word types
# PROGRESS: at sentence #2040000, processed 40776041 words, keeping 687405 word types
# PROGRESS: at sentence #2050000, processed 40976010 words, keeping 687405 word types
# PROGRESS: at sentence #2060000, processed 41175914 words, keeping 687405 word types
# PROGRESS: at sentence #2070000, processed 41375790 words, keeping 687405 word types
# PROGRESS: at sentence #2080000, processed 41575678 words, keeping 687405 word types
# PROGRESS: at sentence #2090000, processed 41775630 words, keeping 687405 word types
# PROGRESS: at sentence #2100000, processed 41975540 words, keeping 687405 word types
# PROGRESS: at sentence #2110000, processed 42175491 words, keeping 687405 word types
# PROGRESS: at sentence #2120000, processed 42375445 words, keeping 687405 word types
# PROGRESS: at sentence #2130000, processed 42575300 words, keeping 687405 word types
# PROGRESS: at sentence #2140000, processed 42775187 words, keeping 687405 word types
# PROGRESS: at sentence #2150000, processed 42975064 words, keeping 687405 word types
# PROGRESS: at sentence #2160000, processed 43174946 words, keeping 687405 word types
# PROGRESS: at sentence #2170000, processed 43374777 words, keeping 687405 word types
# PROGRESS: at sentence #2180000, processed 43574686 words, keeping 687405 word types
# PROGRESS: at sentence #2190000, processed 43774528 words, keeping 687405 word types
# PROGRESS: at sentence #2200000, processed 43974368 words, keeping 687405 word types
# PROGRESS: at sentence #2210000, processed 44174272 words, keeping 687405 word types
# PROGRESS: at sentence #2220000, processed 44374147 words, keeping 687405 word types
# PROGRESS: at sentence #2230000, processed 44574054 words, keeping 687405 word types
# PROGRESS: at sentence #2240000, processed 44773894 words, keeping 687405 word types
# PROGRESS: at sentence #2250000, processed 44973831 words, keeping 687405 word types
# PROGRESS: at sentence #2260000, processed 45173747 words, keeping 687405 word types
# PROGRESS: at sentence #2270000, processed 45373664 words, keeping 687405 word types
# PROGRESS: at sentence #2280000, processed 45573518 words, keeping 687405 word types
# PROGRESS: at sentence #2290000, processed 45773359 words, keeping 687405 word types
# PROGRESS: at sentence #2300000, processed 45973199 words, keeping 687405 word types
# PROGRESS: at sentence #2310000, processed 46173075 words, keeping 687405 word types
# PROGRESS: at sentence #2320000, processed 46372931 words, keeping 687405 word types
# PROGRESS: at sentence #2330000, processed 46572819 words, keeping 687405 word types
# PROGRESS: at sentence #2340000, processed 46772777 words, keeping 687405 word types
# PROGRESS: at sentence #2350000, processed 46972664 words, keeping 687405 word types
# PROGRESS: at sentence #2360000, processed 47172529 words, keeping 687405 word types
# PROGRESS: at sentence #2370000, processed 47372390 words, keeping 687405 word types
# PROGRESS: at sentence #2380000, processed 47572263 words, keeping 687405 word types
# PROGRESS: at sentence #2390000, processed 47772089 words, keeping 687405 word types
# PROGRESS: at sentence #2400000, processed 47971982 words, keeping 687405 word types
# PROGRESS: at sentence #2410000, processed 48171779 words, keeping 687405 word types
# PROGRESS: at sentence #2420000, processed 48371598 words, keeping 687405 word types
# PROGRESS: at sentence #2430000, processed 48571461 words, keeping 687405 word types
# PROGRESS: at sentence #2440000, processed 48771319 words, keeping 687405 word types
# PROGRESS: at sentence #2450000, processed 48971159 words, keeping 687405 word types
# PROGRESS: at sentence #2460000, processed 49170976 words, keeping 687405 word types
# PROGRESS: at sentence #2470000, processed 49370888 words, keeping 687405 word types
# PROGRESS: at sentence #2480000, processed 49570785 words, keeping 687405 word types
# PROGRESS: at sentence #2490000, processed 49770701 words, keeping 687405 word types
# PROGRESS: at sentence #2500000, processed 49970521 words, keeping 687405 word types
# PROGRESS: at sentence #2510000, processed 50170359 words, keeping 687405 word types
# PROGRESS: at sentence #2520000, processed 50370295 words, keeping 687405 word types
# PROGRESS: at sentence #2530000, processed 50570116 words, keeping 687405 word types
# PROGRESS: at sentence #2540000, processed 50770092 words, keeping 687405 word types
# PROGRESS: at sentence #2550000, processed 50969943 words, keeping 687405 word types
# PROGRESS: at sentence #2560000, processed 51169810 words, keeping 687405 word types
# PROGRESS: at sentence #2570000, processed 51369718 words, keeping 687405 word types
# PROGRESS: at sentence #2580000, processed 51569594 words, keeping 687405 word types
# PROGRESS: at sentence #2590000, processed 51769470 words, keeping 687405 word types
# PROGRESS: at sentence #2600000, processed 51969327 words, keeping 687405 word types
# PROGRESS: at sentence #2610000, processed 52169185 words, keeping 687405 word types
# PROGRESS: at sentence #2620000, processed 52369116 words, keeping 687405 word types
# PROGRESS: at sentence #2630000, processed 52568939 words, keeping 687405 word types
# PROGRESS: at sentence #2640000, processed 52768833 words, keeping 687405 word types
# PROGRESS: at sentence #2650000, processed 52968719 words, keeping 687405 word types
# PROGRESS: at sentence #2660000, processed 53168603 words, keeping 687405 word types
# PROGRESS: at sentence #2670000, processed 53368541 words, keeping 687405 word types
# PROGRESS: at sentence #2680000, processed 53568345 words, keeping 687405 word types
# PROGRESS: at sentence #2690000, processed 53768202 words, keeping 687405 word types
# PROGRESS: at sentence #2700000, processed 53968062 words, keeping 687405 word types
# PROGRESS: at sentence #2710000, processed 54167985 words, keeping 687405 word types
# PROGRESS: at sentence #2720000, processed 54367921 words, keeping 687405 word types
# PROGRESS: at sentence #2730000, processed 54567799 words, keeping 687405 word types
# PROGRESS: at sentence #2740000, processed 54767673 words, keeping 687405 word types
# PROGRESS: at sentence #2750000, processed 54967559 words, keeping 687405 word types
# PROGRESS: at sentence #2760000, processed 55167475 words, keeping 687405 word types
# PROGRESS: at sentence #2770000, processed 55367339 words, keeping 687405 word types
# PROGRESS: at sentence #2780000, processed 55567211 words, keeping 687405 word types
# PROGRESS: at sentence #2790000, processed 55767129 words, keeping 687405 word types
# PROGRESS: at sentence #2800000, processed 55967058 words, keeping 687405 word types
# PROGRESS: at sentence #2810000, processed 56166871 words, keeping 687405 word types
# PROGRESS: at sentence #2820000, processed 56366714 words, keeping 687405 word types
# PROGRESS: at sentence #2830000, processed 56566575 words, keeping 687405 word types
# PROGRESS: at sentence #2840000, processed 56766383 words, keeping 687405 word types
# PROGRESS: at sentence #2850000, processed 56966288 words, keeping 687405 word types
# PROGRESS: at sentence #2860000, processed 57166113 words, keeping 687405 word types
# PROGRESS: at sentence #2870000, processed 57366021 words, keeping 687405 word types
# PROGRESS: at sentence #2880000, processed 57565858 words, keeping 687405 word types
# PROGRESS: at sentence #2890000, processed 57765745 words, keeping 687405 word types
# PROGRESS: at sentence #2900000, processed 57965642 words, keeping 687405 word types
# PROGRESS: at sentence #2910000, processed 58165440 words, keeping 687405 word types
# PROGRESS: at sentence #2920000, processed 58365384 words, keeping 687405 word types
# PROGRESS: at sentence #2930000, processed 58565257 words, keeping 687405 word types
# PROGRESS: at sentence #2940000, processed 58765126 words, keeping 687405 word types
# PROGRESS: at sentence #2950000, processed 58964931 words, keeping 687405 word types
# PROGRESS: at sentence #2960000, processed 59164859 words, keeping 687405 word types
# PROGRESS: at sentence #2970000, processed 59364719 words, keeping 687405 word types
# PROGRESS: at sentence #2980000, processed 59564550 words, keeping 687405 word types
# PROGRESS: at sentence #2990000, processed 59764438 words, keeping 687405 word types
# PROGRESS: at sentence #3000000, processed 59964285 words, keeping 687405 word types
# PROGRESS: at sentence #3010000, processed 60164171 words, keeping 687405 word types
# PROGRESS: at sentence #3020000, processed 60364031 words, keeping 687405 word types
# PROGRESS: at sentence #3030000, processed 60563925 words, keeping 687405 word types
# PROGRESS: at sentence #3040000, processed 60763799 words, keeping 687405 word types
# PROGRESS: at sentence #3050000, processed 60963760 words, keeping 687405 word types
# PROGRESS: at sentence #3060000, processed 61163629 words, keeping 687405 word types
# PROGRESS: at sentence #3070000, processed 61363538 words, keeping 687405 word types
# PROGRESS: at sentence #3080000, processed 61563497 words, keeping 687405 word types
# PROGRESS: at sentence #3090000, processed 61763439 words, keeping 687405 word types
# PROGRESS: at sentence #3100000, processed 61963323 words, keeping 687405 word types
# PROGRESS: at sentence #3110000, processed 62163190 words, keeping 687405 word types
# PROGRESS: at sentence #3120000, processed 62363160 words, keeping 687405 word types
# PROGRESS: at sentence #3130000, processed 62563040 words, keeping 687405 word types
# PROGRESS: at sentence #3140000, processed 62762916 words, keeping 687405 word types
# PROGRESS: at sentence #3150000, processed 62962804 words, keeping 687405 word types
# PROGRESS: at sentence #3160000, processed 63162725 words, keeping 687405 word types
# PROGRESS: at sentence #3170000, processed 63362550 words, keeping 687405 word types
# PROGRESS: at sentence #3180000, processed 63562448 words, keeping 687405 word types
# PROGRESS: at sentence #3190000, processed 63762362 words, keeping 687405 word types
# PROGRESS: at sentence #3200000, processed 63962303 words, keeping 687405 word types
# PROGRESS: at sentence #3210000, processed 64162191 words, keeping 687405 word types
# PROGRESS: at sentence #3220000, processed 64362085 words, keeping 687405 word types
# PROGRESS: at sentence #3230000, processed 64561992 words, keeping 687405 word types
# PROGRESS: at sentence #3240000, processed 64761899 words, keeping 687405 word types
# PROGRESS: at sentence #3250000, processed 64961741 words, keeping 687405 word types
# PROGRESS: at sentence #3260000, processed 65161586 words, keeping 687405 word types
# PROGRESS: at sentence #3270000, processed 65361418 words, keeping 687405 word types
# PROGRESS: at sentence #3280000, processed 65561300 words, keeping 687405 word types
# PROGRESS: at sentence #3290000, processed 65761211 words, keeping 687405 word types
# PROGRESS: at sentence #3300000, processed 65961089 words, keeping 687405 word types
# PROGRESS: at sentence #3310000, processed 66160984 words, keeping 687405 word types
# PROGRESS: at sentence #3320000, processed 66360783 words, keeping 687405 word types
# PROGRESS: at sentence #3330000, processed 66560678 words, keeping 687405 word types
# PROGRESS: at sentence #3340000, processed 66760526 words, keeping 687405 word types
# PROGRESS: at sentence #3350000, processed 66960367 words, keeping 687405 word types
# PROGRESS: at sentence #3360000, processed 67160272 words, keeping 687405 word types
# PROGRESS: at sentence #3370000, processed 67360180 words, keeping 687405 word types
# PROGRESS: at sentence #3380000, processed 67560043 words, keeping 687405 word types
# PROGRESS: at sentence #3390000, processed 67759870 words, keeping 687405 word types
# PROGRESS: at sentence #3400000, processed 67959736 words, keeping 687405 word types
# PROGRESS: at sentence #3410000, processed 68159563 words, keeping 687405 word types
# PROGRESS: at sentence #3420000, processed 68359412 words, keeping 687405 word types
# PROGRESS: at sentence #3430000, processed 68559281 words, keeping 687405 word types
# PROGRESS: at sentence #3440000, processed 68759098 words, keeping 687405 word types
# PROGRESS: at sentence #3450000, processed 68959038 words, keeping 687405 word types
# PROGRESS: at sentence #3460000, processed 69158948 words, keeping 687405 word types
# PROGRESS: at sentence #3470000, processed 69358854 words, keeping 687405 word types
# PROGRESS: at sentence #3480000, processed 69558760 words, keeping 687405 word types
# PROGRESS: at sentence #3490000, processed 69758596 words, keeping 687405 word types
# PROGRESS: at sentence #3500000, processed 69958489 words, keeping 687405 word types
# PROGRESS: at sentence #3510000, processed 70158366 words, keeping 687405 word types
# PROGRESS: at sentence #3520000, processed 70358239 words, keeping 687405 word types
# PROGRESS: at sentence #3530000, processed 70558186 words, keeping 687405 word types
# PROGRESS: at sentence #3540000, processed 70758024 words, keeping 687405 word types
# PROGRESS: at sentence #3550000, processed 70957837 words, keeping 687405 word types
# PROGRESS: at sentence #3560000, processed 71157757 words, keeping 687405 word types
# PROGRESS: at sentence #3570000, processed 71357634 words, keeping 687405 word types
# PROGRESS: at sentence #3580000, processed 71557491 words, keeping 687405 word types
# PROGRESS: at sentence #3590000, processed 71757348 words, keeping 687405 word types
# PROGRESS: at sentence #3600000, processed 71957204 words, keeping 687405 word types
# PROGRESS: at sentence #3610000, processed 72157151 words, keeping 687405 word types
# PROGRESS: at sentence #3620000, processed 72357034 words, keeping 687405 word types
# PROGRESS: at sentence #3630000, processed 72556894 words, keeping 687405 word types
# PROGRESS: at sentence #3640000, processed 72756777 words, keeping 687405 word types
# PROGRESS: at sentence #3650000, processed 72956656 words, keeping 687405 word types
# PROGRESS: at sentence #3660000, processed 73156521 words, keeping 687405 word types
# PROGRESS: at sentence #3670000, processed 73356400 words, keeping 687405 word types
# PROGRESS: at sentence #3680000, processed 73556313 words, keeping 687405 word types
# PROGRESS: at sentence #3690000, processed 73756176 words, keeping 687405 word types
# PROGRESS: at sentence #3700000, processed 73956008 words, keeping 687405 word types
# PROGRESS: at sentence #3710000, processed 74155909 words, keeping 687405 word types
# PROGRESS: at sentence #3720000, processed 74355823 words, keeping 687405 word types
# PROGRESS: at sentence #3730000, processed 74555642 words, keeping 687405 word types
# PROGRESS: at sentence #3740000, processed 74755575 words, keeping 687405 word types
# PROGRESS: at sentence #3750000, processed 74955431 words, keeping 687405 word types
# PROGRESS: at sentence #3760000, processed 75155323 words, keeping 687405 word types
# PROGRESS: at sentence #3770000, processed 75355184 words, keeping 687405 word types
# PROGRESS: at sentence #3780000, processed 75555114 words, keeping 687405 word types
# PROGRESS: at sentence #3790000, processed 75755014 words, keeping 687405 word types
# PROGRESS: at sentence #3800000, processed 75954914 words, keeping 687405 word types
# PROGRESS: at sentence #3810000, processed 76154745 words, keeping 687405 word types
# PROGRESS: at sentence #3820000, processed 76354562 words, keeping 687405 word types
# PROGRESS: at sentence #3830000, processed 76554414 words, keeping 687405 word types
# PROGRESS: at sentence #3840000, processed 76754356 words, keeping 687405 word types
# PROGRESS: at sentence #3850000, processed 76954218 words, keeping 687405 word types
# PROGRESS: at sentence #3860000, processed 77154085 words, keeping 687405 word types
# PROGRESS: at sentence #3870000, processed 77353978 words, keeping 687405 word types
# PROGRESS: at sentence #3880000, processed 77553802 words, keeping 687405 word types
# PROGRESS: at sentence #3890000, processed 77753688 words, keeping 687405 word types
# PROGRESS: at sentence #3900000, processed 77953571 words, keeping 687405 word types
# PROGRESS: at sentence #3910000, processed 78153485 words, keeping 687405 word types
# PROGRESS: at sentence #3920000, processed 78353352 words, keeping 687405 word types
# PROGRESS: at sentence #3930000, processed 78553245 words, keeping 687405 word types
# PROGRESS: at sentence #3940000, processed 78753096 words, keeping 687405 word types
# PROGRESS: at sentence #3950000, processed 78953035 words, keeping 687405 word types
# PROGRESS: at sentence #3960000, processed 79152918 words, keeping 687405 word types
# PROGRESS: at sentence #3970000, processed 79352794 words, keeping 687405 word types
# PROGRESS: at sentence #3980000, processed 79552754 words, keeping 687405 word types
# PROGRESS: at sentence #3990000, processed 79752621 words, keeping 687405 word types
# PROGRESS: at sentence #4000000, processed 79952558 words, keeping 687405 word types
# PROGRESS: at sentence #4010000, processed 80152502 words, keeping 687405 word types
# PROGRESS: at sentence #4020000, processed 80352410 words, keeping 687405 word types
# PROGRESS: at sentence #4030000, processed 80552312 words, keeping 687405 word types
# PROGRESS: at sentence #4040000, processed 80752244 words, keeping 687405 word types
# PROGRESS: at sentence #4050000, processed 80952175 words, keeping 687405 word types
# PROGRESS: at sentence #4060000, processed 81152094 words, keeping 687405 word types
# PROGRESS: at sentence #4070000, processed 81351979 words, keeping 687405 word types
# PROGRESS: at sentence #4080000, processed 81551770 words, keeping 687405 word types
# PROGRESS: at sentence #4090000, processed 81751668 words, keeping 687405 word types
# PROGRESS: at sentence #4100000, processed 81951531 words, keeping 687405 word types
# PROGRESS: at sentence #4110000, processed 82151414 words, keeping 687405 word types
# PROGRESS: at sentence #4120000, processed 82351370 words, keeping 687405 word types
# PROGRESS: at sentence #4130000, processed 82551206 words, keeping 687405 word types
# PROGRESS: at sentence #4140000, processed 82751059 words, keeping 687405 word types
# PROGRESS: at sentence #4150000, processed 82950956 words, keeping 687405 word types
# PROGRESS: at sentence #4160000, processed 83150832 words, keeping 687405 word types
# PROGRESS: at sentence #4170000, processed 83350701 words, keeping 687405 word types
# PROGRESS: at sentence #4180000, processed 83550562 words, keeping 687405 word types
# PROGRESS: at sentence #4190000, processed 83750433 words, keeping 687405 word types
# PROGRESS: at sentence #4200000, processed 83950351 words, keeping 687405 word types
# PROGRESS: at sentence #4210000, processed 84150258 words, keeping 687405 word types
# PROGRESS: at sentence #4220000, processed 84350098 words, keeping 687405 word types
# PROGRESS: at sentence #4230000, processed 84549957 words, keeping 687405 word types
# PROGRESS: at sentence #4240000, processed 84749911 words, keeping 687405 word types
# PROGRESS: at sentence #4250000, processed 84949773 words, keeping 687405 word types
# PROGRESS: at sentence #4260000, processed 85149719 words, keeping 687405 word types
# PROGRESS: at sentence #4270000, processed 85349596 words, keeping 687405 word types
# PROGRESS: at sentence #4280000, processed 85549492 words, keeping 687405 word types
# PROGRESS: at sentence #4290000, processed 85749404 words, keeping 687405 word types
# PROGRESS: at sentence #4300000, processed 85949287 words, keeping 687405 word types
# PROGRESS: at sentence #4310000, processed 86149205 words, keeping 687405 word types
# PROGRESS: at sentence #4320000, processed 86349070 words, keeping 687405 word types
# PROGRESS: at sentence #4330000, processed 86548994 words, keeping 687405 word types
# PROGRESS: at sentence #4340000, processed 86748814 words, keeping 687405 word types
# PROGRESS: at sentence #4350000, processed 86948707 words, keeping 687405 word types
# PROGRESS: at sentence #4360000, processed 87148483 words, keeping 687405 word types
# PROGRESS: at sentence #4370000, processed 87348369 words, keeping 687405 word types
# PROGRESS: at sentence #4380000, processed 87548311 words, keeping 687405 word types
# PROGRESS: at sentence #4390000, processed 87748209 words, keeping 687405 word types
# PROGRESS: at sentence #4400000, processed 87948032 words, keeping 687405 word types
# PROGRESS: at sentence #4410000, processed 88147878 words, keeping 687405 word types
# PROGRESS: at sentence #4420000, processed 88347759 words, keeping 687405 word types
# PROGRESS: at sentence #4430000, processed 88547622 words, keeping 687405 word types
# PROGRESS: at sentence #4440000, processed 88747499 words, keeping 687405 word types
# PROGRESS: at sentence #4450000, processed 88947323 words, keeping 687405 word types
# PROGRESS: at sentence #4460000, processed 89147207 words, keeping 687405 word types
# PROGRESS: at sentence #4470000, processed 89347080 words, keeping 687405 word types
# PROGRESS: at sentence #4480000, processed 89546962 words, keeping 687405 word types
# PROGRESS: at sentence #4490000, processed 89746951 words, keeping 687405 word types
# PROGRESS: at sentence #4500000, processed 89946846 words, keeping 687405 word types
# PROGRESS: at sentence #4510000, processed 90146663 words, keeping 687405 word types
# PROGRESS: at sentence #4520000, processed 90346580 words, keeping 687405 word types
# PROGRESS: at sentence #4530000, processed 90546436 words, keeping 687405 word types
# PROGRESS: at sentence #4540000, processed 90746301 words, keeping 687405 word types
# PROGRESS: at sentence #4550000, processed 90946254 words, keeping 687405 word types
# PROGRESS: at sentence #4560000, processed 91146141 words, keeping 687405 word types
# PROGRESS: at sentence #4570000, processed 91346017 words, keeping 687405 word types
# PROGRESS: at sentence #4580000, processed 91545889 words, keeping 687405 word types
# PROGRESS: at sentence #4590000, processed 91745790 words, keeping 687405 word types
# PROGRESS: at sentence #4600000, processed 91945584 words, keeping 687405 word types
# PROGRESS: at sentence #4610000, processed 92145452 words, keeping 687405 word types
# PROGRESS: at sentence #4620000, processed 92345333 words, keeping 687405 word types
# PROGRESS: at sentence #4630000, processed 92545224 words, keeping 687405 word types
# PROGRESS: at sentence #4640000, processed 92745132 words, keeping 687405 word types
# PROGRESS: at sentence #4650000, processed 92945041 words, keeping 687405 word types
# PROGRESS: at sentence #4660000, processed 93144958 words, keeping 687405 word types
# PROGRESS: at sentence #4670000, processed 93344856 words, keeping 687405 word types
# PROGRESS: at sentence #4680000, processed 93544720 words, keeping 687405 word types
# PROGRESS: at sentence #4690000, processed 93744640 words, keeping 687405 word types
# PROGRESS: at sentence #4700000, processed 93944488 words, keeping 687405 word types
# PROGRESS: at sentence #4710000, processed 94144357 words, keeping 687405 word types
# PROGRESS: at sentence #4720000, processed 94344288 words, keeping 687405 word types
# PROGRESS: at sentence #4730000, processed 94544160 words, keeping 687405 word types
# PROGRESS: at sentence #4740000, processed 94744093 words, keeping 687405 word types
# PROGRESS: at sentence #4750000, processed 94944074 words, keeping 687405 word types
# PROGRESS: at sentence #4760000, processed 95143972 words, keeping 687405 word types
# PROGRESS: at sentence #4770000, processed 95343868 words, keeping 687405 word types
# PROGRESS: at sentence #4780000, processed 95543820 words, keeping 687405 word types
# PROGRESS: at sentence #4790000, processed 95743696 words, keeping 687405 word types
# PROGRESS: at sentence #4800000, processed 95943576 words, keeping 687405 word types
# PROGRESS: at sentence #4810000, processed 96143503 words, keeping 687405 word types
# PROGRESS: at sentence #4820000, processed 96343394 words, keeping 687405 word types
# PROGRESS: at sentence #4830000, processed 96543286 words, keeping 687405 word types
# PROGRESS: at sentence #4840000, processed 96743174 words, keeping 687405 word types
# PROGRESS: at sentence #4850000, processed 96943107 words, keeping 687405 word types
# PROGRESS: at sentence #4860000, processed 97142906 words, keeping 687405 word types
# PROGRESS: at sentence #4870000, processed 97342830 words, keeping 687405 word types
# PROGRESS: at sentence #4880000, processed 97542650 words, keeping 687405 word types
# PROGRESS: at sentence #4890000, processed 97742560 words, keeping 687405 word types
# PROGRESS: at sentence #4900000, processed 97942466 words, keeping 687405 word types
# PROGRESS: at sentence #4910000, processed 98142408 words, keeping 687405 word types
# PROGRESS: at sentence #4920000, processed 98342265 words, keeping 687405 word types
# PROGRESS: at sentence #4930000, processed 98542130 words, keeping 687405 word types
# PROGRESS: at sentence #4940000, processed 98741928 words, keeping 687405 word types
# PROGRESS: at sentence #4950000, processed 98941876 words, keeping 687405 word types
# PROGRESS: at sentence #4960000, processed 99141716 words, keeping 687405 word types
# PROGRESS: at sentence #4970000, processed 99341524 words, keeping 687405 word types
# PROGRESS: at sentence #4980000, processed 99541385 words, keeping 687405 word types
# PROGRESS: at sentence #4990000, processed 99741335 words, keeping 687405 word types
# PROGRESS: at sentence #5000000, processed 99941253 words, keeping 687405 word types
# PROGRESS: at sentence #5010000, processed 100141213 words, keeping 687405 word types
# PROGRESS: at sentence #5020000, processed 100341116 words, keeping 687405 word types
# PROGRESS: at sentence #5030000, processed 100541054 words, keeping 687405 word types
# PROGRESS: at sentence #5040000, processed 100740960 words, keeping 687405 word types
# PROGRESS: at sentence #5050000, processed 100940898 words, keeping 687405 word types
# PROGRESS: at sentence #5060000, processed 101140839 words, keeping 687405 word types
# PROGRESS: at sentence #5070000, processed 101340730 words, keeping 687405 word types
# PROGRESS: at sentence #5080000, processed 101540628 words, keeping 687405 word types
# PROGRESS: at sentence #5090000, processed 101740480 words, keeping 687405 word types
# PROGRESS: at sentence #5100000, processed 101940320 words, keeping 687405 word types
# PROGRESS: at sentence #5110000, processed 102140150 words, keeping 687405 word types
# PROGRESS: at sentence #5120000, processed 102340067 words, keeping 687405 word types
# PROGRESS: at sentence #5130000, processed 102539904 words, keeping 687405 word types
# PROGRESS: at sentence #5140000, processed 102739801 words, keeping 687405 word types
# PROGRESS: at sentence #5150000, processed 102939727 words, keeping 687405 word types
# PROGRESS: at sentence #5160000, processed 103139582 words, keeping 687405 word types
# PROGRESS: at sentence #5170000, processed 103339507 words, keeping 687405 word types
# PROGRESS: at sentence #5180000, processed 103539360 words, keeping 687405 word types
# PROGRESS: at sentence #5190000, processed 103739188 words, keeping 687405 word types
# PROGRESS: at sentence #5200000, processed 103939051 words, keeping 687405 word types
# PROGRESS: at sentence #5210000, processed 104138951 words, keeping 687405 word types
# PROGRESS: at sentence #5220000, processed 104338897 words, keeping 687405 word types
# PROGRESS: at sentence #5230000, processed 104538774 words, keeping 687405 word types
# PROGRESS: at sentence #5240000, processed 104738622 words, keeping 687405 word types
# PROGRESS: at sentence #5250000, processed 104938500 words, keeping 687405 word types
# PROGRESS: at sentence #5260000, processed 105138380 words, keeping 687405 word types
# PROGRESS: at sentence #5270000, processed 105338263 words, keeping 687405 word types
# PROGRESS: at sentence #5280000, processed 105538081 words, keeping 687405 word types
# PROGRESS: at sentence #5290000, processed 105737995 words, keeping 687405 word types
# PROGRESS: at sentence #5300000, processed 105937872 words, keeping 687405 word types
# PROGRESS: at sentence #5310000, processed 106137763 words, keeping 687405 word types
# PROGRESS: at sentence #5320000, processed 106337662 words, keeping 687405 word types
# PROGRESS: at sentence #5330000, processed 106537582 words, keeping 687405 word types
# PROGRESS: at sentence #5340000, processed 106737460 words, keeping 687405 word types
# PROGRESS: at sentence #5350000, processed 106937366 words, keeping 687405 word types
# PROGRESS: at sentence #5360000, processed 107137283 words, keeping 687405 word types
# PROGRESS: at sentence #5370000, processed 107337102 words, keeping 687405 word types
# PROGRESS: at sentence #5380000, processed 107536912 words, keeping 687405 word types
# PROGRESS: at sentence #5390000, processed 107736783 words, keeping 687405 word types
# PROGRESS: at sentence #5400000, processed 107936629 words, keeping 687405 word types
# PROGRESS: at sentence #5410000, processed 108136506 words, keeping 687405 word types
# PROGRESS: at sentence #5420000, processed 108336415 words, keeping 687405 word types
# PROGRESS: at sentence #5430000, processed 108536276 words, keeping 687405 word types
# PROGRESS: at sentence #5440000, processed 108736044 words, keeping 687405 word types
# PROGRESS: at sentence #5450000, processed 108935937 words, keeping 687405 word types
# PROGRESS: at sentence #5460000, processed 109135761 words, keeping 687405 word types
# PROGRESS: at sentence #5470000, processed 109335680 words, keeping 687405 word types
# PROGRESS: at sentence #5480000, processed 109535612 words, keeping 687405 word types
# PROGRESS: at sentence #5490000, processed 109735505 words, keeping 687405 word types
# PROGRESS: at sentence #5500000, processed 109935409 words, keeping 687405 word types
# PROGRESS: at sentence #5510000, processed 110135364 words, keeping 687405 word types
# PROGRESS: at sentence #5520000, processed 110335265 words, keeping 687405 word types
# PROGRESS: at sentence #5530000, processed 110535182 words, keeping 687405 word types
# PROGRESS: at sentence #5540000, processed 110735030 words, keeping 687405 word types
# PROGRESS: at sentence #5550000, processed 110934897 words, keeping 687405 word types
# PROGRESS: at sentence #5560000, processed 111134803 words, keeping 687405 word types
# PROGRESS: at sentence #5570000, processed 111334714 words, keeping 687405 word types
# PROGRESS: at sentence #5580000, processed 111534632 words, keeping 687405 word types
# PROGRESS: at sentence #5590000, processed 111734526 words, keeping 687405 word types
# PROGRESS: at sentence #5600000, processed 111934424 words, keeping 687405 word types
# PROGRESS: at sentence #5610000, processed 112134269 words, keeping 687405 word types
# PROGRESS: at sentence #5620000, processed 112334120 words, keeping 687405 word types
# PROGRESS: at sentence #5630000, processed 112534032 words, keeping 687405 word types
# PROGRESS: at sentence #5640000, processed 112733937 words, keeping 687405 word types
# PROGRESS: at sentence #5650000, processed 112933853 words, keeping 687405 word types
# PROGRESS: at sentence #5660000, processed 113133755 words, keeping 687405 word types
# PROGRESS: at sentence #5670000, processed 113333631 words, keeping 687405 word types
# PROGRESS: at sentence #5680000, processed 113533545 words, keeping 687405 word types
# PROGRESS: at sentence #5690000, processed 113733436 words, keeping 687405 word types
# PROGRESS: at sentence #5700000, processed 113933333 words, keeping 687405 word types
# PROGRESS: at sentence #5710000, processed 114133173 words, keeping 687405 word types
# ...
# EPOCH 3 - PROGRESS: at 50.97% examples, 1009340 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 51.78% examples, 1009602 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 52.53% examples, 1008937 words/s, in_qsize 8, out_qsize 3
# EPOCH 3 - PROGRESS: at 53.20% examples, 1006485 words/s, in_qsize 8, out_qsize 2
# EPOCH 3 - PROGRESS: at 53.86% examples, 1004107 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 54.75% examples, 1006071 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 55.47% examples, 1004991 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 56.14% examples, 1002814 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 57.03% examples, 1004922 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 57.93% examples, 1007127 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 58.82% examples, 1008916 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 59.69% examples, 1010603 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 60.47% examples, 1010595 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 61.36% examples, 1012440 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 62.27% examples, 1014274 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 63.21% examples, 1016888 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 64.10% examples, 1018562 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 65.01% examples, 1020458 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 65.79% examples, 1020426 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 66.51% examples, 1019584 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 67.39% examples, 1020958 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 68.24% examples, 1021890 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 68.89% examples, 1019794 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 69.75% examples, 1020848 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 70.59% examples, 1021641 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 71.38% examples, 1021831 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 72.01% examples, 1019458 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 72.68% examples, 1017812 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 73.33% examples, 1015767 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 74.20% examples, 1016994 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 74.95% examples, 1016323 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 75.60% examples, 1014493 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 76.47% examples, 1015552 words/s, in_qsize 8, out_qsize 3
# EPOCH 3 - PROGRESS: at 77.27% examples, 1015547 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 78.11% examples, 1016179 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 79.02% examples, 1017920 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 79.76% examples, 1016939 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 80.54% examples, 1016651 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 81.31% examples, 1016567 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 82.21% examples, 1017978 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 83.01% examples, 1018088 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 83.84% examples, 1018569 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 84.60% examples, 1018233 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 85.27% examples, 1016617 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 86.11% examples, 1017198 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 86.97% examples, 1018021 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 87.84% examples, 1018861 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 88.57% examples, 1018178 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 89.27% examples, 1017141 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 90.17% examples, 1018448 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 91.07% examples, 1019739 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 91.75% examples, 1018376 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 92.43% examples, 1017199 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 93.12% examples, 1016186 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 94.02% examples, 1017503 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 94.91% examples, 1018582 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 95.59% examples, 1017352 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 96.26% examples, 1015964 words/s, in_qsize 8, out_qsize 3
# EPOCH 3 - PROGRESS: at 96.91% examples, 1014215 words/s, in_qsize 7, out_qsize 3
# EPOCH 3 - PROGRESS: at 97.64% examples, 1013651 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 98.35% examples, 1012983 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 99.24% examples, 1014123 words/s, in_qsize 7, out_qsize 0
# EPOCH 3: training on 130526612 raw words (130526612 effective words) took 128.6s, 1015267 effective words/s
# EPOCH 4 - PROGRESS: at 0.66% examples, 847942 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 1.49% examples, 959167 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 2.39% examples, 1027322 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 3.28% examples, 1059959 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 4.16% examples, 1078194 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 4.88% examples, 1054522 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 5.66% examples, 1048072 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 6.55% examples, 1061610 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 7.43% examples, 1070235 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 8.32% examples, 1077976 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 9.10% examples, 1069806 words/s, in_qsize 8, out_qsize 2
# EPOCH 4 - PROGRESS: at 9.87% examples, 1062944 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 10.59% examples, 1052838 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 11.44% examples, 1056476 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 12.54% examples, 1081609 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 13.33% examples, 1076794 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 14.01% examples, 1063795 words/s, in_qsize 8, out_qsize 3
# EPOCH 4 - PROGRESS: at 14.82% examples, 1063047 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 15.50% examples, 1053821 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 16.26% examples, 1050313 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 17.21% examples, 1058689 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 18.03% examples, 1058610 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 18.73% examples, 1051979 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 19.60% examples, 1055049 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 20.49% examples, 1059396 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 21.39% examples, 1063222 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 22.26% examples, 1064897 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 22.91% examples, 1056737 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 23.58% examples, 1049472 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 24.27% examples, 1044387 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 25.17% examples, 1047950 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 26.06% examples, 1051229 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 26.95% examples, 1054284 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 27.75% examples, 1053191 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 28.53% examples, 1051678 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 29.30% examples, 1049236 words/s, in_qsize 8, out_qsize 2
# EPOCH 4 - PROGRESS: at 30.00% examples, 1045486 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 30.83% examples, 1046399 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 31.66% examples, 1047066 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 32.30% examples, 1041116 words/s, in_qsize 7, out_qsize 3
# EPOCH 4 - PROGRESS: at 32.98% examples, 1036999 words/s, in_qsize 8, out_qsize 2
# EPOCH 4 - PROGRESS: at 33.71% examples, 1034916 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 34.58% examples, 1037035 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 35.45% examples, 1039167 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 36.18% examples, 1037190 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 37.02% examples, 1038065 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 37.89% examples, 1040102 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 38.75% examples, 1041675 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 39.60% examples, 1042939 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 40.48% examples, 1044981 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 41.33% examples, 1046243 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 42.12% examples, 1045494 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 42.80% examples, 1042439 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 43.68% examples, 1043882 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 44.48% examples, 1043489 words/s, in_qsize 8, out_qsize 3
# EPOCH 4 - PROGRESS: at 45.21% examples, 1041204 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 45.90% examples, 1038614 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 46.71% examples, 1038797 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 47.57% examples, 1040310 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 48.25% examples, 1037582 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 49.04% examples, 1036709 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 49.82% examples, 1036240 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 50.64% examples, 1036771 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 51.32% examples, 1034268 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 52.19% examples, 1035712 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 52.88% examples, 1033583 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 53.66% examples, 1033035 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 54.35% examples, 1030517 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 55.10% examples, 1029704 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 55.99% examples, 1031405 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 56.83% examples, 1031943 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 57.54% examples, 1030386 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 58.20% examples, 1027883 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 58.97% examples, 1027474 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 59.75% examples, 1027070 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 60.61% examples, 1028269 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 61.49% examples, 1029741 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 62.37% examples, 1031177 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 63.25% examples, 1032408 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 64.12% examples, 1033651 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 64.87% examples, 1032830 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 65.70% examples, 1033291 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 66.45% examples, 1032548 words/s, in_qsize 8, out_qsize 3
# EPOCH 4 - PROGRESS: at 67.22% examples, 1032239 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 68.02% examples, 1032370 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 68.86% examples, 1032976 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 69.57% examples, 1031521 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 70.43% examples, 1032468 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 71.33% examples, 1033910 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 72.22% examples, 1035199 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 73.10% examples, 1036299 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 73.76% examples, 1034252 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 74.41% examples, 1032148 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 75.27% examples, 1033009 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 76.12% examples, 1033730 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 76.78% examples, 1031833 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 77.49% examples, 1030636 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 78.30% examples, 1030902 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 79.10% examples, 1030838 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 79.90% examples, 1030978 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 80.80% examples, 1032274 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 81.60% examples, 1032430 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 82.27% examples, 1030865 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 83.02% examples, 1030153 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 83.79% examples, 1029773 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 84.64% examples, 1030311 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 85.49% examples, 1031097 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 86.38% examples, 1032211 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 87.27% examples, 1033317 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 88.10% examples, 1033513 words/s, in_qsize 7, out_qsize 2
# EPOCH 4 - PROGRESS: at 88.96% examples, 1034342 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 89.70% examples, 1033765 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 90.41% examples, 1032644 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 91.10% examples, 1031470 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 91.98% examples, 1032458 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 92.67% examples, 1031305 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 93.55% examples, 1032337 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 94.46% examples, 1033301 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 95.33% examples, 1034138 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 96.19% examples, 1034794 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 97.11% examples, 1036030 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 97.88% examples, 1035544 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 98.68% examples, 1035458 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 99.53% examples, 1036118 words/s, in_qsize 6, out_qsize 1
# EPOCH 4: training on 130526612 raw words (130526612 effective words) took 126.0s, 1035667 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 652633060 raw words (652633060 effective words) took 632.4s, 1032075 effective words/s', 'datetime': '2023-08-21T18:14:56.795495', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=1761276, vector_size=32, alpha=0.025>', 'datetime': '2023-08-21T18:14:56.796012', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
magnitudes = []
for osmid in osm_nodes['osmidstr']:
    if osmid in model_node.wv:
        vec = model_node.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_nodes['magnitude'] = magnitudes
# Layer(osm_nodes_3310[osm_nodes_3310['magnitude'] > 0], color_continuous_style('magnitude'))


magnitudes = []
osm_edges['u-v'] = osm_edges['u'].astype(str) + '-' + osm_edges['v'].astype(str)
for osmid in osm_edges['u-v']:
    if osmid in model_edge.wv:
        vec = model_edge.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_edges['magnitude'] = magnitudes
# Layer(osm_edges_3310[osm_edges_3310['magnitude'] > 0], color_continuous_style('magnitude'))

# %%
# ftest_edges = osm_edges_3310[osm_edges_3310['magnitude'] > 0].copy()
# ftest_edges['bx'] = ftest_edges.geometry.centroid.x
# ftest_edges['by'] = ftest_edges.geometry.centroid.y

# house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
# house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
# house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# vectors = []
# for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
#     iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
#                 (ftest_edges['bx'] < item['bx'] + 500) & 
#                 (ftest_edges['by'] > item['by'] - 500) & 
#                 (ftest_edges['by'] < item['by'] + 500)]
    
#     jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
#     vec = model.wv[jtem['u-v']]
#     vectors.append(vec)

# %%
ftest_nodes = osm_nodes[osm_nodes['magnitude'] > 0].to_crs('epsg:3310')
ftest_nodes['bx'] = ftest_nodes.geometry.centroid.x
ftest_nodes['by'] = ftest_nodes.geometry.centroid.y
fosmid2geo = {osmid:geo for osmid, geo in zip(ftest_nodes['osmidstr'], ftest_nodes['geometry'])}

ftest_edges = osm_edges[osm_edges['magnitude'] > 0].to_crs('epsg:3310')
ftest_edges['bx'] = ftest_edges.geometry.centroid.x
ftest_edges['by'] = ftest_edges.geometry.centroid.y

house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# %%
vectors = []
geos = []
for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
    iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
                                (ftest_edges['bx'] < item['bx'] + 500) & 
                                (ftest_edges['by'] > item['by'] - 500) & 
                                (ftest_edges['by'] < item['by'] + 500)]
    if len(iftest_edges) == 0:
        iftest_edges = ftest_edges
    
    
    jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
    u, v = str(jtem['u']), str(jtem['v'])
    vec_u, vec_v = model_node.wv[u], model_node.wv[v]
    dist_u, dist_v = item.geometry.distance(fosmid2geo[u]), item.geometry.distance(fosmid2geo[v])
    ratios = np.array([1/dist_u, 1/dist_v])
    ratios /= np.sum(ratios)
    
    
    vec = vec_u*ratios[0] + vec_v*ratios[1]
    vectors.append(vec)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 21608/21608 [01:38<00:00, 218.44it/s]

# %%
np.save(f'{dname}/road2vec_n2v_32_nodes.npy', vectors)

# %%
house_gdf_3310 = house_gdf.to_crs('epsg:3310')
thouse_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
n2v_vectors = np.array(vectors)
n2v_vectors_train = n2v_vectors[:len(thouse_gdf_3310)]

# %%
train_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
dist_mat = []
for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    mdist1 = np.linalg.norm(n2v_vectors[i] - n2v_vectors_train, axis=-1)
    mdist1 /= mdist1.std()
    #dist_mat.append(mdist1)
    mdist2 = train_gdf_3310.distance(item.geometry).values
    mdist2 /= mdist2.std()
    dist_mat.append(mdist1 + mdist2*10)
dist_mat = np.stack(dist_mat, 0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 21608/21608 [01:43<00:00, 209.27it/s]

# %%
j=100
ahgdf = train_gdf.copy()
ahgdf['diststr'] = dist_mat[j]

# %%
Map([
#     Layer(fhgdf, color_continuous_style('diststr', palette='sunset')),
#     Layer(gdf.iloc[data_ori['idx_geo'][j]], color_continuous_style('price', palette='sunset'))
    Layer(ahgdf.iloc[dist_mat[j].argsort()[1:61]], color_continuous_style('diststr', palette='sunset')),
    Layer(house_gdf.iloc[[j]], basic_style(color='green')),

])
# Out:
# /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/cartoframes/utils/utils.py:552: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   parameter_args = inspect.getargspec(decorated_function).args
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;diststr&quot;
#                 description=&quot;&quot;>
#                 <as-legend-color-continuous id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {

# %%
new_idx = []
new_dist_eucli = []
new_dist_geo = []

for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    target = item.values[:-1]
    candidates = thouse_gdf_3310.iloc[dist_mat[i].argsort()[1:61]].values[:, :-1]
    new_idx.append(dist_mat[i].argsort()[1:61])
    new_dist_geo.append(dist_mat[i][dist_mat[i].argsort()[1:61]])
    new_dist_eucli.append(np.linalg.norm(target.astype(float) - candidates.astype(float), axis=-1))
    
new_idx = np.stack(new_idx, 0)
new_dist_eucli = np.stack(new_dist_eucli, 0)
new_dist_geo = np.stack(new_dist_geo, 0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 21608/21608 [01:31<00:00, 235.36it/s]

# %%
newdata = dict() 
newdata['X_train'] = data['X_train']
newdata['y_train'] = data['y_train']
newdata['X_test'] = data['X_test']
newdata['y_test'] = data['y_test']
newdata['idx_eucli'] = new_idx
newdata['idx_geo'] = new_idx
newdata['dist_eucli'] = new_dist_eucli
newdata['dist_geo'] = new_dist_geo

# %%
dname
# Out:
# 'kc'

# %%
np.savez(f'{dname}/data_n2v_nodes.npz', **newdata)

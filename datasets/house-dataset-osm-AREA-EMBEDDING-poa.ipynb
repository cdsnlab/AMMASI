# %%
import os, tqdm

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = (label == label) & (pred == pred)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        
        rmse = np.square(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        
        mape = np.divide(mae, label)
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape*mask)
        
        print('masked:', np.sum(mask == 0))
    return male, rmse, mape

# %%
os.listdir('.')
# Out:
# ['house-dataset-osm-road2vec-poa.ipynb',
#  'house-dataset-feat-kde-fc-kc-poa-sp.ipynb',
#  'mygeometries.py',
#  'house-dataset-osm-neighbor-sp.ipynb',
#  'house-dataset-osm-neighbor-kc-process.ipynb',
#  '.ipynb_checkpoints',
#  'brazil_data',
#  'osmnx-1.3.0.zip',
#  'house-dataset-feat-kde-fc-kc-poa-sp-mapviz.html',
#  'house-dataset-feat-kde-fc-kc-poa-sp-mapviz.ipynb',
#  'house-dataset-osm-AREA-EMBEDDING-sp.ipynb',
#  'house-dataset-osm-road2vec-kc-POI-extraction.ipynb',
#  'house-dataset-osm-sp-NodeEmbedding.ipynb',
#  'house-dataset-osm-poa-NodeEmbedding.ipynb',
#  'house-dataset-osm-AREA-EMBEDDING-kc.ipynb',
#  'house-dataset-osm-road2vec-sp-POI-extraction.ipynb',
#  'house-dataset-POI-sp.ipynb',
#  'house-dataset-osm-neighbor-kc-process-Copy1.ipynb',
#  'house-dataset-osm-kc-NodeEmbedding.ipynb',
#  'osm_poi',
#  'generateSE.py',
#  'house-dataset-feat-kde+gaussianem_important-datagen-same-cluster.ipynb',
#  'house-dataset-osm-road2vec-fc-POI-extraction.ipynb',
#  'test-neighbor-mean-value.ipynb',
#  'house-dataset-osm-road2vec-fc-RoadDistance.ipynb',
#  'sp',
#  'house-dataset-feat-kde+gaussianem_important-datagen-same-cluster-datagen.ipynb',
#  'house-dataset-feat-kde+gaussianem_important-datagen.ipynb',
#  'house-dataset-osm-neighbor-fc-process-waterfront.ipynb',
#  'census_block',
#  'node2vec.py',
#  '.gitkeep ',
#  'poa',
#  'house-dataset-feat-kde+gaussianem_important.ipynb',
#  'house-dataset-osm-road2vec-kc-RoadDistance.ipynb',
#  'fc',
#  'house-dataset-osm-AREA-EMBEDDING-poa.ipynb',
#  'house-dataset-osm-neighbor-kc.ipynb',
#  'kc',
#  'house-dataset-osm-AREA-EMBEDDING-fc.ipynb',
#  'house-dataset-osm-road2vec-poa-POI-extraction.ipynb',
#  'house-dataset-osm-neighbor-fc-process-Copy1.ipynb',
#  'house-dataset-osm-neighbor-fc-process.ipynb',
#  'house-dataset-osm-neighbor-poa.ipynb',
#  'house-dataset-POI-poa.ipynb',
#  'house-dataset-feat-kde-fc-kc-poa-sp.html',
#  'house-dataset-feat-kde-fc-kc-poa-sp-nolatlon.ipynb',
#  'processed',
#  'house-dataset-osm-road2vec-fc-POI-viz.ipynb',
#  'house-dataset-osm-road2vec-kc.ipynb',
#  'house-dataset-osm-neighbor-fc.ipynb',
#  'hereosmnx',
#  'house-dataset-POI-kc.ipynb',
#  '__pycache__',
#  'house-dataset-osm-neighbor-kc-process-waterfront.ipynb',
#  'house-dataset-osm-fc-NodeEmbedding.ipynb',
#  'house-dataset-feat-norm-fc-kc-poa-sp.ipynb',
#  'house-dataset-osm-road2vec-sp.ipynb',
#  'osmdata',
#  'boundary',
#  'house-dataset-POI-fc.ipynb',
#  'myosmnx',
#  'cache']

# %%
import numpy as np

# %%
streetmap = {
    'style': 'mapbox://styles/mapbox/streets-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}
mybasemap = {
    #'style': 'mapbox://styles/mapbox/streets-v9',
    'style': 'mapbox://styles/mapbox/satellite-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}

# %%
from cartoframes.viz import *
# Out:
# Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
dname = 'poa'

# %%
print(dname)
data = np.load(f'{dname}/data.npz')

dict1 = {'lat':data['X_train'][:,0], 'lng': data['X_train'][:,1], 'price': data['y_train']}
dict2 = {'lat':data['X_test'][:,0], 'lng': data['X_test'][:,1], 'price': data['y_test']}
attr_names = []
for a in range(2, data['X_train'].shape[1]):
    dict1.update({f'attr{a-2}': data['X_train'][:, a]})
    dict2.update({f'attr{a-2}': data['X_test'][:, a]})
    attr_names.append(f'attr{a-2}')
df1 = pd.DataFrame(dict1)
df2 = pd.DataFrame(dict2)
df = pd.concat([df1, df2])

train_gdf = gpd.GeoDataFrame(df1.copy(), geometry=gpd.points_from_xy(x=df1.lng, y=df1.lat))
train_gdf.crs = 'EPSG:4326'
test_gdf = gpd.GeoDataFrame(df2.copy(), geometry=gpd.points_from_xy(x=df2.lng, y=df2.lat))
test_gdf.crs = 'EPSG:4326'
house_gdf = gpd.GeoDataFrame(df.copy(), geometry=gpd.points_from_xy(x=df.lng, y=df.lat))
house_gdf.crs = 'EPSG:4326'
#print(np.exp(df['price'].values).mean())
gdf = house_gdf
for attr in attr_names:
    print(attr, gdf[attr].nunique())
    if gdf[attr].nunique() < 30:
        gdf[attr] = gdf[attr].astype(str)
gdfcpy = gdf.copy()


#     display(Map(
#         [
#             Layer(gdfcpy, color_category_style(tattr, cat=cat, palette='cb_blues'), encode_data=False),
#             Layer(gdf, color_continuous_style('price', palette='sunset'), encode_data=False),
#         ],
#         basemap=mybasemap))
# Out:
# poa
# attr0 9
# attr1 2644
# attr2 10
# attr3 2
# attr4 2

# %%
import osmnx as ox
from shapely.geometry import *

if not os.path.isdir('osmdata'):
    os.mkdir('osmdata')
    
DATASET_NAME = dname
OSM_FILE_PATH = f'osmdata/{DATASET_NAME}.graphml'

from shapely.geometry import MultiPoint


x1, y1, x2, y2 = gdf.total_bounds

house_center_latitude = (y1 + y2)/2 #sensor_hull.centroid.y
house_center_longitude = (x1 + x2)/2 #sensor_hull.centroid.x

     
graphs = dict()
# retrieve the street network for the location
if not os.path.isfile(OSM_FILE_PATH):
    center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
    center_point.crs = 'epsg:4326'
    center_point = center_point.to_crs('epsg:3310')
    max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
    print('max_distance:', max_distance)
    graph = ox.graph_from_point((house_center_latitude, house_center_longitude), dist=max_distance)

    # save the street network to a shapefile
    ox.save_graphml(graph, filepath=OSM_FILE_PATH)
else:
    graph = ox.load_graphml(filepath=OSM_FILE_PATH)
    

# buildings = buildings.reset_index()
# buildings.geometry = buildings.geometry.centroid

# %%
osm_nodes, osm_edges = ox.graph_to_gdfs(graph)

# %%
osm_nodes['osmidn'] = osm_nodes.index
osm_nodes['osmidstr'] = osm_nodes['osmidn'].astype(str)
osm_edges = osm_edges.reset_index()
cond = np.array([str(type(s)) for s in osm_edges['highway']]) == "<class 'str'>"
osm_edges = osm_edges[cond]

# %%
alist = osm_nodes.geometry.tolist()

# %%
np.random.shuffle(alist)

# %%
house_gdf.unary_union
# Out:
# <MULTIPOINT (-51.269 -29.985, -51.264 -30.121, -51.264 -30.105, -51.264 -30....>

# %%
house_gdf.unary_union.convex_hull
# Out:
# <POLYGON ((-51.062 -30.232, -51.175 -30.215, -51.19 -30.211, -51.239 -30.189...>

# %%
fosm_edges = osm_edges[osm_edges.intersects(house_gdf.unary_union.convex_hull)]

# %%
len(set(fosm_edges['u'].unique().tolist() + fosm_edges['v'].unique().tolist()))
# Out:
# 46984

# %%
fosm_node_list = list(set(fosm_edges['u'].unique().tolist() + fosm_edges['v'].unique().tolist()))

# %%
minx, miny, maxx, maxy = house_gdf.total_bounds + np.array([-0.01, -0.01, +0.01, +0.01])
ncols = 100
nrows = int(ncols * (maxy - miny) / (maxx - minx) * 1.2)

# %%
nwidth = (maxx - minx) / ncols
nheight = (maxy - miny) / nrows

# %%
gpd.GeoDataFrame(geometry=[box(minx, miny, maxx, maxy)]).to_file(f'boundary/{dname}_boundary.geojson', driver='GeoJSON')

# %%
minx, miny, maxx, maxy = house_gdf.total_bounds + np.array([-0.01, -0.01, +0.01, +0.01])
ncols = 100
nrows = 100 #int(ncols * (maxy - miny) / (maxx - minx) * 1.2)
nwidth = (maxx - minx) / ncols
nheight = (maxy - miny) / nrows
#(maxy - miny) / (maxx - minx)

from shapely import box
geos = []
for j in range(nrows):
    for i in range(ncols):
        x1 = minx + nwidth*i
        x2 = minx + nwidth*(i+1)
        y1 = miny + nheight*j
        y2 = miny + nheight*(j+1)
        
        geos.append(box(x1, y1, x2, y2))
        
grid_gdf = gpd.GeoDataFrame(geometry=geos)

fosm_edges = osm_edges[osm_edges.intersects(box(minx, miny, maxx, maxy))]

grid_num = len(grid_gdf)

###############
import tqdm
adj_mx = np.zeros((grid_num, grid_num))
for road_geo in tqdm.tqdm(fosm_edges.geometry, total=len(fosm_edges)):
    connect_list = grid_gdf[grid_gdf.intersects(road_geo)].index
    for i in range(len(connect_list)):
        for j in range(i+1, len(connect_list)):
            ii = connect_list[i]
            jj = connect_list[j]
            adj_mx[jj, ii] += 1
            
            
##############

import node2vec
import numpy as np
import networkx as nx
from gensim.models import Word2Vec

with open(f'{dname}/Adj-grid.txt', 'w') as fp:
    for i in range(grid_num):
        for j in range(grid_num):
            if adj_mx[i, j] > 0:
                fp.write(f'{i} {j} {adj_mx[i, j]}\n')

def read_graph(edgelist):
    G = nx.read_edgelist(
        edgelist, nodetype=str, data=(('weight',float),),
        create_using=nx.DiGraph())
    return G

Adj_file = f'{dname}/Adj-grid.txt'
nx_G = read_graph(Adj_file)

num_walks = 1000
walk_length = 20
p = 1000
q = 1
is_directed = True

G = node2vec.Graph(nx_G, is_directed, p, q)
G.preprocess_transition_probs()
node2vec_walks = G.simulate_walks(num_walks, walk_length)



from gensim.models import Word2Vec

vector_size = 64
sentences = node2vec_walks
model_node = Word2Vec(sentences, window=7, min_count=0, workers=64, vector_size=vector_size)


vectors = []
for gid in range(grid_num):
    gid = str(gid)
    if gid in model_node.wv:
        vectors.append(model_node.wv[gid])
    else:
        vectors.append(np.zeros(vector_size))
vectors = np.array(vectors)
np.save(f'{dname}/grid_vectors.npy', vectors)
# Out:
# 100%|█████████████████████████████████| 125088/125088 [01:46<00:00, 1177.97it/s]
# Walk iteration:
# 1 / 1000
# 2 / 1000
# 3 / 1000
# 4 / 1000
# 5 / 1000
# 6 / 1000
# 7 / 1000
# 8 / 1000
# 9 / 1000
# 10 / 1000
# 11 / 1000
# 12 / 1000
# 13 / 1000
# 14 / 1000
# 15 / 1000
# 16 / 1000
# 17 / 1000
# 18 / 1000
# 19 / 1000
# 20 / 1000
# 21 / 1000
# 22 / 1000
# 23 / 1000
# 24 / 1000
# 25 / 1000
# 26 / 1000
# 27 / 1000
# 28 / 1000
# 29 / 1000
# 30 / 1000
# 31 / 1000
# 32 / 1000
# 33 / 1000
# 34 / 1000
# 35 / 1000
# 36 / 1000
# 37 / 1000
# 38 / 1000
# 39 / 1000
# 40 / 1000
# 41 / 1000
# 42 / 1000
# 43 / 1000
# 44 / 1000
# 45 / 1000
# 46 / 1000
# 47 / 1000
# 48 / 1000
# 49 / 1000
# 50 / 1000
# 51 / 1000
# 52 / 1000
# 53 / 1000
# 54 / 1000
# 55 / 1000
# 56 / 1000
# 57 / 1000
# 58 / 1000
# 59 / 1000
# 60 / 1000
# 61 / 1000
# 62 / 1000
# 63 / 1000
# 64 / 1000
# 65 / 1000
# 66 / 1000
# 67 / 1000
# 68 / 1000
# 69 / 1000
# 70 / 1000
# 71 / 1000
# 72 / 1000
# 73 / 1000
# 74 / 1000
# 75 / 1000
# 76 / 1000
# 77 / 1000
# 78 / 1000
# 79 / 1000
# 80 / 1000
# 81 / 1000
# 82 / 1000
# 83 / 1000
# 84 / 1000
# 85 / 1000
# 86 / 1000
# 87 / 1000
# 88 / 1000
# 89 / 1000
# 90 / 1000
# 91 / 1000
# 92 / 1000
# 93 / 1000
# 94 / 1000
# 95 / 1000
# 96 / 1000
# 97 / 1000
# 98 / 1000
# 99 / 1000
# 100 / 1000
# 101 / 1000
# 102 / 1000
# 103 / 1000
# 104 / 1000
# 105 / 1000
# 106 / 1000
# 107 / 1000
# 108 / 1000
# 109 / 1000
# 110 / 1000
# 111 / 1000
# 112 / 1000
# 113 / 1000
# 114 / 1000
# 115 / 1000
# 116 / 1000
# 117 / 1000
# 118 / 1000
# 119 / 1000
# 120 / 1000
# 121 / 1000
# 122 / 1000
# 123 / 1000
# 124 / 1000
# 125 / 1000
# 126 / 1000
# 127 / 1000
# 128 / 1000
# 129 / 1000
# 130 / 1000
# 131 / 1000
# 132 / 1000
# 133 / 1000
# 134 / 1000
# 135 / 1000
# 136 / 1000
# 137 / 1000
# 138 / 1000
# 139 / 1000
# 140 / 1000
# 141 / 1000
# 142 / 1000
# 143 / 1000
# 144 / 1000
# 145 / 1000
# 146 / 1000
# 147 / 1000
# 148 / 1000
# 149 / 1000
# 150 / 1000
# 151 / 1000
# 152 / 1000
# 153 / 1000
# 154 / 1000
# 155 / 1000
# 156 / 1000
# 157 / 1000
# 158 / 1000
# 159 / 1000
# 160 / 1000
# 161 / 1000
# 162 / 1000
# 163 / 1000
# 164 / 1000
# 165 / 1000
# 166 / 1000
# 167 / 1000
# 168 / 1000
# 169 / 1000
# 170 / 1000
# 171 / 1000
# 172 / 1000
# 173 / 1000
# 174 / 1000
# 175 / 1000
# 176 / 1000
# 177 / 1000
# 178 / 1000
# 179 / 1000
# 180 / 1000
# 181 / 1000
# 182 / 1000
# 183 / 1000
# 184 / 1000
# 185 / 1000
# 186 / 1000
# 187 / 1000
# 188 / 1000
# 189 / 1000
# 190 / 1000
# 191 / 1000
# 192 / 1000
# 193 / 1000
# 194 / 1000
# 195 / 1000
# 196 / 1000
# 197 / 1000
# 198 / 1000
# 199 / 1000
# 200 / 1000
# 201 / 1000
# 202 / 1000
# 203 / 1000
# 204 / 1000
# 205 / 1000
# 206 / 1000
# 207 / 1000
# 208 / 1000
# 209 / 1000
# 210 / 1000
# 211 / 1000
# 212 / 1000
# 213 / 1000
# 214 / 1000
# 215 / 1000
# 216 / 1000
# 217 / 1000
# 218 / 1000
# 219 / 1000
# 220 / 1000
# 221 / 1000
# 222 / 1000
# 223 / 1000
# 224 / 1000
# 225 / 1000
# 226 / 1000
# 227 / 1000
# 228 / 1000
# 229 / 1000
# 230 / 1000
# 231 / 1000
# 232 / 1000
# 233 / 1000
# 234 / 1000
# 235 / 1000
# 236 / 1000
# 237 / 1000
# 238 / 1000
# 239 / 1000
# 240 / 1000
# 241 / 1000
# 242 / 1000
# 243 / 1000
# 244 / 1000
# 245 / 1000
# 246 / 1000
# 247 / 1000
# 248 / 1000
# 249 / 1000
# 250 / 1000
# 251 / 1000
# 252 / 1000
# 253 / 1000
# 254 / 1000
# 255 / 1000
# 256 / 1000
# 257 / 1000
# 258 / 1000
# 259 / 1000
# 260 / 1000
# 261 / 1000
# 262 / 1000
# 263 / 1000
# 264 / 1000
# 265 / 1000
# 266 / 1000
# 267 / 1000
# 268 / 1000
# 269 / 1000
# 270 / 1000
# 271 / 1000
# 272 / 1000
# 273 / 1000
# 274 / 1000
# 275 / 1000
# 276 / 1000
# 277 / 1000
# 278 / 1000
# 279 / 1000
# 280 / 1000
# 281 / 1000
# 282 / 1000
# 283 / 1000
# 284 / 1000
# 285 / 1000
# 286 / 1000
# 287 / 1000
# 288 / 1000
# 289 / 1000
# 290 / 1000
# 291 / 1000
# 292 / 1000
# 293 / 1000
# 294 / 1000
# 295 / 1000
# 296 / 1000
# 297 / 1000
# 298 / 1000
# 299 / 1000
# 300 / 1000
# 301 / 1000
# 302 / 1000
# 303 / 1000
# 304 / 1000
# 305 / 1000
# 306 / 1000
# 307 / 1000
# 308 / 1000
# 309 / 1000
# 310 / 1000
# 311 / 1000
# 312 / 1000
# 313 / 1000
# 314 / 1000
# 315 / 1000
# 316 / 1000
# 317 / 1000
# 318 / 1000
# 319 / 1000
# 320 / 1000
# 321 / 1000
# 322 / 1000
# 323 / 1000
# 324 / 1000
# 325 / 1000
# 326 / 1000
# 327 / 1000
# 328 / 1000
# 329 / 1000
# 330 / 1000
# 331 / 1000
# 332 / 1000
# 333 / 1000
# 334 / 1000
# 335 / 1000
# 336 / 1000
# 337 / 1000
# 338 / 1000
# 339 / 1000
# 340 / 1000
# 341 / 1000
# 342 / 1000
# 343 / 1000
# 344 / 1000
# 345 / 1000
# 346 / 1000
# 347 / 1000
# 348 / 1000
# 349 / 1000
# 350 / 1000
# 351 / 1000
# 352 / 1000
# 353 / 1000
# 354 / 1000
# 355 / 1000
# 356 / 1000
# 357 / 1000
# 358 / 1000
# 359 / 1000
# 360 / 1000
# 361 / 1000
# 362 / 1000
# 363 / 1000
# 364 / 1000
# 365 / 1000
# 366 / 1000
# 367 / 1000
# 368 / 1000
# 369 / 1000
# 370 / 1000
# 371 / 1000
# 372 / 1000
# 373 / 1000
# 374 / 1000
# 375 / 1000
# 376 / 1000
# 377 / 1000
# 378 / 1000
# 379 / 1000
# 380 / 1000
# 381 / 1000
# 382 / 1000
# 383 / 1000
# 384 / 1000
# 385 / 1000
# 386 / 1000
# 387 / 1000
# 388 / 1000
# 389 / 1000
# 390 / 1000
# 391 / 1000
# 392 / 1000
# 393 / 1000
# 394 / 1000
# 395 / 1000
# 396 / 1000
# 397 / 1000
# 398 / 1000
# 399 / 1000
# 400 / 1000
# 401 / 1000
# 402 / 1000
# 403 / 1000
# 404 / 1000
# 405 / 1000
# 406 / 1000
# 407 / 1000
# 408 / 1000
# 409 / 1000
# 410 / 1000
# 411 / 1000
# 412 / 1000
# 413 / 1000
# 414 / 1000
# 415 / 1000
# 416 / 1000
# 417 / 1000
# 418 / 1000
# 419 / 1000
# 420 / 1000
# 421 / 1000
# 422 / 1000
# 423 / 1000
# 424 / 1000
# 425 / 1000
# 426 / 1000
# 427 / 1000
# 428 / 1000
# 429 / 1000
# 430 / 1000
# 431 / 1000
# 432 / 1000
# 433 / 1000
# 434 / 1000
# 435 / 1000
# 436 / 1000
# 437 / 1000
# 438 / 1000
# 439 / 1000
# 440 / 1000
# 441 / 1000
# 442 / 1000
# 443 / 1000
# 444 / 1000
# 445 / 1000
# 446 / 1000
# 447 / 1000
# 448 / 1000
# 449 / 1000
# 450 / 1000
# 451 / 1000
# 452 / 1000
# 453 / 1000
# 454 / 1000
# 455 / 1000
# 456 / 1000
# 457 / 1000
# 458 / 1000
# 459 / 1000
# 460 / 1000
# 461 / 1000
# 462 / 1000
# 463 / 1000
# 464 / 1000
# 465 / 1000
# 466 / 1000
# 467 / 1000
# 468 / 1000
# 469 / 1000
# 470 / 1000
# 471 / 1000
# 472 / 1000
# 473 / 1000
# 474 / 1000
# 475 / 1000
# 476 / 1000
# 477 / 1000
# 478 / 1000
# 479 / 1000
# 480 / 1000
# 481 / 1000
# 482 / 1000
# 483 / 1000
# 484 / 1000
# 485 / 1000
# 486 / 1000
# 487 / 1000
# 488 / 1000
# 489 / 1000
# 490 / 1000
# 491 / 1000
# 492 / 1000
# 493 / 1000
# 494 / 1000
# 495 / 1000
# 496 / 1000
# 497 / 1000
# 498 / 1000
# 499 / 1000
# 500 / 1000
# 501 / 1000
# 502 / 1000
# 503 / 1000
# 504 / 1000
# 505 / 1000
# 506 / 1000
# 507 / 1000
# 508 / 1000
# 509 / 1000
# 510 / 1000
# 511 / 1000
# 512 / 1000
# 513 / 1000
# 514 / 1000
# 515 / 1000
# 516 / 1000
# 517 / 1000
# 518 / 1000
# 519 / 1000
# 520 / 1000
# 521 / 1000
# 522 / 1000
# 523 / 1000
# 524 / 1000
# 525 / 1000
# 526 / 1000
# 527 / 1000
# 528 / 1000
# 529 / 1000
# 530 / 1000
# 531 / 1000
# 532 / 1000
# 533 / 1000
# 534 / 1000
# 535 / 1000
# 536 / 1000
# 537 / 1000
# 538 / 1000
# 539 / 1000
# 540 / 1000
# 541 / 1000
# 542 / 1000
# 543 / 1000
# 544 / 1000
# 545 / 1000
# 546 / 1000
# 547 / 1000
# 548 / 1000
# 549 / 1000
# 550 / 1000
# 551 / 1000
# 552 / 1000
# 553 / 1000
# 554 / 1000
# 555 / 1000
# 556 / 1000
# 557 / 1000
# 558 / 1000
# 559 / 1000
# 560 / 1000
# 561 / 1000
# 562 / 1000
# 563 / 1000
# 564 / 1000
# 565 / 1000
# 566 / 1000
# 567 / 1000
# 568 / 1000
# 569 / 1000
# 570 / 1000
# 571 / 1000
# 572 / 1000
# 573 / 1000
# 574 / 1000
# 575 / 1000
# 576 / 1000
# 577 / 1000
# 578 / 1000
# 579 / 1000
# 580 / 1000
# 581 / 1000
# 582 / 1000
# 583 / 1000
# 584 / 1000
# 585 / 1000
# 586 / 1000
# 587 / 1000
# 588 / 1000
# 589 / 1000
# 590 / 1000
# 591 / 1000
# 592 / 1000
# 593 / 1000
# 594 / 1000
# 595 / 1000
# 596 / 1000
# 597 / 1000
# 598 / 1000
# 599 / 1000
# 600 / 1000
# 601 / 1000
# 602 / 1000
# 603 / 1000
# 604 / 1000
# 605 / 1000
# 606 / 1000
# 607 / 1000
# 608 / 1000
# 609 / 1000
# 610 / 1000
# 611 / 1000
# 612 / 1000
# 613 / 1000
# 614 / 1000
# 615 / 1000
# 616 / 1000
# 617 / 1000
# 618 / 1000
# 619 / 1000
# 620 / 1000
# 621 / 1000
# 622 / 1000
# 623 / 1000
# 624 / 1000
# 625 / 1000
# 626 / 1000
# 627 / 1000
# 628 / 1000
# 629 / 1000
# 630 / 1000
# 631 / 1000
# 632 / 1000
# 633 / 1000
# 634 / 1000
# 635 / 1000
# 636 / 1000
# 637 / 1000
# 638 / 1000
# 639 / 1000
# 640 / 1000
# 641 / 1000
# 642 / 1000
# 643 / 1000
# 644 / 1000
# 645 / 1000
# 646 / 1000
# 647 / 1000
# 648 / 1000
# 649 / 1000
# 650 / 1000
# 651 / 1000
# 652 / 1000
# 653 / 1000
# 654 / 1000
# 655 / 1000
# 656 / 1000
# 657 / 1000
# 658 / 1000
# 659 / 1000
# 660 / 1000
# 661 / 1000
# 662 / 1000
# 663 / 1000
# 664 / 1000
# 665 / 1000
# 666 / 1000
# 667 / 1000
# 668 / 1000
# 669 / 1000
# 670 / 1000
# 671 / 1000
# 672 / 1000
# 673 / 1000
# 674 / 1000
# 675 / 1000
# 676 / 1000
# 677 / 1000
# 678 / 1000
# 679 / 1000
# 680 / 1000
# 681 / 1000
# 682 / 1000
# 683 / 1000
# 684 / 1000
# 685 / 1000
# 686 / 1000
# 687 / 1000
# 688 / 1000
# 689 / 1000
# 690 / 1000
# 691 / 1000
# 692 / 1000
# 693 / 1000
# 694 / 1000
# 695 / 1000
# 696 / 1000
# 697 / 1000
# 698 / 1000
# 699 / 1000
# 700 / 1000
# 701 / 1000
# 702 / 1000
# 703 / 1000
# 704 / 1000
# 705 / 1000
# 706 / 1000
# 707 / 1000
# 708 / 1000
# 709 / 1000
# 710 / 1000
# 711 / 1000
# 712 / 1000
# 713 / 1000
# 714 / 1000
# 715 / 1000
# 716 / 1000
# 717 / 1000
# 718 / 1000
# 719 / 1000
# 720 / 1000
# 721 / 1000
# 722 / 1000
# 723 / 1000
# 724 / 1000
# 725 / 1000
# 726 / 1000
# 727 / 1000
# 728 / 1000
# 729 / 1000
# 730 / 1000
# 731 / 1000
# 732 / 1000
# 733 / 1000
# 734 / 1000
# 735 / 1000
# 736 / 1000
# 737 / 1000
# 738 / 1000
# 739 / 1000
# 740 / 1000
# 741 / 1000
# 742 / 1000
# 743 / 1000
# 744 / 1000
# 745 / 1000
# 746 / 1000
# 747 / 1000
# 748 / 1000
# 749 / 1000
# 750 / 1000
# 751 / 1000
# 752 / 1000
# 753 / 1000
# 754 / 1000
# 755 / 1000
# 756 / 1000
# 757 / 1000
# 758 / 1000
# 759 / 1000
# 760 / 1000
# 761 / 1000
# 762 / 1000
# 763 / 1000
# 764 / 1000
# 765 / 1000
# 766 / 1000
# 767 / 1000
# 768 / 1000
# 769 / 1000
# 770 / 1000
# 771 / 1000
# 772 / 1000
# 773 / 1000
# 774 / 1000
# 775 / 1000
# 776 / 1000
# 777 / 1000
# 778 / 1000
# 779 / 1000
# 780 / 1000
# 781 / 1000
# 782 / 1000
# 783 / 1000
# 784 / 1000
# 785 / 1000
# 786 / 1000
# 787 / 1000
# 788 / 1000
# 789 / 1000
# 790 / 1000
# 791 / 1000
# 792 / 1000
# 793 / 1000
# 794 / 1000
# 795 / 1000
# 796 / 1000
# 797 / 1000
# 798 / 1000
# 799 / 1000
# 800 / 1000
# 801 / 1000
# 802 / 1000
# 803 / 1000
# 804 / 1000
# 805 / 1000
# 806 / 1000
# 807 / 1000
# 808 / 1000
# 809 / 1000
# 810 / 1000
# 811 / 1000
# 812 / 1000
# 813 / 1000
# 814 / 1000
# 815 / 1000
# 816 / 1000
# 817 / 1000
# 818 / 1000
# 819 / 1000
# 820 / 1000
# 821 / 1000
# 822 / 1000
# 823 / 1000
# 824 / 1000
# 825 / 1000
# 826 / 1000
# 827 / 1000
# 828 / 1000
# 829 / 1000
# 830 / 1000
# 831 / 1000
# 832 / 1000
# 833 / 1000
# 834 / 1000
# 835 / 1000
# 836 / 1000
# 837 / 1000
# 838 / 1000
# 839 / 1000
# 840 / 1000
# 841 / 1000
# 842 / 1000
# 843 / 1000
# 844 / 1000
# 845 / 1000
# 846 / 1000
# 847 / 1000
# 848 / 1000
# 849 / 1000
# 850 / 1000
# 851 / 1000
# 852 / 1000
# 853 / 1000
# 854 / 1000
# 855 / 1000
# 856 / 1000
# 857 / 1000
# 858 / 1000
# 859 / 1000
# 860 / 1000
# 861 / 1000
# 862 / 1000
# 863 / 1000
# 864 / 1000
# 865 / 1000
# 866 / 1000
# 867 / 1000
# 868 / 1000
# 869 / 1000
# 870 / 1000
# 871 / 1000
# 872 / 1000
# 873 / 1000
# 874 / 1000
# 875 / 1000
# 876 / 1000
# 877 / 1000
# 878 / 1000
# 879 / 1000
# 880 / 1000
# 881 / 1000
# 882 / 1000
# 883 / 1000
# 884 / 1000
# 885 / 1000
# 886 / 1000
# 887 / 1000
# 888 / 1000
# 889 / 1000
# 890 / 1000
# 891 / 1000
# 892 / 1000
# 893 / 1000
# 894 / 1000
# 895 / 1000
# 896 / 1000
# 897 / 1000
# 898 / 1000
# 899 / 1000
# 900 / 1000
# 901 / 1000
# 902 / 1000
# 903 / 1000
# 904 / 1000
# 905 / 1000
# 906 / 1000
# 907 / 1000
# 908 / 1000
# 909 / 1000
# 910 / 1000
# 911 / 1000
# 912 / 1000
# 913 / 1000
# 914 / 1000
# 915 / 1000
# 916 / 1000
# 917 / 1000
# 918 / 1000
# 919 / 1000
# 920 / 1000
# 921 / 1000
# 922 / 1000
# 923 / 1000
# 924 / 1000
# 925 / 1000
# 926 / 1000
# 927 / 1000
# 928 / 1000
# 929 / 1000
# 930 / 1000
# 931 / 1000
# 932 / 1000
# 933 / 1000
# 934 / 1000
# 935 / 1000
# 936 / 1000
# 937 / 1000
# 938 / 1000
# 939 / 1000
# 940 / 1000
# 941 / 1000
# 942 / 1000
# 943 / 1000
# 944 / 1000
# 945 / 1000
# 946 / 1000
# 947 / 1000
# 948 / 1000
# 949 / 1000
# 950 / 1000
# 951 / 1000
# 952 / 1000
# 953 / 1000
# 954 / 1000
# 955 / 1000
# 956 / 1000
# 957 / 1000
# 958 / 1000
# 959 / 1000
# 960 / 1000
# 961 / 1000
# 962 / 1000
# 963 / 1000
# 964 / 1000
# 965 / 1000
# 966 / 1000
# 967 / 1000
# 968 / 1000
# 969 / 1000
# 970 / 1000
# 971 / 1000
# 972 / 1000
# 973 / 1000
# 974 / 1000
# 975 / 1000
# 976 / 1000
# 977 / 1000
# 978 / 1000
# 979 / 1000
# 980 / 1000
# 981 / 1000
# 982 / 1000
# 983 / 1000
# 984 / 1000
# 985 / 1000
# 986 / 1000
# 987 / 1000
# 988 / 1000
# 989 / 1000
# 990 / 1000
# 991 / 1000
# 992 / 1000
# 993 / 1000
# 994 / 1000
# 995 / 1000
# 996 / 1000
# 997 / 1000
# 998 / 1000
# 999 / 1000
# 1000 / 1000
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 121324 words, keeping 6282 word types
# PROGRESS: at sentence #20000, processed 243369 words, keeping 6282 word types
# PROGRESS: at sentence #30000, processed 365375 words, keeping 6282 word types
# PROGRESS: at sentence #40000, processed 487297 words, keeping 6282 word types
# PROGRESS: at sentence #50000, processed 609016 words, keeping 6282 word types
# PROGRESS: at sentence #60000, processed 731589 words, keeping 6282 word types
# PROGRESS: at sentence #70000, processed 853041 words, keeping 6282 word types
# PROGRESS: at sentence #80000, processed 975069 words, keeping 6282 word types
# PROGRESS: at sentence #90000, processed 1096765 words, keeping 6282 word types
# PROGRESS: at sentence #100000, processed 1218715 words, keeping 6282 word types
# PROGRESS: at sentence #110000, processed 1339877 words, keeping 6282 word types
# PROGRESS: at sentence #120000, processed 1461913 words, keeping 6282 word types
# PROGRESS: at sentence #130000, processed 1583019 words, keeping 6282 word types
# PROGRESS: at sentence #140000, processed 1705096 words, keeping 6282 word types
# PROGRESS: at sentence #150000, processed 1826667 words, keeping 6282 word types
# PROGRESS: at sentence #160000, processed 1948751 words, keeping 6282 word types
# PROGRESS: at sentence #170000, processed 2070717 words, keeping 6282 word types
# PROGRESS: at sentence #180000, processed 2192795 words, keeping 6282 word types
# PROGRESS: at sentence #190000, processed 2315382 words, keeping 6282 word types
# PROGRESS: at sentence #200000, processed 2436312 words, keeping 6282 word types
# PROGRESS: at sentence #210000, processed 2558342 words, keeping 6282 word types
# PROGRESS: at sentence #220000, processed 2680475 words, keeping 6282 word types
# PROGRESS: at sentence #230000, processed 2803023 words, keeping 6282 word types
# PROGRESS: at sentence #240000, processed 2923968 words, keeping 6282 word types
# PROGRESS: at sentence #250000, processed 3045695 words, keeping 6282 word types
# PROGRESS: at sentence #260000, processed 3166618 words, keeping 6282 word types
# PROGRESS: at sentence #270000, processed 3288490 words, keeping 6282 word types
# PROGRESS: at sentence #280000, processed 3409904 words, keeping 6282 word types
# PROGRESS: at sentence #290000, processed 3531941 words, keeping 6282 word types
# PROGRESS: at sentence #300000, processed 3654169 words, keeping 6282 word types
# PROGRESS: at sentence #310000, processed 3776821 words, keeping 6282 word types
# PROGRESS: at sentence #320000, processed 3898083 words, keeping 6282 word types
# PROGRESS: at sentence #770000, processed 9379566 words, keeping 6282 word types
# PROGRESS: at sentence #780000, processed 9501768 words, keeping 6282 word types
# PROGRESS: at sentence #790000, processed 9623195 words, keeping 6282 word types
# PROGRESS: at sentence #800000, processed 9744588 words, keeping 6282 word types
# PROGRESS: at sentence #810000, processed 9866797 words, keeping 6282 word types
# PROGRESS: at sentence #820000, processed 9988087 words, keeping 6282 word types
# PROGRESS: at sentence #830000, processed 10110416 words, keeping 6282 word types
# PROGRESS: at sentence #840000, processed 10232202 words, keeping 6282 word types
# PROGRESS: at sentence #850000, processed 10353396 words, keeping 6282 word types
# PROGRESS: at sentence #860000, processed 10474765 words, keeping 6282 word types
# PROGRESS: at sentence #870000, processed 10596824 words, keeping 6282 word types
# PROGRESS: at sentence #880000, processed 10717860 words, keeping 6282 word types
# PROGRESS: at sentence #890000, processed 10839808 words, keeping 6282 word types
# PROGRESS: at sentence #900000, processed 10962893 words, keeping 6282 word types
# PROGRESS: at sentence #910000, processed 11084563 words, keeping 6282 word types
# PROGRESS: at sentence #920000, processed 11206500 words, keeping 6282 word types
# PROGRESS: at sentence #930000, processed 11327695 words, keeping 6282 word types
# PROGRESS: at sentence #940000, processed 11449643 words, keeping 6282 word types
# PROGRESS: at sentence #950000, processed 11571329 words, keeping 6282 word types
# PROGRESS: at sentence #960000, processed 11692869 words, keeping 6282 word types
# PROGRESS: at sentence #970000, processed 11814662 words, keeping 6282 word types
# PROGRESS: at sentence #980000, processed 11937046 words, keeping 6282 word types
# PROGRESS: at sentence #990000, processed 12058106 words, keeping 6282 word types
# PROGRESS: at sentence #1000000, processed 12180630 words, keeping 6282 word types
# PROGRESS: at sentence #1010000, processed 12302793 words, keeping 6282 word types
# PROGRESS: at sentence #1020000, processed 12424928 words, keeping 6282 word types
# PROGRESS: at sentence #1030000, processed 12545995 words, keeping 6282 word types
# PROGRESS: at sentence #1040000, processed 12667592 words, keeping 6282 word types
# PROGRESS: at sentence #1050000, processed 12790044 words, keeping 6282 word types
# PROGRESS: at sentence #1060000, processed 12911878 words, keeping 6282 word types
# PROGRESS: at sentence #1070000, processed 13032995 words, keeping 6282 word types
# PROGRESS: at sentence #1080000, processed 13155133 words, keeping 6282 word types
# PROGRESS: at sentence #1090000, processed 13276116 words, keeping 6282 word types
# PROGRESS: at sentence #1100000, processed 13398461 words, keeping 6282 word types
# PROGRESS: at sentence #1110000, processed 13520353 words, keeping 6282 word types
# PROGRESS: at sentence #1120000, processed 13642708 words, keeping 6282 word types
# PROGRESS: at sentence #1130000, processed 13765229 words, keeping 6282 word types
# PROGRESS: at sentence #1140000, processed 13886787 words, keeping 6282 word types
# PROGRESS: at sentence #1150000, processed 14008344 words, keeping 6282 word types
# PROGRESS: at sentence #1160000, processed 14130564 words, keeping 6282 word types
# PROGRESS: at sentence #1170000, processed 14252557 words, keeping 6282 word types
# PROGRESS: at sentence #1180000, processed 14373587 words, keeping 6282 word types
# PROGRESS: at sentence #1190000, processed 14496148 words, keeping 6282 word types
# PROGRESS: at sentence #1200000, processed 14617628 words, keeping 6282 word types
# PROGRESS: at sentence #1210000, processed 14739442 words, keeping 6282 word types
# PROGRESS: at sentence #1220000, processed 14860823 words, keeping 6282 word types
# PROGRESS: at sentence #1230000, processed 14982607 words, keeping 6282 word types
# PROGRESS: at sentence #1240000, processed 15103929 words, keeping 6282 word types
# PROGRESS: at sentence #1250000, processed 15224862 words, keeping 6282 word types
# PROGRESS: at sentence #1260000, processed 15346102 words, keeping 6282 word types
# PROGRESS: at sentence #1270000, processed 15468292 words, keeping 6282 word types
# PROGRESS: at sentence #1280000, processed 15589796 words, keeping 6282 word types
# PROGRESS: at sentence #1290000, processed 15712059 words, keeping 6282 word types
# PROGRESS: at sentence #1300000, processed 15834121 words, keeping 6282 word types
# PROGRESS: at sentence #1310000, processed 15956609 words, keeping 6282 word types
# PROGRESS: at sentence #1320000, processed 16077540 words, keeping 6282 word types
# PROGRESS: at sentence #1330000, processed 16199602 words, keeping 6282 word types
# PROGRESS: at sentence #1340000, processed 16320648 words, keeping 6282 word types
# PROGRESS: at sentence #1350000, processed 16442004 words, keeping 6282 word types
# PROGRESS: at sentence #1360000, processed 16563208 words, keeping 6282 word types
# PROGRESS: at sentence #1370000, processed 16685724 words, keeping 6282 word types
# PROGRESS: at sentence #1380000, processed 16807919 words, keeping 6282 word types
# PROGRESS: at sentence #1390000, processed 16929528 words, keeping 6282 word types
# PROGRESS: at sentence #1400000, processed 17050693 words, keeping 6282 word types
# PROGRESS: at sentence #1410000, processed 17172220 words, keeping 6282 word types
# PROGRESS: at sentence #1420000, processed 17294430 words, keeping 6282 word types
# PROGRESS: at sentence #1430000, processed 17416551 words, keeping 6282 word types
# PROGRESS: at sentence #1440000, processed 17538085 words, keeping 6282 word types
# PROGRESS: at sentence #1450000, processed 17660180 words, keeping 6282 word types
# PROGRESS: at sentence #1460000, processed 17781439 words, keeping 6282 word types
# PROGRESS: at sentence #1470000, processed 17902873 words, keeping 6282 word types
# PROGRESS: at sentence #1480000, processed 18023553 words, keeping 6282 word types
# PROGRESS: at sentence #1490000, processed 18145585 words, keeping 6282 word types
# PROGRESS: at sentence #1500000, processed 18267201 words, keeping 6282 word types
# PROGRESS: at sentence #1510000, processed 18388748 words, keeping 6282 word types
# PROGRESS: at sentence #1520000, processed 18510517 words, keeping 6282 word types
# PROGRESS: at sentence #1530000, processed 18632025 words, keeping 6282 word types
# PROGRESS: at sentence #1540000, processed 18754278 words, keeping 6282 word types
# PROGRESS: at sentence #1550000, processed 18875295 words, keeping 6282 word types
# PROGRESS: at sentence #1560000, processed 18997002 words, keeping 6282 word types
# PROGRESS: at sentence #1570000, processed 19119090 words, keeping 6282 word types
# PROGRESS: at sentence #1580000, processed 19241187 words, keeping 6282 word types
# PROGRESS: at sentence #1590000, processed 19362257 words, keeping 6282 word types
# PROGRESS: at sentence #1600000, processed 19484997 words, keeping 6282 word types
# PROGRESS: at sentence #1610000, processed 19606573 words, keeping 6282 word types
# PROGRESS: at sentence #1620000, processed 19728770 words, keeping 6282 word types
# PROGRESS: at sentence #1630000, processed 19850079 words, keeping 6282 word types
# PROGRESS: at sentence #1640000, processed 19971677 words, keeping 6282 word types
# PROGRESS: at sentence #1650000, processed 20093205 words, keeping 6282 word types
# PROGRESS: at sentence #1660000, processed 20214662 words, keeping 6282 word types
# PROGRESS: at sentence #1670000, processed 20336453 words, keeping 6282 word types
# PROGRESS: at sentence #1680000, processed 20459150 words, keeping 6282 word types
# PROGRESS: at sentence #1690000, processed 20581277 words, keeping 6282 word types
# PROGRESS: at sentence #1700000, processed 20702479 words, keeping 6282 word types
# PROGRESS: at sentence #1710000, processed 20824386 words, keeping 6282 word types
# PROGRESS: at sentence #1720000, processed 20945991 words, keeping 6282 word types
# PROGRESS: at sentence #1730000, processed 21067755 words, keeping 6282 word types
# PROGRESS: at sentence #1740000, processed 21189717 words, keeping 6282 word types
# PROGRESS: at sentence #1750000, processed 21311291 words, keeping 6282 word types
# PROGRESS: at sentence #1760000, processed 21433367 words, keeping 6282 word types
# PROGRESS: at sentence #1770000, processed 21555195 words, keeping 6282 word types
# PROGRESS: at sentence #1780000, processed 21677419 words, keeping 6282 word types
# PROGRESS: at sentence #1790000, processed 21799367 words, keeping 6282 word types
# PROGRESS: at sentence #1800000, processed 21921117 words, keeping 6282 word types
# PROGRESS: at sentence #1810000, processed 22042513 words, keeping 6282 word types
# PROGRESS: at sentence #1820000, processed 22163764 words, keeping 6282 word types
# PROGRESS: at sentence #1830000, processed 22285451 words, keeping 6282 word types
# PROGRESS: at sentence #1840000, processed 22407141 words, keeping 6282 word types
# PROGRESS: at sentence #1850000, processed 22529434 words, keeping 6282 word types
# PROGRESS: at sentence #1860000, processed 22650767 words, keeping 6282 word types
# PROGRESS: at sentence #1870000, processed 22772884 words, keeping 6282 word types
# PROGRESS: at sentence #1880000, processed 22893958 words, keeping 6282 word types
# PROGRESS: at sentence #1890000, processed 23015207 words, keeping 6282 word types
# PROGRESS: at sentence #1900000, processed 23136578 words, keeping 6282 word types
# PROGRESS: at sentence #1910000, processed 23258248 words, keeping 6282 word types
# PROGRESS: at sentence #1920000, processed 23380210 words, keeping 6282 word types
# PROGRESS: at sentence #1930000, processed 23502087 words, keeping 6282 word types
# PROGRESS: at sentence #1940000, processed 23623315 words, keeping 6282 word types
# PROGRESS: at sentence #1950000, processed 23744993 words, keeping 6282 word types
# PROGRESS: at sentence #1960000, processed 23867230 words, keeping 6282 word types
# PROGRESS: at sentence #1970000, processed 23989418 words, keeping 6282 word types
# PROGRESS: at sentence #1980000, processed 24111421 words, keeping 6282 word types
# PROGRESS: at sentence #1990000, processed 24233501 words, keeping 6282 word types
# PROGRESS: at sentence #2000000, processed 24354865 words, keeping 6282 word types
# PROGRESS: at sentence #2010000, processed 24476224 words, keeping 6282 word types
# PROGRESS: at sentence #2020000, processed 24597637 words, keeping 6282 word types
# PROGRESS: at sentence #2030000, processed 24720104 words, keeping 6282 word types
# PROGRESS: at sentence #2040000, processed 24842827 words, keeping 6282 word types
# PROGRESS: at sentence #2050000, processed 24964684 words, keeping 6282 word types
# PROGRESS: at sentence #2060000, processed 25086703 words, keeping 6282 word types
# PROGRESS: at sentence #2070000, processed 25208122 words, keeping 6282 word types
# PROGRESS: at sentence #3390000, processed 41293465 words, keeping 6282 word types
# PROGRESS: at sentence #3400000, processed 41414499 words, keeping 6282 word types
# PROGRESS: at sentence #3410000, processed 41536175 words, keeping 6282 word types
# PROGRESS: at sentence #3420000, processed 41657844 words, keeping 6282 word types
# PROGRESS: at sentence #3430000, processed 41778851 words, keeping 6282 word types
# PROGRESS: at sentence #3440000, processed 41900812 words, keeping 6282 word types
# PROGRESS: at sentence #3450000, processed 42021593 words, keeping 6282 word types
# PROGRESS: at sentence #3460000, processed 42143716 words, keeping 6282 word types
# PROGRESS: at sentence #3470000, processed 42264596 words, keeping 6282 word types
# PROGRESS: at sentence #3480000, processed 42386260 words, keeping 6282 word types
# PROGRESS: at sentence #3490000, processed 42508732 words, keeping 6282 word types
# PROGRESS: at sentence #3500000, processed 42630178 words, keeping 6282 word types
# PROGRESS: at sentence #3510000, processed 42752285 words, keeping 6282 word types
# PROGRESS: at sentence #3520000, processed 42874224 words, keeping 6282 word types
# PROGRESS: at sentence #3530000, processed 42995546 words, keeping 6282 word types
# PROGRESS: at sentence #3540000, processed 43118068 words, keeping 6282 word types
# PROGRESS: at sentence #3550000, processed 43240128 words, keeping 6282 word types
# PROGRESS: at sentence #3560000, processed 43361531 words, keeping 6282 word types
# PROGRESS: at sentence #3570000, processed 43483024 words, keeping 6282 word types
# PROGRESS: at sentence #3580000, processed 43604513 words, keeping 6282 word types
# PROGRESS: at sentence #3590000, processed 43726298 words, keeping 6282 word types
# PROGRESS: at sentence #3600000, processed 43846912 words, keeping 6282 word types
# PROGRESS: at sentence #3610000, processed 43968998 words, keeping 6282 word types
# PROGRESS: at sentence #3620000, processed 44090597 words, keeping 6282 word types
# PROGRESS: at sentence #3630000, processed 44212024 words, keeping 6282 word types
# PROGRESS: at sentence #3640000, processed 44334624 words, keeping 6282 word types
# PROGRESS: at sentence #3650000, processed 44454880 words, keeping 6282 word types
# PROGRESS: at sentence #3660000, processed 44576510 words, keeping 6282 word types
# PROGRESS: at sentence #3670000, processed 44698584 words, keeping 6282 word types
# PROGRESS: at sentence #3680000, processed 44821151 words, keeping 6282 word types
# PROGRESS: at sentence #3690000, processed 44942811 words, keeping 6282 word types
# PROGRESS: at sentence #3700000, processed 45064857 words, keeping 6282 word types
# PROGRESS: at sentence #3710000, processed 45185772 words, keeping 6282 word types
# PROGRESS: at sentence #3720000, processed 45307361 words, keeping 6282 word types
# PROGRESS: at sentence #3730000, processed 45429208 words, keeping 6282 word types
# PROGRESS: at sentence #3740000, processed 45552078 words, keeping 6282 word types
# PROGRESS: at sentence #3750000, processed 45673777 words, keeping 6282 word types
# PROGRESS: at sentence #3760000, processed 45795094 words, keeping 6282 word types
# PROGRESS: at sentence #3770000, processed 45916889 words, keeping 6282 word types
# PROGRESS: at sentence #3780000, processed 46038314 words, keeping 6282 word types
# PROGRESS: at sentence #3790000, processed 46161207 words, keeping 6282 word types
# PROGRESS: at sentence #3800000, processed 46282271 words, keeping 6282 word types
# PROGRESS: at sentence #3810000, processed 46404084 words, keeping 6282 word types
# PROGRESS: at sentence #4250000, processed 51762835 words, keeping 6282 word types
# PROGRESS: at sentence #4260000, processed 51884478 words, keeping 6282 word types
# PROGRESS: at sentence #4270000, processed 52006110 words, keeping 6282 word types
# PROGRESS: at sentence #4280000, processed 52128030 words, keeping 6282 word types
# PROGRESS: at sentence #4290000, processed 52249274 words, keeping 6282 word types
# PROGRESS: at sentence #4300000, processed 52371355 words, keeping 6282 word types
# PROGRESS: at sentence #4310000, processed 52491843 words, keeping 6282 word types
# PROGRESS: at sentence #4320000, processed 52614563 words, keeping 6282 word types
# PROGRESS: at sentence #4330000, processed 52735928 words, keeping 6282 word types
# PROGRESS: at sentence #4340000, processed 52858097 words, keeping 6282 word types
# PROGRESS: at sentence #4350000, processed 52979531 words, keeping 6282 word types
# PROGRESS: at sentence #4360000, processed 53101888 words, keeping 6282 word types
# PROGRESS: at sentence #4370000, processed 53223182 words, keeping 6282 word types
# PROGRESS: at sentence #4380000, processed 53344906 words, keeping 6282 word types
# PROGRESS: at sentence #4390000, processed 53465459 words, keeping 6282 word types
# PROGRESS: at sentence #4400000, processed 53586850 words, keeping 6282 word types
# PROGRESS: at sentence #4410000, processed 53708744 words, keeping 6282 word types
# PROGRESS: at sentence #4420000, processed 53830054 words, keeping 6282 word types
# PROGRESS: at sentence #4430000, processed 53951998 words, keeping 6282 word types
# PROGRESS: at sentence #4440000, processed 54073664 words, keeping 6282 word types
# PROGRESS: at sentence #4450000, processed 54195399 words, keeping 6282 word types
# PROGRESS: at sentence #4460000, processed 54317598 words, keeping 6282 word types
# PROGRESS: at sentence #4470000, processed 54439342 words, keeping 6282 word types
# PROGRESS: at sentence #4480000, processed 54561086 words, keeping 6282 word types
# PROGRESS: at sentence #4490000, processed 54682932 words, keeping 6282 word types
# PROGRESS: at sentence #4500000, processed 54804616 words, keeping 6282 word types
# PROGRESS: at sentence #4510000, processed 54926276 words, keeping 6282 word types
# PROGRESS: at sentence #4520000, processed 55048637 words, keeping 6282 word types
# ...
# PROGRESS: at sentence #5950000, processed 72465455 words, keeping 6282 word types
# PROGRESS: at sentence #5960000, processed 72587788 words, keeping 6282 word types
# PROGRESS: at sentence #5970000, processed 72709791 words, keeping 6282 word types
# PROGRESS: at sentence #5980000, processed 72831022 words, keeping 6282 word types
# PROGRESS: at sentence #5990000, processed 72952489 words, keeping 6282 word types
# PROGRESS: at sentence #6000000, processed 73074063 words, keeping 6282 word types
# PROGRESS: at sentence #6010000, processed 73195251 words, keeping 6282 word types
# PROGRESS: at sentence #6020000, processed 73317381 words, keeping 6282 word types
# PROGRESS: at sentence #6030000, processed 73439220 words, keeping 6282 word types
# PROGRESS: at sentence #6040000, processed 73560508 words, keeping 6282 word types
# PROGRESS: at sentence #6050000, processed 73682410 words, keeping 6282 word types
# PROGRESS: at sentence #6060000, processed 73803594 words, keeping 6282 word types
# PROGRESS: at sentence #6070000, processed 73925602 words, keeping 6282 word types
# PROGRESS: at sentence #6080000, processed 74047562 words, keeping 6282 word types
# PROGRESS: at sentence #6090000, processed 74168834 words, keeping 6282 word types
# PROGRESS: at sentence #6100000, processed 74290840 words, keeping 6282 word types
# PROGRESS: at sentence #6110000, processed 74412948 words, keeping 6282 word types
# PROGRESS: at sentence #6120000, processed 74534158 words, keeping 6282 word types
# PROGRESS: at sentence #6130000, processed 74655686 words, keeping 6282 word types
# PROGRESS: at sentence #6140000, processed 74778071 words, keeping 6282 word types
# PROGRESS: at sentence #6150000, processed 74899418 words, keeping 6282 word types
# PROGRESS: at sentence #6160000, processed 75021172 words, keeping 6282 word types
# PROGRESS: at sentence #6170000, processed 75142278 words, keeping 6282 word types
# PROGRESS: at sentence #6180000, processed 75263636 words, keeping 6282 word types
# PROGRESS: at sentence #6190000, processed 75385794 words, keeping 6282 word types
# PROGRESS: at sentence #6200000, processed 75508237 words, keeping 6282 word types
# PROGRESS: at sentence #6210000, processed 75629376 words, keeping 6282 word types
# PROGRESS: at sentence #6220000, processed 75750616 words, keeping 6282 word types
# PROGRESS: at sentence #6230000, processed 75872961 words, keeping 6282 word types
# PROGRESS: at sentence #6240000, processed 75995012 words, keeping 6282 word types
# PROGRESS: at sentence #6250000, processed 76116904 words, keeping 6282 word types
# PROGRESS: at sentence #6260000, processed 76238159 words, keeping 6282 word types
# PROGRESS: at sentence #6270000, processed 76360118 words, keeping 6282 word types
# PROGRESS: at sentence #6280000, processed 76481631 words, keeping 6282 word types
# collected 6282 word types from a corpus of 76506187 raw words and 6282000 sentences
# Creating a fresh vocabulary
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 6282 unique words (100.00% of original 6282, drops 0)', 'datetime': '2023-11-06T20:56:26.857825', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 76506187 word corpus (100.00% of original 76506187, drops 0)', 'datetime': '2023-11-06T20:56:26.858269', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# deleting the raw counts dictionary of 6282 items
# sample=0.001 downsamples 0 most-common words
# Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 76506187 word corpus (100.0%% of prior 76506187)', 'datetime': '2023-11-06T20:56:26.879749', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# estimated required memory for 6282 words and 64 dimensions: 6357384 bytes
# resetting layer weights
# Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-11-06T20:56:26.916645', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# Word2Vec lifecycle event {'msg': 'training model with 64 workers on 6282 vocabulary and 64 features, using sg=0 hs=0 sample=0.001 negative=5 window=7 shrink_windows=True', 'datetime': '2023-11-06T20:56:26.917326', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'train'}
# EPOCH 0 - PROGRESS: at 3.56% examples, 2689761 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 7.54% examples, 2861072 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 11.79% examples, 2983494 words/s, in_qsize 128, out_qsize 0
# EPOCH 0 - PROGRESS: at 15.84% examples, 3011433 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 19.72% examples, 2997537 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 23.72% examples, 3006029 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 27.69% examples, 3009595 words/s, in_qsize 126, out_qsize 1
# EPOCH 0 - PROGRESS: at 31.75% examples, 3020593 words/s, in_qsize 126, out_qsize 1
# EPOCH 0 - PROGRESS: at 35.79% examples, 3025967 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 39.90% examples, 3037337 words/s, in_qsize 126, out_qsize 1
# EPOCH 0 - PROGRESS: at 43.85% examples, 3034322 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 47.83% examples, 3034961 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 51.81% examples, 3035330 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 55.67% examples, 3028477 words/s, in_qsize 124, out_qsize 3
# EPOCH 0 - PROGRESS: at 59.57% examples, 3023541 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 63.46% examples, 3020392 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 67.49% examples, 3022955 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 71.45% examples, 3023068 words/s, in_qsize 126, out_qsize 1
# EPOCH 0 - PROGRESS: at 75.41% examples, 3023253 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 79.42% examples, 3025340 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 83.15% examples, 3016985 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 87.06% examples, 3015389 words/s, in_qsize 127, out_qsize 0
# EPOCH 0 - PROGRESS: at 91.18% examples, 3020902 words/s, in_qsize 125, out_qsize 2
# EPOCH 0 - PROGRESS: at 95.39% examples, 3029459 words/s, in_qsize 127, out_qsize 0
# EPOCH 0: training on 76506187 raw words (76506187 effective words) took 25.1s, 3052041 effective words/s
# EPOCH 1 - PROGRESS: at 3.79% examples, 2884171 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 7.98% examples, 3040167 words/s, in_qsize 127, out_qsize 1
# EPOCH 1 - PROGRESS: at 11.99% examples, 3048361 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 16.14% examples, 3070960 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 20.24% examples, 3083420 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 24.28% examples, 3082043 words/s, in_qsize 125, out_qsize 2
# EPOCH 1 - PROGRESS: at 28.47% examples, 3095973 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 32.50% examples, 3091755 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 36.66% examples, 3101202 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 40.70% examples, 3099020 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 44.82% examples, 3102744 words/s, in_qsize 122, out_qsize 5
# EPOCH 1 - PROGRESS: at 48.94% examples, 3107102 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 52.99% examples, 3106343 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 57.07% examples, 3104531 words/s, in_qsize 124, out_qsize 3
# EPOCH 1 - PROGRESS: at 61.22% examples, 3107418 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 65.40% examples, 3111150 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 69.53% examples, 3113473 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 73.59% examples, 3112997 words/s, in_qsize 125, out_qsize 2
# EPOCH 1 - PROGRESS: at 77.80% examples, 3118004 words/s, in_qsize 125, out_qsize 2
# EPOCH 1 - PROGRESS: at 81.77% examples, 3113921 words/s, in_qsize 127, out_qsize 0
# EPOCH 1 - PROGRESS: at 85.98% examples, 3118809 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 90.29% examples, 3126023 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 94.63% examples, 3134207 words/s, in_qsize 126, out_qsize 1
# EPOCH 1 - PROGRESS: at 99.16% examples, 3146766 words/s, in_qsize 65, out_qsize 0
# EPOCH 1: training on 76506187 raw words (76506187 effective words) took 24.2s, 3156201 effective words/s
# EPOCH 2 - PROGRESS: at 3.66% examples, 2789034 words/s, in_qsize 125, out_qsize 2
# EPOCH 2 - PROGRESS: at 7.77% examples, 2955869 words/s, in_qsize 128, out_qsize 2
# EPOCH 2 - PROGRESS: at 12.04% examples, 3057665 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 16.22% examples, 3090475 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 20.27% examples, 3090916 words/s, in_qsize 126, out_qsize 1
# EPOCH 2 - PROGRESS: at 24.63% examples, 3127115 words/s, in_qsize 126, out_qsize 2
# EPOCH 2 - PROGRESS: at 28.94% examples, 3145472 words/s, in_qsize 126, out_qsize 1
# EPOCH 2 - PROGRESS: at 33.01% examples, 3140713 words/s, in_qsize 125, out_qsize 2
# EPOCH 2 - PROGRESS: at 37.13% examples, 3140947 words/s, in_qsize 125, out_qsize 2
# EPOCH 2 - PROGRESS: at 41.26% examples, 3142078 words/s, in_qsize 123, out_qsize 4
# EPOCH 2 - PROGRESS: at 45.39% examples, 3144227 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 49.46% examples, 3139050 words/s, in_qsize 125, out_qsize 2
# EPOCH 2 - PROGRESS: at 53.55% examples, 3137629 words/s, in_qsize 125, out_qsize 2
# EPOCH 2 - PROGRESS: at 57.79% examples, 3143875 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 61.94% examples, 3145787 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 66.04% examples, 3144617 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 70.28% examples, 3147646 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 74.31% examples, 3142843 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 78.46% examples, 3143501 words/s, in_qsize 128, out_qsize 0
# EPOCH 2 - PROGRESS: at 82.59% examples, 3144169 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 86.71% examples, 3144149 words/s, in_qsize 126, out_qsize 2
# EPOCH 2 - PROGRESS: at 91.05% examples, 3151779 words/s, in_qsize 127, out_qsize 0
# EPOCH 2 - PROGRESS: at 95.43% examples, 3160237 words/s, in_qsize 126, out_qsize 1
# EPOCH 2: training on 76506187 raw words (76506187 effective words) took 24.0s, 3185083 effective words/s
# EPOCH 3 - PROGRESS: at 3.81% examples, 2914084 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 7.75% examples, 2958102 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 11.66% examples, 2965625 words/s, in_qsize 124, out_qsize 3
# EPOCH 3 - PROGRESS: at 15.84% examples, 3023023 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 19.94% examples, 3039028 words/s, in_qsize 128, out_qsize 0
# EPOCH 3 - PROGRESS: at 24.04% examples, 3052330 words/s, in_qsize 124, out_qsize 3
# EPOCH 3 - PROGRESS: at 28.28% examples, 3077517 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 32.43% examples, 3088194 words/s, in_qsize 124, out_qsize 3
# EPOCH 3 - PROGRESS: at 36.70% examples, 3106827 words/s, in_qsize 125, out_qsize 2
# EPOCH 3 - PROGRESS: at 40.66% examples, 3097353 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 44.87% examples, 3108164 words/s, in_qsize 125, out_qsize 2
# EPOCH 3 - PROGRESS: at 49.03% examples, 3113721 words/s, in_qsize 125, out_qsize 2
# EPOCH 3 - PROGRESS: at 53.25% examples, 3122101 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 57.55% examples, 3132647 words/s, in_qsize 125, out_qsize 2
# EPOCH 3 - PROGRESS: at 61.54% examples, 3126732 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 65.77% examples, 3133614 words/s, in_qsize 126, out_qsize 1
# EPOCH 3 - PROGRESS: at 69.82% examples, 3130867 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 73.86% examples, 3127843 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 77.95% examples, 3127578 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 81.91% examples, 3122378 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 85.91% examples, 3118432 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 90.12% examples, 3122396 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 94.33% examples, 3126715 words/s, in_qsize 127, out_qsize 0
# EPOCH 3 - PROGRESS: at 98.71% examples, 3135817 words/s, in_qsize 98, out_qsize 1
# EPOCH 3: training on 76506187 raw words (76506187 effective words) took 24.3s, 3146262 effective words/s
# EPOCH 4 - PROGRESS: at 3.54% examples, 2707071 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 7.59% examples, 2889582 words/s, in_qsize 128, out_qsize 0
# EPOCH 4 - PROGRESS: at 11.64% examples, 2957337 words/s, in_qsize 124, out_qsize 3
# EPOCH 4 - PROGRESS: at 15.84% examples, 3018948 words/s, in_qsize 126, out_qsize 1
# EPOCH 4 - PROGRESS: at 19.94% examples, 3042520 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 24.18% examples, 3069004 words/s, in_qsize 126, out_qsize 1
# EPOCH 4 - PROGRESS: at 28.26% examples, 3074610 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 32.30% examples, 3075707 words/s, in_qsize 128, out_qsize 0
# EPOCH 4 - PROGRESS: at 36.41% examples, 3082879 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 40.56% examples, 3089910 words/s, in_qsize 126, out_qsize 1
# EPOCH 4 - PROGRESS: at 44.70% examples, 3094855 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 48.85% examples, 3101304 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 53.04% examples, 3109327 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 56.91% examples, 3098107 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 61.01% examples, 3099996 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 65.21% examples, 3106584 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 69.20% examples, 3103065 words/s, in_qsize 124, out_qsize 3
# EPOCH 4 - PROGRESS: at 73.29% examples, 3103655 words/s, in_qsize 124, out_qsize 3
# EPOCH 4 - PROGRESS: at 77.46% examples, 3107845 words/s, in_qsize 125, out_qsize 2
# EPOCH 4 - PROGRESS: at 81.53% examples, 3107956 words/s, in_qsize 125, out_qsize 2
# EPOCH 4 - PROGRESS: at 85.66% examples, 3109794 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 89.69% examples, 3107877 words/s, in_qsize 127, out_qsize 0
# EPOCH 4 - PROGRESS: at 94.11% examples, 3119031 words/s, in_qsize 126, out_qsize 1
# EPOCH 4 - PROGRESS: at 98.45% examples, 3125847 words/s, in_qsize 118, out_qsize 1
# EPOCH 4: training on 76506187 raw words (76506187 effective words) took 24.4s, 3141082 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 382530935 raw words (382530935 effective words) took 122.1s, 3133647 effective words/s', 'datetime': '2023-11-06T20:58:28.990061', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'train'}
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=6282, vector_size=64, alpha=0.025>', 'datetime': '2023-11-06T20:58:28.990458', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-88-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
import numpy as np
from scipy.signal import convolve2d
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from scipy import misc

# Load an example RGB image (you can replace this with your own image)
image = vectors.reshape(100, 100, -1)#misc.face()

# Define the standard deviation for the Gaussian kernel
sigma = 1

# Create a Gaussian kernel using scipy's gaussian_filter
gaussian_kernel = gaussian_filter(np.eye(5), sigma)

# Normalize the kernel
gaussian_kernel /= gaussian_kernel.sum()

# Initialize an empty result image with the same shape as the input image
result = np.zeros_like(image)

# Apply 2D Gaussian convolution to each color channel separately
for channel in range(vector_size):
    result[:, :, channel] = convolve2d(image[:, :, channel], gaussian_kernel, mode='same', boundary='wrap')

# Plot the original RGB image and the convolved result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

mag = []
for row in image.reshape(-1, vector_size):
    mag.append(np.linalg.norm(row))
mag = np.array(mag).reshape(100, 100, 1)


# plt.imshow(image.mean(-1))

plt.imshow(mag)
plt.gca().invert_yaxis()

# %%
import numpy as np
from scipy.signal import convolve2d
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from scipy import misc

# Load an example RGB image (you can replace this with your own image)
image = vectors.reshape(100, 100, -1)#misc.face()

# Define the standard deviation for the Gaussian kernel
sigma = 1

# Create a Gaussian kernel using scipy's gaussian_filter
gaussian_kernel = gaussian_filter(np.eye(5), sigma)

# Normalize the kernel
gaussian_kernel /= gaussian_kernel.sum()

# Initialize an empty result image with the same shape as the input image
result = np.zeros_like(image)

# Apply 2D Gaussian convolution to each color channel separately
for channel in range(vector_size):
    result[:, :, channel] = convolve2d(image[:, :, channel], gaussian_kernel, mode='same', boundary='wrap')

# Plot the original RGB image and the convolved result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)

mag = []
for row in image.reshape(-1, vector_size):
    mag.append(np.linalg.norm(row))
mag = np.array(mag).reshape(100, 100, 1)


# plt.imshow(image.mean(-1))
plt.imshow(mag)
plt.title('Original RGB Image')

mag = []
for row in result.reshape(-1, vector_size):
    mag.append(np.linalg.norm(row))
mag = np.array(mag).reshape(100, 100, 1)


plt.subplot(1, 2, 2)
plt.imshow(mag)
plt.title('Gaussian Convolution')

plt.show()
np.save(f'{dname}/grid_vectors_gaussian.npy', result.reshape(-1, vector_size))

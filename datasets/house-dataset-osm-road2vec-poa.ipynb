# %%
import os, tqdm

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = (label == label) & (pred == pred)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        
        rmse = np.square(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        
        mape = np.divide(mae, label)
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape*mask)
        
        print('masked:', np.sum(mask == 0))
    return male, rmse, mape

# %%
os.listdir('.')
# Out:
# ['house-dataset-osm-road2vec-poa.ipynb',
#  'house-dataset-visualization.html',
#  'house-dataset-visualization.ipynb',
#  '.ipynb_checkpoints',
#  'house-lgbm.ipynb',
#  'generateSE.py',
#  'sp',
#  'house-dataset-visualization-Copy1.ipynb',
#  'house-dataset-osm-road2vec-dbscan.ipynb',
#  'node2vec.py',
#  '.gitkeep ',
#  'poa',
#  'house-dataset-osm-road2vec-Copy2.ipynb',
#  'fc',
#  'kc',
#  'house-dataset-osm-road2vec-kc.ipynb',
#  'house_reverse_geocoding.py',
#  '__pycache__',
#  'house-lgbm-sonia.ipynb',
#  'house-dataset-osm-road2vec-Copy1.ipynb',
#  'osmdata',
#  'house-dataset-osm-road2vec.ipynb',
#  'house-dataset-osm-buildings.ipynb',
#  'house-dataset-osm-buildings-Copy1.ipynb',
#  'cache']

# %%
datasets = ['poa']

# %%
import numpy as np

# %%
streetmap = {
    'style': 'mapbox://styles/mapbox/streets-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}
mybasemap = {
    #'style': 'mapbox://styles/mapbox/streets-v9',
    'style': 'mapbox://styles/mapbox/satellite-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}

# %%
from cartoframes.viz import *

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
for dname in ['poa']:#['kc', 'fc', 'sp', 'poa']:
    print(dname)
    data = np.load(f'{dname}/data.npz')
    
    dict1 = {'lat':data['X_train'][:,0], 'lng': data['X_train'][:,1], 'price': data['y_train']}
    dict2 = {'lat':data['X_test'][:,0], 'lng': data['X_test'][:,1], 'price': data['y_test']}
    attr_names = []
    for a in range(2, data['X_train'].shape[1]):
        dict1.update({f'attr{a-2}': data['X_train'][:, a]})
        dict2.update({f'attr{a-2}': data['X_test'][:, a]})
        attr_names.append(f'attr{a-2}')
    df1 = pd.DataFrame(dict1)
    df2 = pd.DataFrame(dict2)
    df = pd.concat([df1, df2])
    
    train_gdf = gpd.GeoDataFrame(df1.copy(), geometry=gpd.points_from_xy(x=df1.lng, y=df1.lat))
    train_gdf.crs = 'EPSG:4326'
    test_gdf = gpd.GeoDataFrame(df2.copy(), geometry=gpd.points_from_xy(x=df2.lng, y=df2.lat))
    test_gdf.crs = 'EPSG:4326'
    house_gdf = gpd.GeoDataFrame(df.copy(), geometry=gpd.points_from_xy(x=df.lng, y=df.lat))
    house_gdf.crs = 'EPSG:4326'
    #print(np.exp(df['price'].values).mean())
    gdf = house_gdf
    for attr in attr_names:
        print(attr, gdf[attr].nunique())
        if gdf[attr].nunique() < 30:
            gdf[attr] = gdf[attr].astype(str)
    gdfcpy = gdf.copy()
    
    
#     display(Map(
#         [
#             Layer(gdfcpy, color_category_style(tattr, cat=cat, palette='cb_blues'), encode_data=False),
#             Layer(gdf, color_continuous_style('price', palette='sunset'), encode_data=False),
#         ],
#         basemap=mybasemap))
    
    break
# Out:
# poa
# attr0 9
# attr1 2644
# attr2 10
# attr3 2
# attr4 2

# %%
import osmnx as ox
from shapely.geometry import *

if not os.path.isdir('osmdata'):
    os.mkdir('osmdata')
    
DATASET_NAME = dname
OSM_FILE_PATH = f'osmdata/{DATASET_NAME}.graphml'

from shapely.geometry import MultiPoint


x1, y1, x2, y2 = gdf.total_bounds

house_center_latitude = (y1 + y2)/2 #sensor_hull.centroid.y
house_center_longitude = (x1 + x2)/2 #sensor_hull.centroid.x

     
graphs = dict()
# retrieve the street network for the location
if not os.path.isfile(OSM_FILE_PATH):
    center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
    center_point.crs = 'epsg:4326'
    center_point = center_point.to_crs('epsg:3310')
    max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
    print('max_distance:', max_distance)
    graph = ox.graph_from_point((house_center_latitude, house_center_longitude), dist=max_distance)

    # save the street network to a shapefile
    ox.save_graphml(graph, filepath=OSM_FILE_PATH)
else:
    graph = ox.load_graphml(filepath=OSM_FILE_PATH)
    

# buildings = buildings.reset_index()
# buildings.geometry = buildings.geometry.centroid

# %%
# graph2 = ox.graph_from_place('vashon')
# osm_nodes2, osm_edges2 = ox.graph_to_gdfs(graph2)
# osm_nodes1, osm_edges1 = ox.graph_to_gdfs(graph)

# osm_nodes = pd.concat((osm_nodes1, osm_nodes2))
# osm_edges = pd.concat((osm_edges1, osm_edges2))

osm_nodes, osm_edges = ox.graph_to_gdfs(graph)

# %%
osm_nodes['osmidn'] = osm_nodes.index
osm_nodes['osmidstr'] = osm_nodes['osmidn'].astype(str)
osm_edges = osm_edges.reset_index()
cond = np.array([str(type(s)) for s in osm_edges['highway']]) == "<class 'str'>"
osm_edges = osm_edges[cond]

# %%
alist = osm_nodes.geometry.tolist()

# %%
np.random.shuffle(alist)

# %%
Layer(gpd.GeoDataFrame(geometry=alist[:1000]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %%
center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
center_point.crs = 'epsg:4326'
center_point = center_point.to_crs('epsg:3310')
max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
buildings = ox.geometries.geometries_from_point((house_center_latitude, house_center_longitude), 
                                    tags = {'building': True},
                                    dist=max_distance)

# %%
rbuildings = buildings.reset_index()
fbuildings = buildings.reset_index()
fbuildings.geometry = fbuildings.geometry.centroid
fbuildings['nx'] = fbuildings.geometry.x
fbuildings['ny'] = fbuildings.geometry.y

fbuildings['barea'] = buildings.reset_index().to_crs('epsg:3310').area

corr_osmid = []
for _, htem in tqdm.tqdm(house_gdf.iterrows(), total=len(house_gdf)):
    ffbs = rbuildings[(fbuildings['nx'] > htem.lng - 0.002) & (fbuildings['nx'] < htem.lng + 0.002) & \
                        (fbuildings['ny'] > htem.lat - 0.002) & (fbuildings['ny'] < htem.lat + 0.002) & \
                         (fbuildings['barea'] > 70)]
    if len(ffbs) == 0:
        corr_osmid.append(-1)
    else:
        target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
        corr_osmid.append(target_bd['osmid'])

nhouse_gdf = house_gdf.copy()
nhouse_gdf['osmid'] = corr_osmid
# Out:
# /tmp/ipykernel_1320774/565877014.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   fbuildings.geometry = fbuildings.geometry.centroid
#   0%|                                                                                         | 0/15368 [00:00<?, ?it/s]/tmp/ipykernel_1320774/565877014.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
# 100%|████████████████████████████████████████████████████████████████████████████| 15368/15368 [02:14<00:00, 114.61it/s]

# %%
osmid2geo = {osmid:geo for osmid, geo in zip(rbuildings['osmid'], rbuildings['geometry'])}

geos = []
for i, osmid in enumerate(nhouse_gdf['osmid']):
    if osmid > 0:
        geos.append(osmid2geo[osmid])
    else:
        geos.append(house_gdf.iloc[i].geometry)

nhouse_gdf.geometry = geos
nhouse_gdf.geometry = nhouse_gdf.geometry.centroid
# Out:
# /tmp/ipykernel_1320774/2617699450.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nhouse_gdf.geometry = nhouse_gdf.geometry.centroid

# %% [markdown]
# # Next

# %%
import node2vec
import numpy as np
import networkx as nx
from gensim.models import Word2Vec

with open(f'{dname}/Adj.txt', 'w') as fp:
    for _, item in osm_edges.iterrows():
        fp.write(f'{item.u} {item.v} 1.0\n')
        
        
def read_graph(edgelist):
    G = nx.read_edgelist(
        edgelist, nodetype=str, data=(('weight',float),),
        create_using=nx.DiGraph())
    return G

Adj_file = f'{dname}/Adj.txt'
nx_G = read_graph(Adj_file)

num_walks = 10
walk_length = 20
p = 2
q = 1
is_directed = True

G = node2vec.Graph(nx_G, is_directed, p, q)
G.preprocess_transition_probs()
node2vec_walks = G.simulate_walks(num_walks, walk_length)
# Out:
# /disk1/jupyter/smhan/ASI/datasets/node2vec.py:120: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   J = np.zeros(K, dtype=np.int)
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10

# %%
from gensim.models import Word2Vec

vector_size = 32
sentences = node2vec_walks
model_node = Word2Vec(sentences, window=5, min_count=0, workers=4, vector_size=vector_size)

edge_discover_path_list = []
for path in node2vec_walks:# + discover_path_list:
    edge = []
    for u, v in zip(path[:-1], path[1:]):
        edge.append(f'{u}-{v}')
    edge_discover_path_list.append(edge)
sentences = edge_discover_path_list
model_edge = Word2Vec(sentences, window=5, min_count=1, workers=4, vector_size=vector_size)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 199671 words, keeping 55101 word types
# PROGRESS: at sentence #20000, processed 399352 words, keeping 65226 word types
# PROGRESS: at sentence #30000, processed 599087 words, keeping 67743 word types
# PROGRESS: at sentence #40000, processed 798747 words, keeping 68467 word types
# PROGRESS: at sentence #50000, processed 998531 words, keeping 68663 word types
# PROGRESS: at sentence #60000, processed 1198205 words, keeping 68740 word types
# PROGRESS: at sentence #70000, processed 1397806 words, keeping 68767 word types
# PROGRESS: at sentence #80000, processed 1597515 words, keeping 68767 word types
# PROGRESS: at sentence #90000, processed 1797154 words, keeping 68767 word types
# PROGRESS: at sentence #100000, processed 1996876 words, keeping 68767 word types
# PROGRESS: at sentence #110000, processed 2196647 words, keeping 68767 word types
# PROGRESS: at sentence #120000, processed 2396249 words, keeping 68767 word types
# PROGRESS: at sentence #130000, processed 2595899 words, keeping 68767 word types
# PROGRESS: at sentence #140000, processed 2795563 words, keeping 68767 word types
# PROGRESS: at sentence #150000, processed 2995269 words, keeping 68767 word types
# PROGRESS: at sentence #160000, processed 3194969 words, keeping 68767 word types
# PROGRESS: at sentence #170000, processed 3394656 words, keeping 68767 word types
# PROGRESS: at sentence #180000, processed 3594336 words, keeping 68767 word types
# PROGRESS: at sentence #190000, processed 3793979 words, keeping 68767 word types
# PROGRESS: at sentence #200000, processed 3993695 words, keeping 68767 word types
# PROGRESS: at sentence #210000, processed 4193304 words, keeping 68767 word types
# PROGRESS: at sentence #220000, processed 4392916 words, keeping 68767 word types
# PROGRESS: at sentence #230000, processed 4592731 words, keeping 68767 word types
# PROGRESS: at sentence #240000, processed 4792434 words, keeping 68767 word types
# PROGRESS: at sentence #250000, processed 4992128 words, keeping 68767 word types
# PROGRESS: at sentence #260000, processed 5191906 words, keeping 68767 word types
# PROGRESS: at sentence #270000, processed 5391541 words, keeping 68767 word types
# PROGRESS: at sentence #280000, processed 5591188 words, keeping 68767 word types
# PROGRESS: at sentence #290000, processed 5790869 words, keeping 68767 word types
# PROGRESS: at sentence #300000, processed 5990610 words, keeping 68767 word types
# PROGRESS: at sentence #310000, processed 6190336 words, keeping 68767 word types
# PROGRESS: at sentence #320000, processed 6389871 words, keeping 68767 word types
# PROGRESS: at sentence #330000, processed 6589709 words, keeping 68767 word types
# PROGRESS: at sentence #340000, processed 6789360 words, keeping 68767 word types
# PROGRESS: at sentence #350000, processed 6988910 words, keeping 68767 word types
# PROGRESS: at sentence #360000, processed 7188601 words, keeping 68767 word types
# PROGRESS: at sentence #370000, processed 7388281 words, keeping 68767 word types
# PROGRESS: at sentence #380000, processed 7587964 words, keeping 68767 word types
# PROGRESS: at sentence #390000, processed 7787584 words, keeping 68767 word types
# PROGRESS: at sentence #400000, processed 7987418 words, keeping 68767 word types
# PROGRESS: at sentence #410000, processed 8187170 words, keeping 68767 word types
# PROGRESS: at sentence #420000, processed 8386864 words, keeping 68767 word types
# PROGRESS: at sentence #430000, processed 8586448 words, keeping 68767 word types
# PROGRESS: at sentence #440000, processed 8786221 words, keeping 68767 word types
# PROGRESS: at sentence #450000, processed 8985981 words, keeping 68767 word types
# PROGRESS: at sentence #460000, processed 9185783 words, keeping 68767 word types
# PROGRESS: at sentence #470000, processed 9385492 words, keeping 68767 word types
# PROGRESS: at sentence #480000, processed 9585288 words, keeping 68767 word types
# PROGRESS: at sentence #490000, processed 9785026 words, keeping 68767 word types
# PROGRESS: at sentence #500000, processed 9984664 words, keeping 68767 word types
# PROGRESS: at sentence #510000, processed 10184446 words, keeping 68767 word types
# PROGRESS: at sentence #520000, processed 10384074 words, keeping 68767 word types
# PROGRESS: at sentence #530000, processed 10583778 words, keeping 68767 word types
# PROGRESS: at sentence #540000, processed 10783323 words, keeping 68767 word types
# PROGRESS: at sentence #550000, processed 10983026 words, keeping 68767 word types
# PROGRESS: at sentence #560000, processed 11182749 words, keeping 68767 word types
# PROGRESS: at sentence #570000, processed 11382504 words, keeping 68767 word types
# PROGRESS: at sentence #580000, processed 11582263 words, keeping 68767 word types
# PROGRESS: at sentence #590000, processed 11782003 words, keeping 68767 word types
# PROGRESS: at sentence #600000, processed 11981606 words, keeping 68767 word types
# PROGRESS: at sentence #610000, processed 12181269 words, keeping 68767 word types
# PROGRESS: at sentence #620000, processed 12380947 words, keeping 68767 word types
# PROGRESS: at sentence #630000, processed 12580731 words, keeping 68767 word types
# PROGRESS: at sentence #640000, processed 12780313 words, keeping 68767 word types
# PROGRESS: at sentence #650000, processed 12980088 words, keeping 68767 word types
# PROGRESS: at sentence #660000, processed 13179760 words, keeping 68767 word types
# PROGRESS: at sentence #670000, processed 13379481 words, keeping 68767 word types
# PROGRESS: at sentence #680000, processed 13579059 words, keeping 68767 word types
# collected 68767 word types from a corpus of 13732160 raw words and 687670 sentences
# Creating a fresh vocabulary
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 68767 unique words (100.00% of original 68767, drops 0)', 'datetime': '2023-08-21T18:46:25.118998', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 13732160 word corpus (100.00% of original 13732160, drops 0)', 'datetime': '2023-08-21T18:46:25.119408', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# deleting the raw counts dictionary of 68767 items
# sample=0.001 downsamples 0 most-common words
# Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 13732160 word corpus (100.0%% of prior 13732160)', 'datetime': '2023-08-21T18:46:25.327027', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# estimated required memory for 68767 words and 32 dimensions: 51987852 bytes
# resetting layer weights
# Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-08-21T18:46:25.681319', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# Word2Vec lifecycle event {'msg': 'training model with 4 workers on 68767 vocabulary and 32 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-08-21T18:46:25.681806', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# EPOCH 0 - PROGRESS: at 16.37% examples, 2248263 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 33.55% examples, 2299311 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 50.72% examples, 2316868 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 67.82% examples, 2323472 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 84.92% examples, 2327376 words/s, in_qsize 7, out_qsize 0
# EPOCH 0: training on 13732160 raw words (13732160 effective words) took 5.9s, 2330995 effective words/s
# EPOCH 1 - PROGRESS: at 16.88% examples, 2310951 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 34.27% examples, 2346233 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 51.96% examples, 2373086 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 70.15% examples, 2403882 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 88.99% examples, 2439374 words/s, in_qsize 7, out_qsize 0
# EPOCH 1: training on 13732160 raw words (13732160 effective words) took 5.6s, 2462465 effective words/s
# EPOCH 2 - PROGRESS: at 19.14% examples, 2625864 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 39.44% examples, 2702615 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 60.18% examples, 2747772 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 81.28% examples, 2783191 words/s, in_qsize 7, out_qsize 0
# EPOCH 2: training on 13732160 raw words (13732160 effective words) took 4.9s, 2809889 effective words/s
# EPOCH 3 - PROGRESS: at 20.52% examples, 2817674 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 42.35% examples, 2905733 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 64.25% examples, 2939643 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 86.37% examples, 2961959 words/s, in_qsize 7, out_qsize 0
# EPOCH 3: training on 13732160 raw words (13732160 effective words) took 4.6s, 2974157 effective words/s
# EPOCH 4 - PROGRESS: at 21.03% examples, 2883302 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 42.93% examples, 2941118 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 64.91% examples, 2964320 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 86.88% examples, 2976549 words/s, in_qsize 7, out_qsize 0
# EPOCH 4: training on 13732160 raw words (13732160 effective words) took 4.6s, 2983766 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 68660800 raw words (68660800 effective words) took 25.6s, 2681613 effective words/s', 'datetime': '2023-08-21T18:46:51.286426', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=68767, vector_size=32, alpha=0.025>', 'datetime': '2023-08-21T18:46:51.287123', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'created'}
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 189671 words, keeping 100251 word types
# PROGRESS: at sentence #20000, processed 379352 words, keeping 139222 word types
# PROGRESS: at sentence #30000, processed 569087 words, keeping 154788 word types
# PROGRESS: at sentence #40000, processed 758747 words, keeping 160718 word types
# PROGRESS: at sentence #50000, processed 948531 words, keeping 163056 word types
# PROGRESS: at sentence #60000, processed 1138205 words, keeping 164031 word types
# PROGRESS: at sentence #70000, processed 1327806 words, keeping 164382 word types
# PROGRESS: at sentence #80000, processed 1517515 words, keeping 164508 word types
# PROGRESS: at sentence #90000, processed 1707154 words, keeping 164570 word types
# PROGRESS: at sentence #100000, processed 1896876 words, keeping 164601 word types
# PROGRESS: at sentence #110000, processed 2086647 words, keeping 164627 word types
# PROGRESS: at sentence #120000, processed 2276249 words, keeping 164633 word types
# PROGRESS: at sentence #130000, processed 2465899 words, keeping 164638 word types
# PROGRESS: at sentence #140000, processed 2655563 words, keeping 164640 word types
# PROGRESS: at sentence #150000, processed 2845269 words, keeping 164641 word types
# PROGRESS: at sentence #160000, processed 3034969 words, keeping 164642 word types
# PROGRESS: at sentence #170000, processed 3224656 words, keeping 164642 word types
# PROGRESS: at sentence #180000, processed 3414336 words, keeping 164642 word types
# PROGRESS: at sentence #190000, processed 3603979 words, keeping 164642 word types
# PROGRESS: at sentence #200000, processed 3793695 words, keeping 164642 word types
# PROGRESS: at sentence #210000, processed 3983304 words, keeping 164643 word types
# PROGRESS: at sentence #220000, processed 4172916 words, keeping 164643 word types
# PROGRESS: at sentence #230000, processed 4362731 words, keeping 164643 word types
# PROGRESS: at sentence #240000, processed 4552434 words, keeping 164643 word types
# PROGRESS: at sentence #250000, processed 4742128 words, keeping 164643 word types
# PROGRESS: at sentence #260000, processed 4931906 words, keeping 164644 word types
# PROGRESS: at sentence #270000, processed 5121541 words, keeping 164645 word types
# PROGRESS: at sentence #280000, processed 5311188 words, keeping 164645 word types
# PROGRESS: at sentence #290000, processed 5500869 words, keeping 164645 word types
# PROGRESS: at sentence #300000, processed 5690610 words, keeping 164645 word types
# PROGRESS: at sentence #310000, processed 5880336 words, keeping 164645 word types
# PROGRESS: at sentence #320000, processed 6069871 words, keeping 164645 word types
# PROGRESS: at sentence #330000, processed 6259709 words, keeping 164645 word types
# PROGRESS: at sentence #340000, processed 6449360 words, keeping 164645 word types
# PROGRESS: at sentence #350000, processed 6638910 words, keeping 164645 word types
# PROGRESS: at sentence #360000, processed 6828601 words, keeping 164645 word types
# PROGRESS: at sentence #370000, processed 7018281 words, keeping 164645 word types
# PROGRESS: at sentence #380000, processed 7207964 words, keeping 164646 word types
# PROGRESS: at sentence #390000, processed 7397584 words, keeping 164646 word types
# PROGRESS: at sentence #400000, processed 7587418 words, keeping 164646 word types
# PROGRESS: at sentence #410000, processed 7777170 words, keeping 164646 word types
# PROGRESS: at sentence #420000, processed 7966864 words, keeping 164646 word types
# PROGRESS: at sentence #430000, processed 8156448 words, keeping 164646 word types
# PROGRESS: at sentence #440000, processed 8346221 words, keeping 164646 word types
# PROGRESS: at sentence #450000, processed 8535981 words, keeping 164646 word types
# PROGRESS: at sentence #460000, processed 8725783 words, keeping 164646 word types
# PROGRESS: at sentence #470000, processed 8915492 words, keeping 164646 word types
# PROGRESS: at sentence #480000, processed 9105288 words, keeping 164646 word types
# PROGRESS: at sentence #490000, processed 9295026 words, keeping 164646 word types
# PROGRESS: at sentence #500000, processed 9484664 words, keeping 164646 word types
# PROGRESS: at sentence #510000, processed 9674446 words, keeping 164646 word types
# PROGRESS: at sentence #520000, processed 9864074 words, keeping 164646 word types
# PROGRESS: at sentence #530000, processed 10053778 words, keeping 164646 word types
# PROGRESS: at sentence #540000, processed 10243323 words, keeping 164646 word types
# PROGRESS: at sentence #550000, processed 10433026 words, keeping 164646 word types
# PROGRESS: at sentence #560000, processed 10622749 words, keeping 164646 word types
# PROGRESS: at sentence #570000, processed 10812504 words, keeping 164646 word types
# PROGRESS: at sentence #580000, processed 11002263 words, keeping 164646 word types
# PROGRESS: at sentence #590000, processed 11192003 words, keeping 164646 word types
# PROGRESS: at sentence #600000, processed 11381606 words, keeping 164646 word types
# PROGRESS: at sentence #610000, processed 11571269 words, keeping 164646 word types
# PROGRESS: at sentence #620000, processed 11760947 words, keeping 164646 word types
# PROGRESS: at sentence #630000, processed 11950731 words, keeping 164646 word types
# PROGRESS: at sentence #640000, processed 12140313 words, keeping 164646 word types
# PROGRESS: at sentence #650000, processed 12330088 words, keeping 164646 word types
# PROGRESS: at sentence #660000, processed 12519760 words, keeping 164646 word types
# PROGRESS: at sentence #670000, processed 12709481 words, keeping 164646 word types
# PROGRESS: at sentence #680000, processed 12899059 words, keeping 164646 word types
# collected 164646 word types from a corpus of 13044490 raw words and 687670 sentences
# Creating a fresh vocabulary
# Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 164646 unique words (100.00% of original 164646, drops 0)', 'datetime': '2023-08-21T18:46:57.354523', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 13044490 word corpus (100.00% of original 13044490, drops 0)', 'datetime': '2023-08-21T18:46:57.355037', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# deleting the raw counts dictionary of 164646 items
# sample=0.001 downsamples 0 most-common words
# Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 13044490 word corpus (100.0%% of prior 13044490)', 'datetime': '2023-08-21T18:46:57.860786', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# estimated required memory for 164646 words and 32 dimensions: 124472376 bytes
# resetting layer weights
# Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-08-21T18:46:58.732986', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'build_vocab'}
# Word2Vec lifecycle event {'msg': 'training model with 4 workers on 164646 vocabulary and 32 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-08-21T18:46:58.733485', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# EPOCH 0 - PROGRESS: at 14.78% examples, 1928019 words/s, in_qsize 8, out_qsize 0
# EPOCH 0 - PROGRESS: at 30.18% examples, 1968049 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 45.66% examples, 1983983 words/s, in_qsize 8, out_qsize 0
# EPOCH 0 - PROGRESS: at 61.13% examples, 1991254 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 76.60% examples, 1996448 words/s, in_qsize 7, out_qsize 0
# EPOCH 0 - PROGRESS: at 92.07% examples, 1999397 words/s, in_qsize 7, out_qsize 0
# EPOCH 0: training on 13044490 raw words (13044490 effective words) took 6.5s, 2004121 effective words/s
# EPOCH 1 - PROGRESS: at 14.63% examples, 1902774 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 30.03% examples, 1953476 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 45.50% examples, 1973346 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 60.90% examples, 1979998 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 76.37% examples, 1986715 words/s, in_qsize 7, out_qsize 0
# EPOCH 1 - PROGRESS: at 91.84% examples, 1990402 words/s, in_qsize 7, out_qsize 0
# EPOCH 1: training on 13044490 raw words (13044490 effective words) took 6.5s, 1994660 effective words/s
# EPOCH 2 - PROGRESS: at 14.94% examples, 1944010 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 30.18% examples, 1964066 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 45.50% examples, 1971431 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 60.82% examples, 1976250 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 76.14% examples, 1978712 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 91.46% examples, 1980068 words/s, in_qsize 7, out_qsize 0
# EPOCH 2: training on 13044490 raw words (13044490 effective words) took 6.6s, 1983013 effective words/s
# EPOCH 3 - PROGRESS: at 15.01% examples, 1944848 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 30.49% examples, 1977708 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 45.96% examples, 1987059 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 61.36% examples, 1992096 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 76.75% examples, 1994881 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 92.07% examples, 1994279 words/s, in_qsize 7, out_qsize 0
# EPOCH 3: training on 13044490 raw words (13044490 effective words) took 6.5s, 1996884 effective words/s
# EPOCH 4 - PROGRESS: at 15.01% examples, 1954196 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 30.49% examples, 1984953 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 45.96% examples, 1994551 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 61.51% examples, 2000917 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 76.98% examples, 2003549 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 92.45% examples, 2005963 words/s, in_qsize 7, out_qsize 0
# EPOCH 4: training on 13044490 raw words (13044490 effective words) took 6.5s, 2008373 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 65222450 raw words (65222450 effective words) took 32.7s, 1995354 effective words/s', 'datetime': '2023-08-21T18:47:31.420933', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=164646, vector_size=32, alpha=0.025>', 'datetime': '2023-08-21T18:47:31.421774', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
magnitudes = []
for osmid in osm_nodes['osmidstr']:
    if osmid in model_node.wv:
        vec = model_node.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_nodes['magnitude'] = magnitudes
# Layer(osm_nodes_3310[osm_nodes_3310['magnitude'] > 0], color_continuous_style('magnitude'))


magnitudes = []
osm_edges['u-v'] = osm_edges['u'].astype(str) + '-' + osm_edges['v'].astype(str)
for osmid in osm_edges['u-v']:
    if osmid in model_edge.wv:
        vec = model_edge.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_edges['magnitude'] = magnitudes
# Layer(osm_edges_3310[osm_edges_3310['magnitude'] > 0], color_continuous_style('magnitude'))

# %%
# ftest_edges = osm_edges_3310[osm_edges_3310['magnitude'] > 0].copy()
# ftest_edges['bx'] = ftest_edges.geometry.centroid.x
# ftest_edges['by'] = ftest_edges.geometry.centroid.y

# house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
# house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
# house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# vectors = []
# for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
#     iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
#                 (ftest_edges['bx'] < item['bx'] + 500) & 
#                 (ftest_edges['by'] > item['by'] - 500) & 
#                 (ftest_edges['by'] < item['by'] + 500)]
    
#     jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
#     vec = model.wv[jtem['u-v']]
#     vectors.append(vec)

# %%
ftest_nodes = osm_nodes[osm_nodes['magnitude'] > 0].to_crs('epsg:3310')
ftest_nodes['bx'] = ftest_nodes.geometry.centroid.x
ftest_nodes['by'] = ftest_nodes.geometry.centroid.y
fosmid2geo = {osmid:geo for osmid, geo in zip(ftest_nodes['osmidstr'], ftest_nodes['geometry'])}

ftest_edges = osm_edges[osm_edges['magnitude'] > 0].to_crs('epsg:3310')
ftest_edges['bx'] = ftest_edges.geometry.centroid.x
ftest_edges['by'] = ftest_edges.geometry.centroid.y

house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# %%
vectors = []
geos = []
for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
    iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
                                (ftest_edges['bx'] < item['bx'] + 500) & 
                                (ftest_edges['by'] > item['by'] - 500) & 
                                (ftest_edges['by'] < item['by'] + 500)]
    if len(iftest_edges) == 0:
        iftest_edges = ftest_edges
    
    
    jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
    u, v = str(jtem['u']), str(jtem['v'])
    vec_u, vec_v = model_node.wv[u], model_node.wv[v]
    dist_u, dist_v = item.geometry.distance(fosmid2geo[u]), item.geometry.distance(fosmid2geo[v])
    ratios = np.array([1/dist_u, 1/dist_v])
    ratios /= np.sum(ratios)
    
    
    vec = vec_u*ratios[0] + vec_v*ratios[1]
    vectors.append(vec)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 15368/15368 [00:31<00:00, 493.87it/s]

# %%
np.save(f'{dname}/road2vec_n2v_32_nodes.npy', vectors)

# %%
house_gdf_3310 = house_gdf.to_crs('epsg:3310')
thouse_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
n2v_vectors = np.array(vectors)
n2v_vectors_train = n2v_vectors[:len(thouse_gdf_3310)]

# %%
train_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
dist_mat = []
for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    mdist1 = np.linalg.norm(n2v_vectors[i] - n2v_vectors_train, axis=-1)
    mdist1 /= mdist1.std()
    #dist_mat.append(mdist1)
    mdist2 = train_gdf_3310.distance(item.geometry).values
    mdist2 /= mdist2.std()
    dist_mat.append(mdist1 + mdist2*10)
dist_mat = np.stack(dist_mat, 0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 15368/15368 [00:52<00:00, 291.15it/s]

# %%
j=100
ahgdf = train_gdf.copy()
ahgdf['diststr'] = dist_mat[j]

# %%
Map([
#     Layer(fhgdf, color_continuous_style('diststr', palette='sunset')),
#     Layer(gdf.iloc[data_ori['idx_geo'][j]], color_continuous_style('price', palette='sunset'))
    Layer(ahgdf.iloc[dist_mat[j].argsort()[1:61]], color_continuous_style('diststr', palette='sunset')),
    Layer(house_gdf.iloc[[j]], basic_style(color='green')),

])
# Out:
# /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/cartoframes/utils/utils.py:552: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   parameter_args = inspect.getargspec(decorated_function).args
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;diststr&quot;
#                 description=&quot;&quot;>
#                 <as-legend-color-continuous id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {

# %%
new_idx = []
new_dist_eucli = []
new_dist_geo = []

for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    target = item.values[:-1]
    candidates = thouse_gdf_3310.iloc[dist_mat[i].argsort()[1:61]].values[:, :-1]
    new_idx.append(dist_mat[i].argsort()[1:61])
    new_dist_geo.append(dist_mat[i][dist_mat[i].argsort()[1:61]])
    new_dist_eucli.append(np.linalg.norm(target.astype(float) - candidates.astype(float), axis=-1))
    
new_idx = np.stack(new_idx, 0)
new_dist_eucli = np.stack(new_dist_eucli, 0)
new_dist_geo = np.stack(new_dist_geo, 0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 15368/15368 [00:47<00:00, 326.68it/s]

# %%
newdata = dict() 
newdata['X_train'] = data['X_train']
newdata['y_train'] = data['y_train']
newdata['X_test'] = data['X_test']
newdata['y_test'] = data['y_test']
newdata['idx_eucli'] = new_idx
newdata['idx_geo'] = new_idx
newdata['dist_eucli'] = new_dist_eucli
newdata['dist_geo'] = new_dist_geo

# %%
dname
# Out:
# 'poa'

# %%
np.savez(f'{dname}/data_n2v_nodes.npz', **newdata)

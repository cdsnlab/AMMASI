# %%
import os, tqdm

# %%
from sklearn.metrics import r2_score
import numpy as np

# metric
def metric(label, pred):
    assert label.shape == pred.shape
    
    with np.errstate(divide = 'ignore', invalid = 'ignore'):
        mask = (label == label) & (pred == pred)
        mask = mask.astype(np.float32)
        mask /= np.mean(mask)
        
        male = np.abs(np.subtract(np.log(pred), np.log(label))).astype(np.float32)
        mae = np.abs(np.subtract(pred, label)).astype(np.float32)
        
        male = np.nan_to_num(male * mask)
        male = np.mean(male)
        
        mae = np.nan_to_num(mae * mask)
        mae = np.mean(mae)
        
        rmse = np.square(mae)
        rmse = np.nan_to_num(rmse * mask)
        rmse = np.sqrt(np.mean(rmse))
        
        mape = np.divide(mae, label)
        mape = np.nan_to_num(mape * mask)
        mape = np.median(mape*mask)
        
        print('masked:', np.sum(mask == 0))
    return male, rmse, mape

# %%
os.listdir('.')
# Out:
# ['house-dataset-osm-road2vec-poa.ipynb',
#  'house-dataset-visualization.html',
#  'house-dataset-visualization.ipynb',
#  '.ipynb_checkpoints',
#  'house-lgbm.ipynb',
#  'generateSE.py',
#  'sp',
#  'house-dataset-visualization-Copy1.ipynb',
#  'house-dataset-osm-road2vec-dbscan.ipynb',
#  'node2vec.py',
#  '.gitkeep ',
#  'poa',
#  'house-dataset-osm-road2vec-Copy2.ipynb',
#  'fc',
#  'kc',
#  'house-dataset-osm-road2vec-fc.ipynb',
#  'house-dataset-osm-road2vec-kc.ipynb',
#  'house_reverse_geocoding.py',
#  '__pycache__',
#  'house-lgbm-sonia.ipynb',
#  'house-dataset-osm-road2vec-Copy1.ipynb',
#  'house-dataset-osm-road2vec-sp.ipynb',
#  'osmdata',
#  'house-dataset-osm-road2vec.ipynb',
#  'house-dataset-osm-buildings.ipynb',
#  'house-dataset-osm-buildings-Copy1.ipynb',
#  'cache']

# %%
datasets = ['fc']

# %%
import numpy as np

# %%
streetmap = {
    'style': 'mapbox://styles/mapbox/streets-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}
mybasemap = {
    #'style': 'mapbox://styles/mapbox/streets-v9',
    'style': 'mapbox://styles/mapbox/satellite-v9',
    'token': 'pk.eyJ1IjoiaHNtNjkxMSIsImEiOiJjazl0and6aDUwOWF2M2RvemdrYjllczV3In0.qGmaAF6v-1LAF9C-dnMLBg'
}

# %%
from cartoframes.viz import *
# Out:
# Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
for dname in ['fc']:#['kc', 'fc', 'sp', 'poa']:
    print(dname)
    data = np.load(f'{dname}/data.npz')
    
    dict1 = {'lat':data['X_train'][:,0], 'lng': data['X_train'][:,1], 'price': data['y_train']}
    dict2 = {'lat':data['X_test'][:,0], 'lng': data['X_test'][:,1], 'price': data['y_test']}
    attr_names = []
    for a in range(2, data['X_train'].shape[1]):
        dict1.update({f'attr{a-2}': data['X_train'][:, a]})
        dict2.update({f'attr{a-2}': data['X_test'][:, a]})
        attr_names.append(f'attr{a-2}')
    df1 = pd.DataFrame(dict1)
    df2 = pd.DataFrame(dict2)
    df = pd.concat([df1, df2])
    
    train_gdf = gpd.GeoDataFrame(df1.copy(), geometry=gpd.points_from_xy(x=df1.lng, y=df1.lat))
    train_gdf.crs = 'EPSG:4326'
    test_gdf = gpd.GeoDataFrame(df2.copy(), geometry=gpd.points_from_xy(x=df2.lng, y=df2.lat))
    test_gdf.crs = 'EPSG:4326'
    house_gdf = gpd.GeoDataFrame(df.copy(), geometry=gpd.points_from_xy(x=df.lng, y=df.lat))
    house_gdf.crs = 'EPSG:4326'
    #print(np.exp(df['price'].values).mean())
    gdf = house_gdf
    for attr in attr_names:
        print(attr, gdf[attr].nunique())
        if gdf[attr].nunique() < 30:
            gdf[attr] = gdf[attr].astype(str)
    gdfcpy = gdf.copy()
    
    
#     display(Map(
#         [
#             Layer(gdfcpy, color_category_style(tattr, cat=cat, palette='cb_blues'), encode_data=False),
#             Layer(gdf, color_continuous_style('price', palette='sunset'), encode_data=False),
#         ],
#         basemap=mybasemap))
    
    break
# Out:
# fc
# attr0 6447
# attr1 18
# attr2 11
# attr3 6447
# attr4 16372
# attr5 79
# attr6 3230
# attr7 8
# attr8 6

# %%
#vectors = np.load(f'{dname}/road2vec_n2v_32_nodes.npy')
np.save(f'{dname}/feat2vec_n2v_32_nodes.npy', df.values)

# %%
import osmnx as ox
from shapely.geometry import *

if not os.path.isdir('osmdata'):
    os.mkdir('osmdata')
    
DATASET_NAME = dname
OSM_FILE_PATH = f'osmdata/{DATASET_NAME}.graphml'

from shapely.geometry import MultiPoint


x1, y1, x2, y2 = gdf.total_bounds

house_center_latitude = (y1 + y2)/2 #sensor_hull.centroid.y
house_center_longitude = (x1 + x2)/2 #sensor_hull.centroid.x

     
graphs = dict()
# retrieve the street network for the location
if not os.path.isfile(OSM_FILE_PATH):
    center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
    center_point.crs = 'epsg:4326'
    center_point = center_point.to_crs('epsg:3310')
    max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
    print('max_distance:', max_distance)
    graph = ox.graph_from_point((house_center_latitude, house_center_longitude), dist=max_distance)

    # save the street network to a shapefile
    ox.save_graphml(graph, filepath=OSM_FILE_PATH)
else:
    graph = ox.load_graphml(filepath=OSM_FILE_PATH)
    

# buildings = buildings.reset_index()
# buildings.geometry = buildings.geometry.centroid

# %%
# graph2 = ox.graph_from_place('vashon')
# osm_nodes2, osm_edges2 = ox.graph_to_gdfs(graph2)
# osm_nodes1, osm_edges1 = ox.graph_to_gdfs(graph)

# osm_nodes = pd.concat((osm_nodes1, osm_nodes2))
# osm_edges = pd.concat((osm_edges1, osm_edges2))

osm_nodes, osm_edges = ox.graph_to_gdfs(graph)

# %%
osm_nodes['osmidn'] = osm_nodes.index
osm_nodes['osmidstr'] = osm_nodes['osmidn'].astype(str)
osm_edges = osm_edges.reset_index()
cond = np.array([str(type(s)) for s in osm_edges['highway']]) == "<class 'str'>"
osm_edges = osm_edges[cond]

# %%
alist = osm_nodes.geometry.tolist()

# %%
np.random.shuffle(alist)

# %%
Layer(gpd.GeoDataFrame(geometry=alist[:1000]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]

# %%
center_point = gpd.GeoDataFrame(geometry = [Point(house_center_longitude, house_center_latitude)])
center_point.crs = 'epsg:4326'
center_point = center_point.to_crs('epsg:3310')
max_distance = gdf.to_crs('epsg:3310').distance(center_point.iloc[0].geometry).max()+1000
buildings = ox.geometries.geometries_from_point((house_center_latitude, house_center_longitude), 
                                    tags = {'building': True},
                                    dist=max_distance)

# %%
rbuildings = buildings.reset_index()
fbuildings = buildings.reset_index()
fbuildings.geometry = fbuildings.geometry.centroid
fbuildings['nx'] = fbuildings.geometry.x
fbuildings['ny'] = fbuildings.geometry.y

fbuildings['barea'] = buildings.reset_index().to_crs('epsg:3310').area

corr_osmid = []
for _, htem in tqdm.tqdm(house_gdf.iterrows(), total=len(house_gdf)):
    ffbs = rbuildings[(fbuildings['nx'] > htem.lng - 0.002) & (fbuildings['nx'] < htem.lng + 0.002) & \
                        (fbuildings['ny'] > htem.lat - 0.002) & (fbuildings['ny'] < htem.lat + 0.002) & \
                         (fbuildings['barea'] > 70)]
    if len(ffbs) == 0:
        corr_osmid.append(-1)
    else:
        target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
        corr_osmid.append(target_bd['osmid'])

nhouse_gdf = house_gdf.copy()
nhouse_gdf['osmid'] = corr_osmid
# Out:
# /tmp/ipykernel_1321065/565877014.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   fbuildings.geometry = fbuildings.geometry.centroid
#   0%|                                                                                         | 0/68848 [00:00<?, ?it/s]/tmp/ipykernel_1321065/565877014.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   target_bd = ffbs.iloc[ffbs.distance(htem.geometry).values.argmin()]
# 100%|█████████████████████████████████████████████████████████████████████████████| 68848/68848 [15:42<00:00, 73.06it/s]

# %%
osmid2geo = {osmid:geo for osmid, geo in zip(rbuildings['osmid'], rbuildings['geometry'])}

geos = []
for i, osmid in enumerate(nhouse_gdf['osmid']):
    if osmid > 0:
        geos.append(osmid2geo[osmid])
    else:
        geos.append(house_gdf.iloc[i].geometry)

nhouse_gdf.geometry = geos
nhouse_gdf.geometry = nhouse_gdf.geometry.centroid
# Out:
# /tmp/ipykernel_1321065/2617699450.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nhouse_gdf.geometry = nhouse_gdf.geometry.centroid

# %% [markdown]
# # Next

# %%
import node2vec
import numpy as np
import networkx as nx
from gensim.models import Word2Vec

with open(f'{dname}/Adj.txt', 'w') as fp:
    for _, item in osm_edges.iterrows():
        fp.write(f'{item.u} {item.v} 1.0\n')
        
        
def read_graph(edgelist):
    G = nx.read_edgelist(
        edgelist, nodetype=str, data=(('weight',float),),
        create_using=nx.DiGraph())
    return G

Adj_file = f'{dname}/Adj.txt'
nx_G = read_graph(Adj_file)

num_walks = 10
walk_length = 20
p = 2
q = 1
is_directed = True

G = node2vec.Graph(nx_G, is_directed, p, q)
G.preprocess_transition_probs()
node2vec_walks = G.simulate_walks(num_walks, walk_length)
# Out:
# /disk1/jupyter/smhan/ASI/datasets/node2vec.py:120: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   J = np.zeros(K, dtype=np.int)
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10

# %%
from gensim.models import Word2Vec

vector_size = 32
sentences = node2vec_walks
model_node = Word2Vec(sentences, window=5, min_count=0, workers=4, vector_size=vector_size)

edge_discover_path_list = []
for path in node2vec_walks:# + discover_path_list:
    edge = []
    for u, v in zip(path[:-1], path[1:]):
        edge.append(f'{u}-{v}')
    edge_discover_path_list.append(edge)
sentences = edge_discover_path_list
model_edge = Word2Vec(sentences, window=5, min_count=1, workers=4, vector_size=vector_size)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# PROGRESS: at sentence #10000, processed 199808 words, keeping 106558 word types
# PROGRESS: at sentence #20000, processed 399588 words, keeping 183431 word types
# PROGRESS: at sentence #30000, processed 599401 words, keeping 238593 word types
# PROGRESS: at sentence #40000, processed 799160 words, keeping 279826 word types
# PROGRESS: at sentence #50000, processed 998927 words, keeping 309845 word types
# PROGRESS: at sentence #60000, processed 1198674 words, keeping 331613 word types
# PROGRESS: at sentence #70000, processed 1398570 words, keeping 348720 word types
# PROGRESS: at sentence #80000, processed 1598291 words, keeping 361554 word types
# PROGRESS: at sentence #90000, processed 1798061 words, keeping 371319 word types
# PROGRESS: at sentence #100000, processed 1997873 words, keeping 378698 word types
# PROGRESS: at sentence #110000, processed 2197514 words, keeping 384478 word types
# PROGRESS: at sentence #120000, processed 2397348 words, keeping 388932 word types
# PROGRESS: at sentence #130000, processed 2597119 words, keeping 392444 word types
# PROGRESS: at sentence #140000, processed 2796834 words, keeping 395396 word types
# PROGRESS: at sentence #150000, processed 2996597 words, keeping 397739 word types
# PROGRESS: at sentence #160000, processed 3196441 words, keeping 399626 word types
# PROGRESS: at sentence #170000, processed 3396175 words, keeping 401134 word types
# PROGRESS: at sentence #180000, processed 3595965 words, keeping 402335 word types
# PROGRESS: at sentence #190000, processed 3795646 words, keeping 403297 word types
# PROGRESS: at sentence #200000, processed 3995418 words, keeping 404003 word types
# PROGRESS: at sentence #210000, processed 4195095 words, keeping 404599 word types
# PROGRESS: at sentence #220000, processed 4394660 words, keeping 405105 word types
# PROGRESS: at sentence #230000, processed 4594479 words, keeping 405546 word types
# PROGRESS: at sentence #240000, processed 4794206 words, keeping 405905 word types
# PROGRESS: at sentence #250000, processed 4993934 words, keeping 406203 word types
# PROGRESS: at sentence #260000, processed 5193788 words, keeping 406445 word types
# PROGRESS: at sentence #270000, processed 5393544 words, keeping 406643 word types
# PROGRESS: at sentence #280000, processed 5593411 words, keeping 406802 word types
# PROGRESS: at sentence #290000, processed 5793249 words, keeping 406941 word types
# PROGRESS: at sentence #300000, processed 5993104 words, keeping 407051 word types
# PROGRESS: at sentence #310000, processed 6192877 words, keeping 407148 word types
# PROGRESS: at sentence #320000, processed 6392647 words, keeping 407217 word types
# PROGRESS: at sentence #330000, processed 6592319 words, keeping 407289 word types
# PROGRESS: at sentence #340000, processed 6791995 words, keeping 407331 word types
# PROGRESS: at sentence #350000, processed 6991668 words, keeping 407360 word types
# PROGRESS: at sentence #3790000, processed 75707753 words, keeping 407505 word types
# PROGRESS: at sentence #3800000, processed 75907542 words, keeping 407505 word types
# PROGRESS: at sentence #3810000, processed 76107269 words, keeping 407505 word types
# PROGRESS: at sentence #3820000, processed 76307026 words, keeping 407505 word types
# PROGRESS: at sentence #3830000, processed 76506838 words, keeping 407505 word types
# PROGRESS: at sentence #3840000, processed 76706674 words, keeping 407505 word types
# PROGRESS: at sentence #3850000, processed 76906450 words, keeping 407505 word types
# PROGRESS: at sentence #3860000, processed 77106134 words, keeping 407505 word types
# PROGRESS: at sentence #3870000, processed 77305954 words, keeping 407505 word types
# PROGRESS: at sentence #3880000, processed 77505738 words, keeping 407505 word types
# PROGRESS: at sentence #3890000, processed 77705362 words, keeping 407505 word types
# PROGRESS: at sentence #3900000, processed 77905129 words, keeping 407505 word types
# PROGRESS: at sentence #3910000, processed 78104796 words, keeping 407505 word types
# PROGRESS: at sentence #3920000, processed 78304630 words, keeping 407505 word types
# PROGRESS: at sentence #3930000, processed 78504453 words, keeping 407505 word types
# PROGRESS: at sentence #3940000, processed 78704204 words, keeping 407505 word types
# PROGRESS: at sentence #3950000, processed 78903934 words, keeping 407505 word types
# PROGRESS: at sentence #3960000, processed 79103561 words, keeping 407505 word types
# PROGRESS: at sentence #3970000, processed 79303348 words, keeping 407505 word types
# PROGRESS: at sentence #3980000, processed 79503145 words, keeping 407505 word types
# PROGRESS: at sentence #3990000, processed 79702941 words, keeping 407505 word types
# PROGRESS: at sentence #4000000, processed 79902644 words, keeping 407505 word types
# PROGRESS: at sentence #4010000, processed 80102526 words, keeping 407505 word types
# PROGRESS: at sentence #4020000, processed 80302253 words, keeping 407505 word types
# PROGRESS: at sentence #4030000, processed 80501914 words, keeping 407505 word types
# PROGRESS: at sentence #4040000, processed 80701679 words, keeping 407505 word types
# PROGRESS: at sentence #4050000, processed 80901397 words, keeping 407505 word types
# PROGRESS: at sentence #4060000, processed 81101157 words, keeping 407505 word types
# PROGRESS: at sentence #4070000, processed 81300926 words, keeping 407505 word types
# collected 407505 word types from a corpus of 81401804 raw words and 4075050 sentences
# Creating a fresh vocabulary
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 407505 unique words (100.00% of original 407505, drops 0)', 'datetime': '2023-08-21T19:20:42.657925', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 81401804 word corpus (100.00% of original 81401804, drops 0)', 'datetime': '2023-08-21T19:20:42.658780', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# deleting the raw counts dictionary of 407505 items
# sample=0.001 downsamples 0 most-common words
# Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 81401804 word corpus (100.0%% of prior 81401804)', 'datetime': '2023-08-21T19:20:43.982314', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'prepare_vocab'}
# estimated required memory for 407505 words and 32 dimensions: 308073780 bytes
# resetting layer weights
# Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023
words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 56.08% examples, 1018747 words/s, in_qsize 8, out_qsize 2
# EPOCH 2 - PROGRESS: at 57.17% examples, 1014253 words/s, in_qsize 8, out_qsize 2
# EPOCH 2 - PROGRESS: at 58.30% examples, 1011224 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 59.80% examples, 1014011 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 61.28% examples, 1016616 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 62.52% examples, 1015071 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 63.83% examples, 1015023 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 65.08% examples, 1013722 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 66.45% examples, 1013884 words/s, in_qsize 8, out_qsize 2
# EPOCH 2 - PROGRESS: at 67.71% examples, 1012741 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 68.99% examples, 1012264 words/s, in_qsize 8, out_qsize 0
# EPOCH 2 - PROGRESS: at 70.35% examples, 1012849 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 71.85% examples, 1015291 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 73.02% examples, 1013026 words/s, in_qsize 5, out_qsize 2
# EPOCH 2 - PROGRESS: at 74.25% examples, 1011882 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 75.62% examples, 1012274 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 76.87% examples, 1011105 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 78.10% examples, 1009962 words/s, in_qsize 8, out_qsize 1
# EPOCH 2 - PROGRESS: at 79.41% examples, 1009700 words/s, in_qsize 8, out_qsize 3
# EPOCH 2 - PROGRESS: at 80.53% examples, 1007407 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 82.00% examples, 1009448 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 83.54% examples, 1012255 words/s, in_qsize 8, out_qsize 0
# EPOCH 2 - PROGRESS: at 85.00% examples, 1013903 words/s, in_qsize 5, out_qsize 2
# EPOCH 2 - PROGRESS: at 86.29% examples, 1013589 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 87.69% examples, 1014519 words/s, in_qsize 7, out_qsize 0
# EPOCH 2 - PROGRESS: at 89.05% examples, 1014873 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 90.54% examples, 1016808 words/s, in_qsize 8, out_qsize 1
# EPOCH 2 - PROGRESS: at 92.04% examples, 1018793 words/s, in_qsize 8, out_qsize 1
# EPOCH 2 - PROGRESS: at 93.39% examples, 1018780 words/s, in_qsize 5, out_qsize 2
# EPOCH 2 - PROGRESS: at 94.89% examples, 1020580 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 96.36% examples, 1022111 words/s, in_qsize 6, out_qsize 1
# EPOCH 2 - PROGRESS: at 97.83% examples, 1023607 words/s, in_qsize 8, out_qsize 1
# EPOCH 2 - PROGRESS: at 99.33% examples, 1025244 words/s, in_qsize 8, out_qsize 1
# EPOCH 2: training on 77326754 raw words (77326754 effective words) took 75.3s, 1026294 effective words/s
# EPOCH 3 - PROGRESS: at 1.03% examples, 785300 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 2.43% examples, 917345 words/s, in_qsize 8, out_qsize 2
# EPOCH 3 - PROGRESS: at 3.88% examples, 981885 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 5.40% examples, 1027381 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 6.93% examples, 1054844 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 8.42% examples, 1071781 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 9.65% examples, 1052278 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 10.80% examples, 1027597 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 11.91% examples, 1007642 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 13.31% examples, 1014603 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 14.78% examples, 1024186 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 15.87% examples, 1006547 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 17.23% examples, 1009552 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 18.62% examples, 1014209 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 19.84% examples, 1008837 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 21.15% examples, 1008875 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 22.34% examples, 1002351 words/s, in_qsize 8, out_qsize 3
# EPOCH 3 - PROGRESS: at 23.48% examples, 993446 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 24.86% examples, 996963 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 25.95% examples, 988475 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 27.20% examples, 986333 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 28.34% examples, 981084 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 29.60% examples, 980768 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 30.74% examples, 975352 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 32.27% examples, 983112 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 33.73% examples, 988304 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 34.82% examples, 982774 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 36.01% examples, 979568 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 37.12% examples, 974252 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 38.74% examples, 982999 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 40.06% examples, 982773 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 41.22% examples, 980048 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 42.72% examples, 985250 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 44.14% examples, 988538 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 45.43% examples, 988678 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 46.57% examples, 985332 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 47.67% examples, 981033 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 48.91% examples, 980168 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 50.38% examples, 984158 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 51.74% examples, 985436 words/s, in_qsize 8, out_qsize 2
# EPOCH 3 - PROGRESS: at 53.11% examples, 986991 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 54.45% examples, 987870 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 55.67% examples, 986708 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 56.88% examples, 984903 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 58.41% examples, 988787 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 59.80% examples, 990679 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 60.95% examples, 988246 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 62.27% examples, 988209 words/s, in_qsize 5, out_qsize 2
# EPOCH 3 - PROGRESS: at 63.72% examples, 990212 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 65.24% examples, 993759 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 66.77% examples, 997291 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 68.01% examples, 996485 words/s, in_qsize 8, out_qsize 2
# EPOCH 3 - PROGRESS: at 69.28% examples, 995567 words/s, in_qsize 8, out_qsize 2
# EPOCH 3 - PROGRESS: at 70.61% examples, 996011 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 72.13% examples, 999040 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 73.66% examples, 1002143 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 74.97% examples, 1002155 words/s, in_qsize 8, out_qsize 1
# EPOCH 3 - PROGRESS: at 76.32% examples, 1002662 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 77.66% examples, 1002968 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 79.06% examples, 1004117 words/s, in_qsize 7, out_qsize 0
# EPOCH 3 - PROGRESS: at 80.54% examples, 1006294 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 81.76% examples, 1004999 words/s, in_qsize 7, out_qsize 3
# EPOCH 3 - PROGRESS: at 83.08% examples, 1005101 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 84.42% examples, 1005376 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 85.92% examples, 1007564 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 87.42% examples, 1009743 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 88.81% examples, 1010128 words/s, in_qsize 7, out_qsize 3
# EPOCH 3 - PROGRESS: at 90.13% examples, 1010092 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 91.49% examples, 1010621 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 92.95% examples, 1012231 words/s, in_qsize 8, out_qsize 0
# EPOCH 3 - PROGRESS: at 94.29% examples, 1012357 words/s, in_qsize 8, out_qsize 3
# EPOCH 3 - PROGRESS: at 95.43% examples, 1009837 words/s, in_qsize 4, out_qsize 3
# EPOCH 3 - PROGRESS: at 96.57% examples, 1007824 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 97.92% examples, 1008135 words/s, in_qsize 6, out_qsize 1
# EPOCH 3 - PROGRESS: at 99.03% examples, 1006167 words/s, in_qsize 8, out_qsize 2
# EPOCH 3: training on 77326754 raw words (77326754 effective words) took 77.0s, 1004478 effective words/s
# EPOCH 4 - PROGRESS: at 1.12% examples, 845080 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 2.22% examples, 842479 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 3.57% examples, 898238 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 4.94% examples, 936049 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 6.46% examples, 983082 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 7.99% examples, 1010085 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 9.41% examples, 1022401 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 10.83% examples, 1031129 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 12.28% examples, 1040638 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 13.77% examples, 1052093 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 15.17% examples, 1053679 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 16.63% examples, 1059395 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 18.08% examples, 1063208 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 19.46% examples, 1062983 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 20.74% examples, 1056879 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 22.06% examples, 1052622 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 23.50% examples, 1056318 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 25.00% examples, 1061709 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 26.48% examples, 1065664 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 27.98% examples, 1069707 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 29.48% examples, 1073819 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 30.61% examples, 1064664 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 31.71% examples, 1053882 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 32.80% examples, 1044938 words/s, in_qsize 8, out_qsize 3
# EPOCH 4 - PROGRESS: at 34.17% examples, 1045140 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 35.54% examples, 1044167 words/s, in_qsize 5, out_qsize 2
# EPOCH 4 - PROGRESS: at 36.67% examples, 1037147 words/s, in_qsize 4, out_qsize 3
# EPOCH 4 - PROGRESS: at 37.91% examples, 1033594 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 39.21% examples, 1031806 words/s, in_qsize 8, out_qsize 2
# EPOCH 4 - PROGRESS: at 40.63% examples, 1033695 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 42.10% examples, 1035716 words/s, in_qsize 8, out_qsize 2
# EPOCH 4 - PROGRESS: at 43.55% examples, 1037834 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 45.05% examples, 1040814 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 46.56% examples, 1044535 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 48.08% examples, 1048231 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 49.44% examples, 1047888 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 50.96% examples, 1051063 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 52.49% examples, 1054142 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 53.99% examples, 1056782 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 55.36% examples, 1056630 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 56.78% examples, 1057494 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 58.03% examples, 1055376 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 59.52% examples, 1057253 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 60.89% examples, 1056787 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 62.23% examples, 1056112 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 63.73% examples, 1058032 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 64.97% examples, 1055791 words/s, in_qsize 8, out_qsize 3
# EPOCH 4 - PROGRESS: at 66.42% examples, 1056949 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 67.58% examples, 1053228 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 69.03% examples, 1054332 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 70.13% examples, 1050077 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 71.63% examples, 1052024 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 73.07% examples, 1053264 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 74.57% examples, 1055009 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 75.80% examples, 1052804 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 77.33% examples, 1054995 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 78.80% examples, 1056206 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 80.06% examples, 1054635 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 81.27% examples, 1052521 words/s, in_qsize 7, out_qsize 3
# EPOCH 4 - PROGRESS: at 82.38% examples, 1048804 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 83.64% examples, 1047624 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 85.13% examples, 1049171 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 86.60% examples, 1050496 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 88.09% examples, 1051640 words/s, in_qsize 7, out_qsize 0
# EPOCH 4 - PROGRESS: at 89.56% examples, 1052823 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 91.06% examples, 1054222 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 92.28% examples, 1052426 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 93.44% examples, 1050088 words/s, in_qsize 8, out_qsize 1
# EPOCH 4 - PROGRESS: at 94.60% examples, 1047731 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 96.11% examples, 1049237 words/s, in_qsize 8, out_qsize 0
# EPOCH 4 - PROGRESS: at 97.57% examples, 1050333 words/s, in_qsize 6, out_qsize 1
# EPOCH 4 - PROGRESS: at 99.02% examples, 1051104 words/s, in_qsize 6, out_qsize 1
# EPOCH 4: training on 77326754 raw words (77326754 effective words) took 73.5s, 1052478 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 386633770 raw words (386633770 effective words) took 377.4s, 1024457 effective words/s', 'datetime': '2023-08-21T19:31:21.888655', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'train'}
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=980984, vector_size=32, alpha=0.025>', 'datetime': '2023-08-21T19:31:21.889301', 'gensim': '4.3.1', 'python': '3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]', 'platform': 'Linux-5.15.0-76-generic-x86_64-with-glibc2.31', 'event': 'created'}

# %%
magnitudes = []
for osmid in osm_nodes['osmidstr']:
    if osmid in model_node.wv:
        vec = model_node.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_nodes['magnitude'] = magnitudes
# Layer(osm_nodes_3310[osm_nodes_3310['magnitude'] > 0], color_continuous_style('magnitude'))


magnitudes = []
osm_edges['u-v'] = osm_edges['u'].astype(str) + '-' + osm_edges['v'].astype(str)
for osmid in osm_edges['u-v']:
    if osmid in model_edge.wv:
        vec = model_edge.wv[osmid]
        mag = np.linalg.norm(vec)
        magnitudes.append(mag)
    else:
        magnitudes.append(-1)
osm_edges['magnitude'] = magnitudes
# Layer(osm_edges_3310[osm_edges_3310['magnitude'] > 0], color_continuous_style('magnitude'))

# %%
# ftest_edges = osm_edges_3310[osm_edges_3310['magnitude'] > 0].copy()
# ftest_edges['bx'] = ftest_edges.geometry.centroid.x
# ftest_edges['by'] = ftest_edges.geometry.centroid.y

# house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
# house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
# house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# vectors = []
# for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
#     iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
#                 (ftest_edges['bx'] < item['bx'] + 500) & 
#                 (ftest_edges['by'] > item['by'] - 500) & 
#                 (ftest_edges['by'] < item['by'] + 500)]
    
#     jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
#     vec = model.wv[jtem['u-v']]
#     vectors.append(vec)

# %%
ftest_nodes = osm_nodes[osm_nodes['magnitude'] > 0].to_crs('epsg:3310')
ftest_nodes['bx'] = ftest_nodes.geometry.centroid.x
ftest_nodes['by'] = ftest_nodes.geometry.centroid.y
fosmid2geo = {osmid:geo for osmid, geo in zip(ftest_nodes['osmidstr'], ftest_nodes['geometry'])}

ftest_edges = osm_edges[osm_edges['magnitude'] > 0].to_crs('epsg:3310')
ftest_edges['bx'] = ftest_edges.geometry.centroid.x
ftest_edges['by'] = ftest_edges.geometry.centroid.y

house_gdf_3310 = nhouse_gdf.to_crs('epsg:3310')
house_gdf_3310['bx'] = house_gdf_3310.geometry.centroid.x
house_gdf_3310['by'] = house_gdf_3310.geometry.centroid.y

# %%
vectors = []
geos = []
for _, item in tqdm.tqdm(house_gdf_3310.iterrows(), total=len(house_gdf)):
    iftest_edges = ftest_edges[(ftest_edges['bx'] > item['bx'] - 500) & 
                                (ftest_edges['bx'] < item['bx'] + 500) & 
                                (ftest_edges['by'] > item['by'] - 500) & 
                                (ftest_edges['by'] < item['by'] + 500)]
    if len(iftest_edges) == 0:
        iftest_edges = ftest_edges
    
    
    jtem = iftest_edges.iloc[iftest_edges.distance(item.geometry).argmin()]
    u, v = str(jtem['u']), str(jtem['v'])
    vec_u, vec_v = model_node.wv[u], model_node.wv[v]
    dist_u, dist_v = item.geometry.distance(fosmid2geo[u]), item.geometry.distance(fosmid2geo[v])
    ratios = np.array([1/dist_u, 1/dist_v])
    ratios /= np.sum(ratios)
    
    
    vec = vec_u*ratios[0] + vec_v*ratios[1]
    vectors.append(vec)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 68848/68848 [03:21<00:00, 342.04it/s]

# %%
np.save(f'{dname}/road2vec_n2v_32_nodes.npy', vectors)

# %%
house_gdf_3310 = house_gdf.to_crs('epsg:3310')
thouse_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
n2v_vectors = np.array(vectors)
n2v_vectors_train = n2v_vectors[:len(thouse_gdf_3310)]

# %%
train_gdf_3310 = train_gdf.to_crs('epsg:3310')

# %%
dist_mat = []
for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    mdist1 = np.linalg.norm(n2v_vectors[i] - n2v_vectors_train, axis=-1)
    mdist1 /= mdist1.std()
    #dist_mat.append(mdist1)
    mdist2 = train_gdf_3310.distance(item.geometry).values
    mdist2 /= mdist2.std()
    dist_mat.append(mdist1 + mdist2*10)
dist_mat = np.stack(dist_mat, 0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 68848/68848 [20:25<00:00, 56.19it/s]

# %%
j=100
ahgdf = train_gdf.copy()
ahgdf['diststr'] = dist_mat[j]

# %%
Map([
#     Layer(fhgdf, color_continuous_style('diststr', palette='sunset')),
#     Layer(gdf.iloc[data_ori['idx_geo'][j]], color_continuous_style('price', palette='sunset'))
    Layer(ahgdf.iloc[dist_mat[j].argsort()[1:61]], color_continuous_style('diststr', palette='sunset')),
    Layer(house_gdf.iloc[[j]], basic_style(color='green')),

])
# Out:
# /home/smhan/.conda/envs/TF2/lib/python3.10/site-packages/cartoframes/utils/utils.py:552: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   parameter_args = inspect.getargspec(decorated_function).args
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#           <div class=&quot;as-map-panels&quot; data-name=&quot;Legends&quot;>
#             <div class=&quot;as-panel as-panel--vertical as-panel--left as-panel--top&quot;>
#
#
# <div class=&quot;as-panel__element&quot; id=&quot;legends&quot;>
#   <as-layer-selector id=&quot;layer-selector&quot;>
#
#
#
#
#
#
#         <div slot=&quot;as-checkbox-layer-1-slot&quot;>
#
#
#               <as-legend
#                 heading=&quot;diststr&quot;
#                 description=&quot;&quot;>
#                 <as-legend-color-continuous id=&quot;layer1_map0_legend0&quot; slot=&quot;legends&quot;></as-legend-color-continuous>
#
#               </as-legend>
#
#
#         </div>
#
#
#   </as-layer-selector>
# </div>
#             </div> <!-- as-panel -->
#           </div> <!-- as-map-panels -->
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {

# %%
new_idx = []
new_dist_eucli = []
new_dist_geo = []

for i, (_, item) in tqdm.tqdm(enumerate(house_gdf_3310.iterrows()), total=len(house_gdf_3310)):
    target = item.values[:-1]
    candidates = thouse_gdf_3310.iloc[dist_mat[i].argsort()[1:61]].values[:, :-1]
    new_idx.append(dist_mat[i].argsort()[1:61])
    new_dist_geo.append(dist_mat[i][dist_mat[i].argsort()[1:61]])
    new_dist_eucli.append(np.linalg.norm(target.astype(float) - candidates.astype(float), axis=-1))
    
new_idx = np.stack(new_idx, 0)
new_dist_eucli = np.stack(new_dist_eucli, 0)
new_dist_geo = np.stack(new_dist_geo, 0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 68848/68848 [16:34<00:00, 69.26it/s]

# %%
newdata = dict() 
newdata['X_train'] = data['X_train']
newdata['y_train'] = data['y_train']
newdata['X_test'] = data['X_test']
newdata['y_test'] = data['y_test']
newdata['idx_eucli'] = new_idx
newdata['idx_geo'] = new_idx
newdata['dist_eucli'] = new_dist_eucli
newdata['dist_geo'] = new_dist_geo

# %%
dname
# Out:
# 'sp'

# %%
np.savez(f'{dname}/data_n2v_nodes.npz', **newdata)
